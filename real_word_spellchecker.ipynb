# %% [markdown]
# <a href="https://colab.research.google.com/github/Neilus03/NLP-2023/blob/main/exercise3_real_word_spellchecker_neil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import pickle
import os

# %%
words = None
if False:
    from nltk.corpus import gutenberg as corpus
    words = corpus.words()
    vocabulary = vocabulary[803:-2]
    # first 803 and last 2 words are punctuation signs, numbers and underscored 
    # words like _home_
else:
    # Using the whole corpus means too much work to later compute the words at a 
    # distance for each word in the vocabulary, so we load just one book
    import nltk
    nltk.download('gutenberg')
    words = nltk.corpus.gutenberg.words('austen-emma.txt')
    # using all the words in the book will take 25-30 min. to process later
    # so we limit its number for the moment.
    words = words[:10000] # cell [15] will take 1.5 min. 
    #words = words[:100000] # cell [15] will take 15 min.
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
vocabulary = list(set(words))
vocabulary.sort()
# get rid of some non-words like ',' '--' '['
idx_first_word = vocabulary.index('A')
vocabulary = vocabulary[idx_first_word:]
# plus some more annoying non-words
vocabulary.remove('[')
vocabulary.remove(']')
vocabulary.remove('`')
vocabulary.remove('II')
vocabulary = np.array(vocabulary)
print(vocabulary)
print('Vocabulary size {} words'.format(len(vocabulary)))
# Out:
# ['A' 'Abbey' 'After' ... 'yourself' 'youth' 'youthful']
# Vocabulary size 1711 words

# %% [markdown]
# For each word in the vocabulary find the nearest words = at Levenshtein distance up to ``MAX_DIST``. This is a long computation, $O(n^2)$ for $n$ size of the vocabulary. We try to speed up it a little : if $\text{dist}(w_1, w_2) \leq d$ then $|\text{len}(w_1) - \text{len}(w_2)| \leq d$. This reduces the candidate words in the vocabulary for which to compute the distance to each word.
# We save the resulting dictionary to avoid recomputing it each time.

# %%
from nltk.metrics.distance import edit_distance

def levenshtein(s1, s2):
    return edit_distance(s1, s2, substitution_cost=1, transpositions=True)

word_lengths = np.array([len(w) for w in vocabulary])
dict_lengths = {}
for l in range(min(word_lengths), max(word_lengths)+1):
    dict_lengths[l] = vocabulary[word_lengths==l] # needs vocabulary to be a numpy array

min_length = min(dict_lengths)
max_length = max(dict_lengths)

MAX_DIST = 1
fname = 'close_words_{}.pkl'.format(MAX_DIST)
if not os.path.exists(fname):
    close_words = {}
    for word in tqdm(vocabulary):
        length = len(word)
        candidate_words = []
        d1 = max(min_length, length - MAX_DIST)
        d2 = min(max_length, length + MAX_DIST)
        for d in range(d1, d2+1):
            candidate_words.extend(dict_lengths[d])
        close_words[word] = [w for w in candidate_words if levenshtein(word,w) <= MAX_DIST]
    #becareful with pickle, remove the file so you can recompute the distances for new words in next batch
    with open(fname,'wb') as f:
        pickle.dump(close_words, f)
else:
    close_words = pickle.load(open(fname,'rb'))

print(close_words)
# Out:
# {'A': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At'], 'Abbey': ['Abbey'], 'After': ['After', 'after'], 'Agricultural': ['Agricultural'], 'Ah': ['A', 'Ah', 'An', 'As', 'At', 'Oh'], 'Alderneys': ['Alderneys'], 'All': ['All', 'all', 'ill'], 'Altogether': ['Altogether', 'altogether'], 'An': ['A', 'Ah', 'An', 'As', 'At', 'In', 'an', 'in', 'on', 'And'], 'And': ['An', 'And', 'and', 'end'], 'As': ['A', 's', 'Ah', 'An', 'As', 'At', 'as', 'is', 'us'], 'At': ['A', 'Ah', 'An', 'As', 'At', 'It', 'at', 'it'], 'Austen': ['Austen'], 'Bates': ['Bates'], 'Being': ['Being', 'being'], 'Between': ['Between', 'between'], 'Boarding': ['Boarding'], 'Broadway': ['Broadway'], 'Brunswick': ['Brunswick'], 'But': ['But', 'but', 'out', 'put'], 'By': ['By', 'My', 'by', 'my'], 'CHAPTER': ['CHAPTER'], 'Captain': ['Captain'], 'Children': ['Children', 'children'], 'Christmas': ['Christmas'], 'Churchill': ['Churchill', 'Churchills'], 'Churchills': ['Churchill', 'Churchills'], 'Dear': ['Dear', 'bear', 'dear', 'hear', 'tear', 'year'], 'Depend': ['Depend', 'depend'], 'Dirty': ['Dirty', 'dirty'], 'Donwell': ['Donwell'], 'Elegant': ['Elegant', 'elegant'], 'Elton': ['Elton'], 'Emma': ['Emma'], 'Encouragement': ['Encouragement', 'encouragement'], 'Enscombe': ['Enscombe'], 'Especially': ['Especially', 'especially'], 'Even': ['Even', 'Ever', 'even'], 'Ever': ['Even', 'Ever', 'ever', 'over', 'Every'], 'Every': ['Ever', 'very', 'Every', 'every'], 'Extracts': ['Extracts'], 'Farm': ['Farm', 'farm', 'harm', 'warm'], 'Farmer': ['Farmer', 'farmer'], 'For': ['or', 'For', 'for', 'nor'], 'Forest': ['Forest'], 'Fortunately': ['Fortunately'], 'Frank': ['rank', 'Frank', 'drank'], 'From': ['From', 'from'], 'Goddard': ['Goddard'], 'Had': ['Had', 'bad', 'had', 'sad'], 'Hannah': ['Hannah'], 'Harriet': ['Harriet'], 'Hartfield': ['Hartfield'], 'He': ['He', 'We', 'be', 'he', 'me', 'we', 'Her'], 'Her': ['He', 'Her', 'her'], 'Highbury': ['Highbury'], 'His': ['is', 'His', 'Tis', 'his'], 'How': ['How', 'Now', 'cow', 'how', 'now'], 'I': ['A', 'I', 'a', 's', 'IV', 'If', 'In', 'It'], 'III': ['III'], 'IV': ['I', 'IV', 'If', 'In', 'It'], 'If': ['I', 'IV', 'If', 'In', 'It', 'if', 'of'], 'In': ['I', 'An', 'IV', 'If', 'In', 'It', 'an', 'in', 'on'], 'Invite': ['Invite'], 'Isabella': ['Isabella'], 'It': ['I', 'At', 'IV', 'If', 'In', 'It', 'at', 'it'], 'James': ['James', 'games'], 'Jane': ['Jane', 'June', 'Lane'], 'June': ['Jane', 'June'], 'Kingston': ['Kingston'], 'Knightley': ['Knightley'], 'Lane': ['Jane', 'Lane'], 'London': ['London'], 'Look': ['Look', 'look', 'took'], 'Martin': ['Martin', 'Martins'], 'Martins': ['Martin', 'Martins'], 'Matrimony': ['Matrimony', 'matrimony'], 'Mill': ['ill', 'Mill', 'fill', 'till', 'will'], 'Miss': ['Miss', 'miss'], 'Mitchell': ['Mitchell'], 'Mr': ['Mr', 'My', 'or', 'Mrs'], 'Mrs': ['Mr', 'Mrs'], 'My': ['By', 'Mr', 'My', 'by', 'my'], 'Nash': ['Nash'], 'No': ['No', 'To', 'do', 'go', 'no', 'so', 'to', 'Not', 'Now'], 'Nobody': ['Nobody', 'nobody'], 'Not': ['No', 'Not', 'Now', 'got', 'not'], 'November': ['November'], 'Now': ['No', 'How', 'Not', 'Now', 'cow', 'how', 'now'], 'October': ['October'], 'Oh': ['Ah', 'Oh'], 'One': ['One', 'one'], 'Only': ['Only', 'only'], 'Ours': ['Ours'], 'Perry': ['Perry', 'merry', 'Perrys'], 'Perrys': ['Perry', 'Perrys'], 'Poor': ['Poor', 'door', 'poor'], 'Pray': ['Pray', 'pray'], 'Prince': ['Prince'], 'Quick': ['Quick'], 'Randalls': ['Randalls'], 'Real': ['Real', 'deal', 'meal', 'real'], 'Reports': ['Reports'], 'Richardson': ['Richardson'], 'Romance': ['Romance'], 'School': ['School', 'school'], 'Serle': ['Serle'], 'She': ['he', 'She', 'The', 'she', 'the'], 'Sixteen': ['Sixteen', 'sixteen'], 'Smith': ['Smith'], 'Some': ['Some', 'come', 'home', 'some'], 'Somebody': ['Somebody', 'somebody'], 'Sorrow': ['Sorrow', 'sorrow'], 'Square': ['Square'], 'Success': ['Success', 'success'], 'Such': ['Such', 'much', 'such'], 'Sunday': ['Sunday'], 'Taylor': ['Taylor'], 'That': ['That', 'What', 'that', 'what'], 'The': ['he', 'She', 'The', 'she', 'the', 'They'], ' ...

# %% [markdown]
# Given one sentence $X$, which is a list of words, build the candidates to correct sentence $C(X)$ assuming at most one word is mispelled.

# %%
#sentence = 'Only two of the apple'
sentence = 'I wish you where here'
X = sentence.split(' ')
for x in X:
  assert x in vocabulary, 'All the words in the sentence must belong to the '\
      + 'vocabulary, {} doesn\'t'.format(x)
CX = [X] # no errors
#print(CX)
for i in range(len(X)): # one mispelled word at a time
    
    if X[i] in vocabulary: 
        for cw in close_words[X[i]]:
            if cw != X[i]:
                C = X.copy()
                C[i] = cw
                CX.append(C)
    else:
        pass # let it be as it is
print(f'Sentence that contain a mispelled word to be corrected:\n{CX[0]}\n\n\nCandidates to be the corrected sentence:\n')
for W in CX[1:]: #as I dont want to print the same sentence that was mispelled.
    print('\t'.join(W))
# Out:
# Sentence that contain a mispelled word to be corrected:
# ['I', 'wish', 'you', 'where', 'here']
#
#
# Candidates to be the corrected sentence:
#
# A	wish	you	where	here
# a	wish	you	where	here
# s	wish	you	where	here
# IV	wish	you	where	here
# If	wish	you	where	here
# In	wish	you	where	here
# It	wish	you	where	here
# I	fish	you	where	here
# I	with	you	where	here
# I	wish	You	where	here
# I	wish	your	where	here
# I	wish	you	here	here
# I	wish	you	were	here
# I	wish	you	There	here
# I	wish	you	Where	here
# I	wish	you	there	here
# I	wish	you	where	her
# I	wish	you	where	hers
# I	wish	you	where	were
# I	wish	you	where	There
# I	wish	you	where	Where
# I	wish	you	where	there
# I	wish	you	where	where

# %% [markdown]
# Likelihood $P(X | W) = \prod_{i=1}^n p(x_i | w_i)$ where $n$ is number of words in $X$ (same as in $W$), and $p(x | w)$  is Eq. B.8. $X$ is the written sentence, $W$ are the candidate sentences in $C(X)$. Each $W$ contains zero (ie, $W=X$) or at most one mispelled word, and in this case the mispelled word $w_i$ is at a Levenshtein distance $1...$ ``MAX_DIST`` of the written word $x_i$

# %%
alpha = 0.95
likelihoods = []
for W in CX:
    PXW = 1.0
    #print(X,W)
    for x,w in zip(X,W):
        if w==x:
            pxw = alpha
        else:
            close_to_x = close_words[x] # includes x itself
            pxw = (1-alpha) / (len(close_to_x) - 1) # so we substract 1
        PXW *= pxw
    likelihoods.append(PXW)

likelihoods = np.array(likelihoods)
idx_most_likely = likelihoods.argmax()
print('Sentence with highest likelihood is the written one, X:')
print('\t'.join(CX[idx_most_likely]), '\t', likelihoods[idx_most_likely])
print('\n\nLikelihoods\n')
num_candidates = len(CX)
for i in range(1,num_candidates): #the 1 is not to print again the likelihood of X as wehave just printed before
    print('\t'.join(CX[i]), '\t', likelihoods[i])
# Out:
# Sentence with highest likelihood is the written one, X:
# I	wish	you	where	here 	 0.7737809374999999
#
#
# Likelihoods
#
# A	wish	you	where	here 	 0.005817901785714291
# a	wish	you	where	here 	 0.005817901785714291
# s	wish	you	where	here 	 0.005817901785714291
# IV	wish	you	where	here 	 0.005817901785714291
# If	wish	you	where	here 	 0.005817901785714291
# In	wish	you	where	here 	 0.005817901785714291
# It	wish	you	where	here 	 0.005817901785714291
# I	fish	you	where	here 	 0.020362656250000017
# I	with	you	where	here 	 0.020362656250000017
# I	wish	You	where	here 	 0.020362656250000017
# I	wish	your	where	here 	 0.020362656250000017
# I	wish	you	here	here 	 0.008145062500000006
# I	wish	you	were	here 	 0.008145062500000006
# I	wish	you	There	here 	 0.008145062500000006
# I	wish	you	Where	here 	 0.008145062500000006
# I	wish	you	there	here 	 0.008145062500000006
# I	wish	you	where	her 	 0.00581790178571429
# I	wish	you	where	hers 	 0.00581790178571429
# I	wish	you	where	were 	 0.00581790178571429
# I	wish	you	where	There 	 0.00581790178571429
# I	wish	you	where	Where 	 0.00581790178571429
# I	wish	you	where	there 	 0.00581790178571429
# I	wish	you	where	where 	 0.00581790178571429

# %% [markdown]
# Priors $P(W)$ for all $W \in C(X)$ computed by a LM model, for instance tri-grams (on this same corpus). We've chosen the stupid backoff version.

# %%
nltk.download('punkt')

sents = nltk.corpus.gutenberg.sents('austen-emma.txt')
text = []
for s in tqdm(sents):
    text.append(s[:-1]) # except ending point

from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm.models import StupidBackoff

n=3
lm = StupidBackoff(alpha=0.4, order=n)
train, vocab = padded_everygram_pipeline(n, text)
lm.fit(train, vocab)
print(lm.counts)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100%|██████████| 7752/7752 [00:00<00:00, 19082.32it/s]
# <NgramCounter with 3 ngram orders and 623964 ngrams>

# %%
def P(W, verbose=False):
    S = ['<s>', '<s>',] + W + ['</s>'] 
    if verbose: print(S)
    num_words = len(S)
    PW = 1.0
    for i in range(2,num_words-1): # omit </s> because likelihoods don't have it
        score = lm.score(S[i], [S[i-2], S[i-1]])
        if verbose: print('P({} | {}, {}) = {}'.format(S[i], S[i-2], S[i-1], score))
        PW *= score
    return PW

print('X =', X)
score = P(X, verbose=True)
print('P(X) = {}'.format(score))
for i in range(len(CX)):
    print('\nW = CX[i] = {}'.format(CX[i]))
    score = P(CX[i], verbose=True)
    print('P(W) = {}'.format(score))
# Out:
# X = ['I', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(X) = 1.1475972685804098e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1475972685804098e-11
#
# W = CX[i] = ['A', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'A', 'wish', 'you', 'where', 'here', '</s>']
# P(A | <s>, <s>) = 0.011996904024767802
# P(wish | <s>, A) = 9.937888198757765e-05
# P(you | A, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2559652429973822e-15
#
# W = CX[i] = ['a', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'a', 'wish', 'you', 'where', 'here', '</s>']
# P(a | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, a) = 0.00026631158455392814
# P(you | a, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.8095085058862247e-16
#
# W = CX[i] = ['s', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 's', 'wish', 'you', 'where', 'here', '</s>']
# P(s | <s>, <s>) = 0.000691944006674701
# P(wish | <s>, s) = 0.0004287245444801715
# P(you | s, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.1250979180599283e-16
#
# W = CX[i] = ['IV', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'IV', 'wish', 'you', 'where', 'here', '</s>']
# P(IV | <s>, <s>) = 0.0
# P(wish | <s>, IV) = 9.937888198757765e-05
# P(you | IV, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 0.0
#
# W = CX[i] = ['If', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'If', 'wish', 'you', 'where', 'here', '</s>']
# P(If | <s>, <s>) = 0.009545923632610939
# P(wish | <s>, If) = 9.937888198757765e-05
# P(you | If, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 9.993701933527558e-16
#
# W = CX[i] = ['In', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'In', 'wish', 'you', 'where', 'here', '</s>']
# P(In | <s>, <s>) = 0.00696594427244582
# P(wish | <s>, In) = 9.937888198757765e-05
# P(you | In, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 7.292701410952542e-16
#
# W = CX[i] = ['It', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'It', 'wish', 'you', 'where', 'here', '</s>']
# P(It | <s>, <s>) = 0.0380546955624355
# P(wish | <s>, It) = 9.937888198757765e-05
# P(you | It, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.983975770798148e-15
#
# W = CX[i] = ['I', 'fish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'fish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(fish | <s>, I) = 1.48326689533698e-06
# P(you | I, fish) = 0.0012437192917400576
# P(where | fish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.639226995003733e-18
#
# W = CX[i] = ['I', 'with', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'with', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(with | <s>, I) = 0.0008803189023824974
# P(you | I, with) = 0.010109519797809606
# P(where | with, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.75565033967376e-14
#
# W = CX[i] = ['I', 'wish', 'You', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'You', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(You | I, wish) = 0.00022471493464355243
# P(where | wish, You) = 5.265597478446279e-05
# P(here | You, where) = 9.863724853990915e-05
# P(W) = 1.6561492188051316e-15
#
# W = CX[i] = ['I', 'wish', 'your', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'your', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(your | I, wish) = 0.03125
# P(where | wish, your) = 5.265597478446279e-05
# P(here | your, where) = 9.863724853990915e-05
# P(W) = 2.3031252092681206e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'here', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'here', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(here | wish, you) = 9.863724853990915e-05
# P(here | you, here) = 9.863724853990915e-05
# P(W) = 4.745735466421492e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'were', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'were', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(were | wish, you) = 0.010256410256410256
# P(here | you, were) = 0.046511627906976744
# P(W) = 2.3269044616873836e-07
#
# W = CX[i] = ['I', 'wish', 'you', 'There', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'There', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(There | wish, you) = 9.567071474923519e-05
# P(here | you, There) = 9.863724853990915e-05
# P(W) = 4.603006580213327e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'Where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'Where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(Where | wish, you) = 1.186613516269584e-05
# P(here | you, Where) = 9.863724853990915e-05
# P(W) = 5.709155448326608e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'there', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'there', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(there | wish, you) = 0.0007155635062611808
# P(here | you, there) = 9.863724853990915e-05
# P(W) = 3.4427918057412304e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'her']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'her', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(her | you, where) = 0.0017658292388986745
# P(W) = 2.0544579672856812e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hers']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hers', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hers | you, where) = 1.4832668953369799e-05
# P(W) = 1.725710178316406e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'were']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'were', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(were | you, where) = 0.00043830536757207754
# P(W) = 5.0994735769249797e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'There']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'There', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(There | you, where) = 9.567071474923519e-05
# P(W) = 1.1130830650140817e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Where | you, where) = 1.186613516269584e-05
# P(W) = 1.3805681426531248e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'there']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'there', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(there | you, where) = 0.011267605633802818
# P(W) = 1.3109320910914838e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(where | you, where) = 5.265597478446279e-05
# P(W) = 6.126271133023242e-12

# %%
priors = []
for W in CX:
    priors.append(P(W))
    
posteriors = np.array(priors)*np.array(likelihoods)
idx_best_post = np.argmax(posteriors)

for i in range(num_candidates):
    best = '<----' if i==idx_best_post else ''
    print('\t'.join(CX[i]), '\tlikelihood = {}\tprior = {}\tposterior = {} {}'
          .format(likelihoods[i], priors[i], posteriors[i],best))

print('\nThe original sentence was:')
print('\t' + ' '.join(X))
print('The right sentence is:')
print('\t' + ' '.join(CX[idx_best_post]))
# Out:
# I	wish	you	where	here 	likelihood = 0.7737809374999999	prior = 1.1475972685804098e-11	posterior = 8.879888903545887e-12
# A	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 1.2559652429973822e-15	posterior = 7.307082430029553e-18
# a	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 1.8095085058862247e-16	posterior = 1.0527542767660666e-18
# s	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 3.1250979180599283e-16	posterior = 1.818151275801287e-18
# IV	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 0.0	posterior = 0.0
# If	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 9.993701933527558e-16	posterior = 5.8142376324966335e-18
# In	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 7.292701410952542e-16	posterior = 4.242822056146192e-18
# It	wish	you	where	here 	likelihood = 0.005817901785714291	prior = 3.983975770798148e-15	posterior = 2.3178379751169013e-17
# I	fish	you	where	here 	likelihood = 0.020362656250000017	prior = 3.639226995003733e-18	posterior = 7.410432831498154e-20
# I	with	you	where	here 	likelihood = 0.020362656250000017	prior = 1.75565033967376e-14	posterior = 3.574970436197254e-16
# I	wish	You	where	here 	likelihood = 0.020362656250000017	prior = 1.6561492188051316e-15	posterior = 3.372359724123496e-17
# I	wish	your	where	here 	likelihood = 0.020362656250000017	prior = 2.3031252092681206e-13	posterior = 4.689774693703609e-15
# I	wish	you	here	here 	likelihood = 0.008145062500000006	prior = 4.745735466421492e-12	posterior = 3.8654311982469735e-14
# I	wish	you	were	here 	likelihood = 0.008145062500000006	prior = 2.3269044616873836e-07	posterior = 1.895278227197261e-09 <----
# I	wish	you	There	here 	likelihood = 0.008145062500000006	prior = 4.603006580213327e-12	posterior = 3.749177628374884e-14
# I	wish	you	Where	here 	likelihood = 0.008145062500000006	prior = 5.709155448326608e-13	posterior = 4.650142794883578e-15
# I	wish	you	there	here 	likelihood = 0.008145062500000006	prior = 3.4427918057412304e-11	posterior = 2.80417544322502e-13
# I	wish	you	where	her 	likelihood = 0.00581790178571429	prior = 2.0544579672856812e-10	posterior = 1.1952634676546316e-12
# I	wish	you	where	hers 	likelihood = 0.00581790178571429	prior = 1.725710178316406e-12	posterior = 1.0040012328052345e-14
# I	wish	you	where	were 	likelihood = 0.00581790178571429	prior = 5.0994735769249797e-11	posterior = 2.9668236429394675e-13
# I	wish	you	where	There 	likelihood = 0.00581790178571429	prior = 1.1130830650140817e-11	posterior = 6.47580795159376e-14
# I	wish	you	where	Where 	likelihood = 0.00581790178571429	prior = 1.3805681426531248e-12	posterior = 8.032009862441876e-15
# I	wish	you	where	there 	likelihood = 0.00581790178571429	prior = 1.3109320910914838e-09	posterior = 7.626874153711311e-12
# I	wish	you	where	where 	likelihood = 0.00581790178571429	prior = 6.126271133023242e-12	posterior = 3.5642043764585823e-14
#
# The original sentence was:
# 	I wish you where here
# The right sentence is:
# 	I wish you were here

# %% [markdown]
# That's it! Now, let's try this code and do some modifications:
# 1. change probabilities by log of probabilities to get scores more easy to interpret
# 1. relax the assumption that in a sentence there's at most 1 mispelled word, what if we suppose there may be at most 2 ?
# 1. and what is the effect of $\alpha$ ? change it to 0.9, 0.8...
# 1. make a long (>20) list of sentences each with 1 or 2 mispelled words to assess the speller : does it really work ?
# 1. same for a second list of sentences withouth any spelling error (but different from any one in the selected part of the book), are there any errors ?
# 1. extra points: what if you change the tri-gram language model by the neural network of exercise 2 ?

# %% [markdown]
# ### 1. change probabilities by log of probabilities to get scores more easy to interpret

# %%
import math

alpha = 0.95 ################CHANGED CODE NOTED BY '#' #######################
log_likelihoods = [] ##############################
for W in CX: #######################################
    log_PXW = 0.0 #######################################
    #print(X,W)
    for x, w in zip(X, W):#######################################
        if w == x:#######################################
            pxw = alpha#######################################
        else:#######################################
            close_to_x = close_words[x]  # includes x itself#######################################
            pxw = (1 - alpha) / (len(close_to_x) - 1)  # so we subtract 1#######################################
        log_PXW += math.log(pxw)#######################################
    log_likelihoods.append(log_PXW)#######################################

log_likelihoods = np.array(log_likelihoods)
idx_most_likely = log_likelihoods.argmax()
print('Sentence with highest likelihood is the written one, X:')
print('\t'.join(CX[idx_most_likely]), '\t', log_likelihoods[idx_most_likely])
print('\n\nLikelihoods\n')
num_candidates = len(CX)
for i in range(1,num_candidates): #the 1 is not to print again the likelihood of X as wehave just printed before
    print('\t'.join(CX[i]), '\t', likelihoods[i])
# Out:
# Sentence with highest likelihood is the written one, X:
# I	wish	you	where	here 	 -0.2564664719377529
#
#
# Likelihoods
#
# A	wish	you	where	here 	 0.005817901785714291
# a	wish	you	where	here 	 0.005817901785714291
# s	wish	you	where	here 	 0.005817901785714291
# IV	wish	you	where	here 	 0.005817901785714291
# If	wish	you	where	here 	 0.005817901785714291
# In	wish	you	where	here 	 0.005817901785714291
# It	wish	you	where	here 	 0.005817901785714291
# I	fish	you	where	here 	 0.020362656250000017
# I	with	you	where	here 	 0.020362656250000017
# I	wish	You	where	here 	 0.020362656250000017
# I	wish	your	where	here 	 0.020362656250000017
# I	wish	you	here	here 	 0.008145062500000006
# I	wish	you	were	here 	 0.008145062500000006
# I	wish	you	There	here 	 0.008145062500000006
# I	wish	you	Where	here 	 0.008145062500000006
# I	wish	you	there	here 	 0.008145062500000006
# I	wish	you	where	her 	 0.00581790178571429
# I	wish	you	where	hers 	 0.00581790178571429
# I	wish	you	where	were 	 0.00581790178571429
# I	wish	you	where	There 	 0.00581790178571429
# I	wish	you	where	Where 	 0.00581790178571429
# I	wish	you	where	there 	 0.00581790178571429
# I	wish	you	where	where 	 0.00581790178571429

# %%
nltk.download('punkt')

sents = nltk.corpus.gutenberg.sents('austen-emma.txt')
text = []
for s in tqdm(sents):
    text.append(s[:-1])  # except ending point

from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm.models import StupidBackoff

n = 3
lm = StupidBackoff(alpha=0.4, order=n)
train, vocab = padded_everygram_pipeline(n, text)
lm.fit(train, vocab)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100%|██████████| 7752/7752 [00:00<00:00, 11975.02it/s]

# %%
def log_P(W, verbose=False):
    S = ['<s>', '<s>'] + W + ['</s>']
    if verbose: print(S)
    num_words = len(S)
    log_PW = 0.0
    epsilon = 1e-20  # small value to avoid log(0)
    for i in range(2, num_words - 1):  # omit </s> because likelihoods don't have it
        score = lm.score(S[i], [S[i - 2], S[i - 1]])
        if verbose: print('P({} | {}, {}) = {}'.format(S[i], S[i - 2], S[i - 1], score))
        log_PW += math.log(score + epsilon)
    return log_PW


print('X =', X)
score = P(X, verbose=True)
print('P(X) = {}'.format(score))
for i in range(len(CX)):
    print('\nW = CX[i] = {}'.format(CX[i]))
    score = P(CX[i], verbose=True)
    print('P(W) = {}'.format(score))
# Out:
# X = ['I', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(X) = 1.1475972685804098e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1475972685804098e-11
#
# W = CX[i] = ['A', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'A', 'wish', 'you', 'where', 'here', '</s>']
# P(A | <s>, <s>) = 0.011996904024767802
# P(wish | <s>, A) = 9.937888198757765e-05
# P(you | A, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2559652429973822e-15
#
# W = CX[i] = ['a', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'a', 'wish', 'you', 'where', 'here', '</s>']
# P(a | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, a) = 0.00026631158455392814
# P(you | a, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.8095085058862247e-16
#
# W = CX[i] = ['s', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 's', 'wish', 'you', 'where', 'here', '</s>']
# P(s | <s>, <s>) = 0.000691944006674701
# P(wish | <s>, s) = 0.0004287245444801715
# P(you | s, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.1250979180599283e-16
#
# W = CX[i] = ['IV', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'IV', 'wish', 'you', 'where', 'here', '</s>']
# P(IV | <s>, <s>) = 0.0
# P(wish | <s>, IV) = 9.937888198757765e-05
# P(you | IV, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 0.0
#
# W = CX[i] = ['If', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'If', 'wish', 'you', 'where', 'here', '</s>']
# P(If | <s>, <s>) = 0.009545923632610939
# P(wish | <s>, If) = 9.937888198757765e-05
# P(you | If, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 9.993701933527558e-16
#
# W = CX[i] = ['In', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'In', 'wish', 'you', 'where', 'here', '</s>']
# P(In | <s>, <s>) = 0.00696594427244582
# P(wish | <s>, In) = 9.937888198757765e-05
# P(you | In, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 7.292701410952542e-16
#
# W = CX[i] = ['It', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'It', 'wish', 'you', 'where', 'here', '</s>']
# P(It | <s>, <s>) = 0.0380546955624355
# P(wish | <s>, It) = 9.937888198757765e-05
# P(you | It, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.983975770798148e-15
#
# W = CX[i] = ['I', 'fish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'fish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(fish | <s>, I) = 1.48326689533698e-06
# P(you | I, fish) = 0.0012437192917400576
# P(where | fish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.639226995003733e-18
#
# W = CX[i] = ['I', 'with', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'with', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(with | <s>, I) = 0.0008803189023824974
# P(you | I, with) = 0.010109519797809606
# P(where | with, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.75565033967376e-14
#
# W = CX[i] = ['I', 'wish', 'You', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'You', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(You | I, wish) = 0.00022471493464355243
# P(where | wish, You) = 5.265597478446279e-05
# P(here | You, where) = 9.863724853990915e-05
# P(W) = 1.6561492188051316e-15
#
# W = CX[i] = ['I', 'wish', 'your', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'your', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(your | I, wish) = 0.03125
# P(where | wish, your) = 5.265597478446279e-05
# P(here | your, where) = 9.863724853990915e-05
# P(W) = 2.3031252092681206e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'here', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'here', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(here | wish, you) = 9.863724853990915e-05
# P(here | you, here) = 9.863724853990915e-05
# P(W) = 4.745735466421492e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'were', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'were', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(were | wish, you) = 0.010256410256410256
# P(here | you, were) = 0.046511627906976744
# P(W) = 2.3269044616873836e-07
#
# W = CX[i] = ['I', 'wish', 'you', 'There', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'There', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(There | wish, you) = 9.567071474923519e-05
# P(here | you, There) = 9.863724853990915e-05
# P(W) = 4.603006580213327e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'Where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'Where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(Where | wish, you) = 1.186613516269584e-05
# P(here | you, Where) = 9.863724853990915e-05
# P(W) = 5.709155448326608e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'there', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'there', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(there | wish, you) = 0.0007155635062611808
# P(here | you, there) = 9.863724853990915e-05
# P(W) = 3.4427918057412304e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'her']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'her', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(her | you, where) = 0.0017658292388986745
# P(W) = 2.0544579672856812e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hers']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hers', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hers | you, where) = 1.4832668953369799e-05
# P(W) = 1.725710178316406e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'were']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'were', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(were | you, where) = 0.00043830536757207754
# P(W) = 5.0994735769249797e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'There']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'There', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(There | you, where) = 9.567071474923519e-05
# P(W) = 1.1130830650140817e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Where | you, where) = 1.186613516269584e-05
# P(W) = 1.3805681426531248e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'there']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'there', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(there | you, where) = 0.011267605633802818
# P(W) = 1.3109320910914838e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(where | you, where) = 5.265597478446279e-05
# P(W) = 6.126271133023242e-12

# %%
log_priors = []
for W in CX:
    log_priors.append(log_P(W))

log_posteriors = np.array(log_priors) + np.array(log_likelihoods)
idx_best_post = np.argmax(log_posteriors)

for i in range(num_candidates):
    best = '<----' if i == idx_best_post else ''
    print('\t'.join(CX[i]), '\tlog_likelihood = {}\tlog_prior = {}\tlog_posterior = {} {}'
          .format(log_likelihoods[i], log_priors[i], log_posteriors[i], best))


print('\nThe original sentence was:')
print('\t' + ' '.join(X))
print('The right sentence is:')
print('\t' + ' '.join(CX[idx_best_post]))

print('\nAs it is the sentence with the highest posterior probability')
# Out:
# I	wish	you	where	here 	log_likelihood = -0.2564664719377529	log_prior = -25.190765597926926	log_posterior = -25.44723206986468
# A	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -34.31087200002036	log_posterior = -39.45768760017987
# a	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -36.24830622321094	log_posterior = -41.395121823370445
# s	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -35.701895871428086	log_posterior = -40.84871147158759
# IV	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -75.93946719948393	log_posterior = -81.08628279964343
# If	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -34.53940639996945	log_posterior = -39.68622200012896
# In	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -34.85448744660935	log_posterior = -40.001303046768854
# It	wish	you	where	here 	log_likelihood = -5.146815600159504	log_prior = -33.156496136833795	log_posterior = -38.3033117369933
# I	fish	you	where	here 	log_likelihood = -3.8940526316641377	log_prior = -40.15476037880656	log_posterior = -44.048813010470695
# I	with	you	where	here 	log_likelihood = -3.8940526316641377	log_prior = -31.673351949723987	log_posterior = -35.567404581388125
# I	wish	You	where	here 	log_likelihood = -3.8940526316641377	log_prior = -34.034281235032985	log_posterior = -37.92833386669712
# I	wish	your	where	here 	log_likelihood = -3.8940526316641377	log_prior = -29.09933922166435	log_posterior = -32.99339185332849
# I	wish	you	here	here 	log_likelihood = -4.810343363538292	log_prior = -26.073774697685543	log_posterior = -30.884118061223838
# I	wish	you	were	here 	log_likelihood = -4.810343363538292	log_prior = -15.273556823911006	log_posterior = -20.0839001874493 <----
# I	wish	you	There	here 	log_likelihood = -4.810343363538292	log_prior = -26.104311421545624	log_posterior = -30.91465478508392
# I	wish	you	Where	here 	log_likelihood = -4.810343363538292	log_prior = -28.191535103667512	log_posterior = -33.001878467205806
# I	wish	you	there	here 	log_likelihood = -4.810343363538292	log_prior = -24.09215330925882	log_posterior = -28.902496672797113
# I	wish	you	where	her 	log_likelihood = -5.146815600159505	log_prior = -22.30583887966182	log_posterior = -27.452654479821327
# I	wish	you	where	hers 	log_likelihood = -5.146815600159505	log_prior = -27.08538245259469	log_posterior = -32.23219805275419
# I	wish	you	where	were 	log_likelihood = -5.146815600159505	log_prior = -23.69929870874258	log_posterior = -28.846114308902088
# I	wish	you	where	There 	log_likelihood = -5.146815600159505	log_prior = -25.221302321787007	log_posterior = -30.368117921946514
# I	wish	you	where	Where 	log_likelihood = -5.146815600159505	log_prior = -27.308526003908902	log_posterior = -32.45534160406841
# I	wish	you	where	there 	log_likelihood = -5.146815600159505	log_prior = -20.45252743282648	log_posterior = -25.599343032985985
# I	wish	you	where	where 	log_likelihood = -5.146815600159505	log_prior = -25.818434849107366	log_posterior = -30.965250449266872
#
# The original sentence was:
# 	I wish you where here
# The right sentence is:
# 	I wish you were here
#
# As it is the sentence with the highest posterior probability

# %% [markdown]
# ### 2.relax the assumption that in a sentence there's at most 1 mispelled word, what if we suppose there may be at most 2

# %%
from nltk.metrics.distance import edit_distance

def levenshtein(s1, s2):
    return edit_distance(s1, s2, substitution_cost=1, transpositions=True)

word_lengths = np.array([len(w) for w in vocabulary])
dict_lengths = {}
for l in range(min(word_lengths), max(word_lengths)+1):
    dict_lengths[l] = vocabulary[word_lengths==l] # needs vocabulary to be a numpy array

min_length = min(dict_lengths)
max_length = max(dict_lengths)

MAX_DIST_2 = 2 ##############CHANGED VALUE###############################
fname = 'close_words_{}.pkl'.format(MAX_DIST_2)
if not os.path.exists(fname):
    close_words = {}
    for word in tqdm(vocabulary):
        length = len(word)
        candidate_words = []
        d1 = max(min_length, length - MAX_DIST_2)
        d2 = min(max_length, length + MAX_DIST_2)
        for d in range(d1, d2+1):
            candidate_words.extend(dict_lengths[d])
        close_words[word] = [w for w in candidate_words if levenshtein(word,w) <= MAX_DIST_2]
    #becareful with pickle, remove the file so you can recompute the distances for new words in next batch
    with open(fname,'wb') as f:
        pickle.dump(close_words, f)
else:
    close_words = pickle.load(open(fname,'rb'))

print(close_words)
# Out:
# {'A': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At', 'By', 'He', 'IV', 'If', 'In', 'It', 'Mr', 'My', 'No', 'Oh', 'To', 'We', 'am', 'an', 'as', 'at', 'be', 'by', 'do', 'go', 'he', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'we', 'All', 'And'], 'Abbey': ['Abbey'], 'After': ['After', 'after', 'often', 'water'], 'Agricultural': ['Agricultural'], 'Ah': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At', 'By', 'He', 'IV', 'If', 'In', 'It', 'Mr', 'My', 'No', 'Oh', 'To', 'We', 'am', 'an', 'as', 'at', 'be', 'by', 'do', 'go', 'he', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'we', 'All', 'And', 'She', 'The', 'Who', 'she', 'shy', 'the', 'who', 'why'], 'Alderneys': ['Alderneys'], 'All': ['A', 'Ah', 'An', 'As', 'At', 'All', 'And', 'all', 'ill', 'old', 'Mill', 'Well', 'call', 'fell', 'fill', 'full', 'tell', 'till', 'well', 'will'], 'Altogether': ['together', 'Altogether', 'altogether'], 'An': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At', 'By', 'He', 'IV', 'If', 'In', 'It', 'Mr', 'My', 'No', 'Oh', 'To', 'We', 'am', 'an', 'as', 'at', 'be', 'by', 'do', 'go', 'he', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'we', 'All', 'And', 'One', 'and', 'any', 'can', 'end', 'man', 'one', 'own', 'run', 'son', 'win'], 'And': ['A', 'Ah', 'An', 'As', 'At', 'In', 'an', 'in', 'no', 'on', 'All', 'And', 'Had', 'One', 'and', 'any', 'bad', 'bid', 'did', 'end', 'had', 'led', 'odd', 'old', 'one', 'sad', 'find', 'fond', 'kind', 'mind', 'send'], 'As': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At', 'By', 'He', 'IV', 'If', 'In', 'It', 'Mr', 'My', 'No', 'Oh', 'To', 'We', 'am', 'an', 'as', 'at', 'be', 'by', 'do', 'go', 'he', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'we', 'All', 'And', 'His', 'Mrs', 'Tis', 'ask', 'has', 'his', 'its', 'was', 'yes'], 'At': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At', 'By', 'He', 'IV', 'If', 'In', 'It', 'Mr', 'My', 'No', 'Oh', 'To', 'We', 'am', 'an', 'as', 'at', 'be', 'by', 'do', 'go', 'he', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'we', 'All', 'And', 'But', 'Not', 'bit', 'but', 'eat', 'get', 'got', 'its', 'let', 'met', 'not', 'out', 'put', 'sat', 'set', 'sit', 'yet'], 'Austen': ['Austen'], 'Bates': ['ages', 'hate', 'late', 'rate', 'Bates', 'James', 'eaten', 'games', 'water'], 'Being': ['sing', 'Being', 'being', 'bring', 'doing', 'going', 'owing', 'thing', 'beings'], 'Between': ['Between', 'between', 'betweens'], 'Boarding': ['Boarding'], 'Broadway': ['Broadway'], 'Brunswick': ['Brunswick'], 'But': ['At', 'By', 'It', 'at', 'it', 'up', 'us', 'But', 'Not', 'bit', 'but', 'due', 'eat', 'get', 'got', 'let', 'met', 'not', 'our', 'out', 'put', 'run', 'sat', 'set', 'sit', 'sup', 'yet', 'aunt', 'hurt', 'just', 'must'], 'By': ['A', 'I', 'a', 's', 'Ah', 'An', 'As', 'At', 'By', 'He', 'IV', 'If', 'In', 'It', 'Mr', 'My', 'No', 'Oh', 'To', 'We', 'am', 'an', 'as', 'at', 'be', 'by', 'do', 'go', 'he', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'we', 'But', 'any', 'boy', 'bye', 'day', 'joy', 'lay', 'may', 'pay', 'say', 'shy', 'way', 'why'], 'CHAPTER': ['CHAPTER'], 'Captain': ['Captain'], 'Children': ['Children', 'children'], 'Christmas': ['Christmas'], 'Churchill': ['Churchill', 'Churchills'], 'Churchills': ['Churchill', 'Churchills'], 'Dear': ['Her', 'eat', 'far', 'her', 'tea', 'Dear', 'Real', 'bear', 'deal', 'dear', 'head', 'hear', 'heir', 'meal', 'mean', 'neat', 'read', 'real', 'seat', 'tear', 'year', 'bears', 'heard', 'heart', 'tears', 'years'], 'Depend': ['spend', 'Depend', 'depend'], 'Dirty': ['pity', 'Dirty', 'dirty', 'fifty', 'thirty'], 'Donwell': ['Donwell'], 'Elegant': ['Elegant', 'elegant'], 'Elton': ['Elton'], 'Emma': ['Emma'], 'Encouragement': ['Encouragement', 'encouragement', 'encouragements'], 'Enscombe': ['Enscombe'], 'Especially': ['Especially', 'especially'], 'Even': ['vex', 'Even', 'Ever', 'When', 'been', 'even' ...

# %%
#sentence = 'Only two of the apples'
sentence = 'I wish you where here'
X = sentence.split(' ')
for x in X:
  assert x in vocabulary, 'All the words in the sentence must belong to the '\
      + 'vocabulary, {} doesn\'t'.format(x)
CX = [X] # no errors
#print(CX)
for i in range(len(X)): # one mispelled word at a time
    
    if X[i] in vocabulary: 
        for cw in close_words[X[i]]:
            if cw != X[i]:
                C = X.copy()
                C[i] = cw
                CX.append(C)
    else:
        pass # let it be as it is
print(f'Sentence that contain a mispelled word to be corrected:\n{CX[0]}\n\n\nCandidates to be the corrected sentence:\n')
for W in CX[1:]: #as I dont want to print the same sentence that was mispelled.
    print('\t'.join(W))
# Out:
# Sentence that contain a mispelled word to be corrected:
# ['I', 'wish', 'you', 'where', 'here']
#
#
# Candidates to be the corrected sentence:
#
# A	wish	you	where	here
# a	wish	you	where	here
# s	wish	you	where	here
# Ah	wish	you	where	here
# An	wish	you	where	here
# As	wish	you	where	here
# At	wish	you	where	here
# By	wish	you	where	here
# He	wish	you	where	here
# IV	wish	you	where	here
# If	wish	you	where	here
# In	wish	you	where	here
# It	wish	you	where	here
# Mr	wish	you	where	here
# My	wish	you	where	here
# No	wish	you	where	here
# Oh	wish	you	where	here
# To	wish	you	where	here
# We	wish	you	where	here
# am	wish	you	where	here
# an	wish	you	where	here
# as	wish	you	where	here
# at	wish	you	where	here
# be	wish	you	where	here
# by	wish	you	where	here
# do	wish	you	where	here
# go	wish	you	where	here
# he	wish	you	where	here
# if	wish	you	where	here
# in	wish	you	where	here
# is	wish	you	where	here
# it	wish	you	where	here
# me	wish	you	where	here
# my	wish	you	where	here
# no	wish	you	where	here
# of	wish	you	where	here
# on	wish	you	where	here
# or	wish	you	where	here
# so	wish	you	where	here
# to	wish	you	where	here
# up	wish	you	where	here
# us	wish	you	where	here
# we	wish	you	where	here
# III	wish	you	where	here
# I	is	you	where	here
# I	His	you	where	here
# I	Tis	you	where	here
# I	his	you	where	here
# I	was	you	where	here
# I	win	you	where	here
# I	Miss	you	where	here
# I	Nash	you	where	here
# I	With	you	where	here
# I	fish	you	where	here
# I	high	you	where	here
# I	miss	you	where	here
# I	rich	you	where	here
# I	sigh	you	where	here
# I	wife	you	where	here
# I	will	you	where	here
# I	wine	you	where	here
# I	with	you	where	here
# I	which	you	where	here
# I	wished	you	where	here
# I	wishes	you	where	here
# I	wish	No	where	here
# I	wish	To	where	here
# I	wish	do	where	here
# I	wish	go	where	here
# I	wish	no	where	here
# I	wish	of	where	here
# I	wish	on	where	here
# I	wish	or	where	here
# I	wish	so	where	here
# I	wish	to	where	here
# I	wish	For	where	here
# I	wish	How	where	here
# I	wish	Not	where	here
# I	wish	Now	where	here
# I	wish	You	where	here
# I	wish	boy	where	here
# I	wish	cow	where	here
# I	wish	for	where	here
# I	wish	got	where	here
# I	wish	how	where	here
# I	wish	joy	where	here
# I	wish	nor	where	here
# I	wish	not	where	here
# I	wish	now	where	here
# I	wish	our	where	here
# I	wish	out	where	here
# I	wish	son	where	here
# I	wish	too	where	here
# I	wish	yes	where	here
# I	wish	yet	where	here
# I	wish	Your	where	here
# I	wish	four	where	here
# I	wish	hour	where	here
# I	wish	your	where	here
# I	wish	_you_	where	here
# I	wish	young	where	here
# I	wish	youth	where	here
# I	wish	you	her	here
# I	wish	you	here	here
# I	wish	you	hers	here
# I	wish	you	were	here
# I	wish	you	when	here
# I	wish	you	There	here
# I	wish	you	These	here
# I	wish	you	Where	here
# I	wish	you	_her_	here
# I	wish	you	cheer	here
# I	wish	you	share	here
# I	wish	you	there	here
# I	wish	you	these	here
# I	wish	you	three	here
# I	wish	you	while	here
# I	wish	you	whole	here
# I	wish	you	whose	here
# I	wish	you	where	he
# I	wish	you	where	Her
# I	wish	you	where	are
# I	wish	you	where	her
# I	wish	you	where	see
# I	wish	you	where	bore
# I	wish	you	where	care
# I	wish	you	where	dare
# I	wish	you	where	fire
# I	wish	you	where	free
# I	wish	you	where	hard
# I	wish	you	where	harm
# I	wish	you	where	hate
# I	wish	you	where	have
# I	wish	you	where	head
# I	wish	you	where	hear
# I	wish	you	where	heir
# I	wish	you	where	help
# I	wish	you	where	hers
# I	wish	you	where	home
# I	wish	you	where	hope
# I	wish	you	where	hurt
# I	wish	you	where	more
# I	wish	you	where	sure
# I	wish	you	where	very
# I	wish	you	where	were
# I	wish	you	where	Serle
# I	wish	you	where	There
# I	wish	you	where	These
# I	wish	you	where	Where
# I	wish	you	where	_her_
# I	wish	you	where	cheer
# I	wish	you	where	heard
# I	wish	you	where	heart
# I	wish	you	where	share
# I	wish	you	where	there
# I	wish	you	where	these
# I	wish	you	where	three
# I	wish	you	where	where

# %%
alpha = 0.95
likelihoods = []
for W in CX:
    PXW = 1.0
    #print(X,W)
    for x,w in zip(X,W):
        if w==x:
            pxw = alpha
        else:
            close_to_x = close_words[x] # includes x itself
            pxw = (1-alpha) / (len(close_to_x) - 1) # so we substract 1
        PXW *= pxw
    likelihoods.append(PXW)

likelihoods = np.array(likelihoods)
idx_most_likely = likelihoods.argmax()
print('Sentence with highest likelihood is the written one, X:')
print('\t'.join(CX[idx_most_likely]), '\t', likelihoods[idx_most_likely])
print('\n\nLikelihoods\n')
num_candidates = len(CX)
for i in range(1,num_candidates): #the 1 is not to print again the likelihood of X as wehave just printed before
    print('\t'.join(CX[i]), '\t', likelihoods[i])
# Out:
# Sentence with highest likelihood is the written one, X:
# I	wish	you	where	here 	 0.7737809374999999
#
#
# Likelihoods
#
# A	wish	you	where	here 	 0.0009255752840909097
# a	wish	you	where	here 	 0.0009255752840909097
# s	wish	you	where	here 	 0.0009255752840909097
# Ah	wish	you	where	here 	 0.0009255752840909097
# An	wish	you	where	here 	 0.0009255752840909097
# As	wish	you	where	here 	 0.0009255752840909097
# At	wish	you	where	here 	 0.0009255752840909097
# By	wish	you	where	here 	 0.0009255752840909097
# He	wish	you	where	here 	 0.0009255752840909097
# IV	wish	you	where	here 	 0.0009255752840909097
# If	wish	you	where	here 	 0.0009255752840909097
# In	wish	you	where	here 	 0.0009255752840909097
# It	wish	you	where	here 	 0.0009255752840909097
# Mr	wish	you	where	here 	 0.0009255752840909097
# My	wish	you	where	here 	 0.0009255752840909097
# No	wish	you	where	here 	 0.0009255752840909097
# Oh	wish	you	where	here 	 0.0009255752840909097
# To	wish	you	where	here 	 0.0009255752840909097
# We	wish	you	where	here 	 0.0009255752840909097
# am	wish	you	where	here 	 0.0009255752840909097
# an	wish	you	where	here 	 0.0009255752840909097
# as	wish	you	where	here 	 0.0009255752840909097
# at	wish	you	where	here 	 0.0009255752840909097
# be	wish	you	where	here 	 0.0009255752840909097
# by	wish	you	where	here 	 0.0009255752840909097
# do	wish	you	where	here 	 0.0009255752840909097
# go	wish	you	where	here 	 0.0009255752840909097
# he	wish	you	where	here 	 0.0009255752840909097
# if	wish	you	where	here 	 0.0009255752840909097
# in	wish	you	where	here 	 0.0009255752840909097
# is	wish	you	where	here 	 0.0009255752840909097
# it	wish	you	where	here 	 0.0009255752840909097
# me	wish	you	where	here 	 0.0009255752840909097
# my	wish	you	where	here 	 0.0009255752840909097
# no	wish	you	where	here 	 0.0009255752840909097
# of	wish	you	where	here 	 0.0009255752840909097
# on	wish	you	where	here 	 0.0009255752840909097
# or	wish	you	where	here 	 0.0009255752840909097
# so	wish	you	where	here 	 0.0009255752840909097
# to	wish	you	where	here 	 0.0009255752840909097
# up	wish	you	where	here 	 0.0009255752840909097
# us	wish	you	where	here 	 0.0009255752840909097
# we	wish	you	where	here 	 0.0009255752840909097
# III	wish	you	where	here 	 0.0009255752840909097
# I	is	you	where	here 	 0.0019393005952380966
# I	His	you	where	here 	 0.0019393005952380966
# I	Tis	you	where	here 	 0.0019393005952380966
# I	his	you	where	here 	 0.0019393005952380966
# I	was	you	where	here 	 0.0019393005952380966
# I	win	you	where	here 	 0.0019393005952380966
# I	Miss	you	where	here 	 0.0019393005952380966
# I	Nash	you	where	here 	 0.0019393005952380966
# I	With	you	where	here 	 0.0019393005952380966
# I	fish	you	where	here 	 0.0019393005952380966
# I	high	you	where	here 	 0.0019393005952380966
# I	miss	you	where	here 	 0.0019393005952380966
# I	rich	you	where	here 	 0.0019393005952380966
# I	sigh	you	where	here 	 0.0019393005952380966
# I	wife	you	where	here 	 0.0019393005952380966
# I	will	you	where	here 	 0.0019393005952380966
# I	wine	you	where	here 	 0.0019393005952380966
# I	with	you	where	here 	 0.0019393005952380966
# I	which	you	where	here 	 0.0019393005952380966
# I	wished	you	where	here 	 0.0019393005952380966
# I	wishes	you	where	here 	 0.0019393005952380966
# I	wish	No	where	here 	 0.0011006841216216225
# I	wish	To	where	here 	 0.0011006841216216225
# I	wish	do	where	here 	 0.0011006841216216225
# I	wish	go	where	here 	 0.0011006841216216225
# I	wish	no	where	here 	 0.0011006841216216225
# I	wish	of	where	here 	 0.0011006841216216225
# I	wish	on	where	here 	 0.0011006841216216225
# I	wish	or	where	here 	 0.0011006841216216225
# I	wish	so	where	here 	 0.0011006841216216225
# I	wish	to	where	here 	 0.0011006841216216225
# I	wish	For	where	here 	 0.0011006841216216225
# I	wish	How	where	here 	 0.0011006841216216225
# I	wish	Not	where	here 	 0.0011006841216216225
# I	wish	Now	where	here 	 0.0011006841216216225
# I	wish	You	where	here 	 0.0011006841216216225
# I	wish	boy	where	here 	 0.0011006841216216225
# I	wish	cow	where	here 	 0.0011006841216216225
# I	wish	for	where	here 	 0.0011006841216216225
# I	wish	got	where	here 	 0.0011006841216216225
# I	wish	how	where	here 	 0.0011006841216216225
# I	wish	joy	where	here 	 0.0011006841216216225
# I	wish	nor	where	here 	 0.0011006841216216225
# I	wish	not	where	here 	 0.0011006841216216225
# I	wish	now	where	here 	 0.0011006841216216225
# I	wish	our	where	here 	 0.0011006841216216225
# I	wish	out	where	here 	 0.0011006841216216225
# I	wish	son	where	here 	 0.0011006841216216225
# I	wish	too	where	here 	 0.0011006841216216225
# I	wish	yes	where	here 	 0.0011006841216216225
# I	wish	yet	where	here 	 0.0011006841216216225
# I	wish	Your	where	here 	 0.0011006841216216225
# I	wish	four	where	here 	 0.0011006841216216225
# I	wish	hour	where	here 	 0.0011006841216216225
# I	wish	your	where	here 	 0.0011006841216216225
# I	wish	_you_	where	here 	 0.0011006841216216225
# I	wish	young	where	here 	 0.0011006841216216225
# I	wish	youth	where	here 	 0.0011006841216216225
# I	wish	you	her	here 	 0.0023956066176470604
# I	wish	you	here	here 	 0.0023956066176470604
# I	wish	you	hers	here 	 0.0023956066176470604
# I	wish	you	were	here 	 0.0023956066176470604
# I	wish	you	when	here 	 0.0023956066176470604
# I	wish	you	There	here 	 0.0023956066176470604
# I	wish	you	These	here 	 0.0023956066176470604
# I	wish	you	Where	here 	 0.0023956066176470604
# I	wish	you	_her_	here 	 0.0023956066176470604
# I	wish	you	cheer	here 	 0.0023956066176470604
# I	wish	you	share	here 	 0.0023956066176470604
# I	wish	you	there	here 	 0.0023956066176470604
# I	wish	you	these	here 	 0.0023956066176470604
# I	wish	you	three	here 	 0.0023956066176470604
# I	wish	you	while	here 	 0.0023956066176470604
# I	wish	you	whole	here 	 0.0023956066176470604
# I	wish	you	whose	here 	 0.0023956066176470604
# I	wish	you	where	he 	 0.0010442387820512827
# I	wish	you	where	Her 	 0.0010442387820512827
# I	wish	you	where	are 	 0.0010442387820512827
# I	wish	you	where	her 	 0.0010442387820512827
# I	wish	you	where	see 	 0.0010442387820512827
# I	wish	you	where	bore 	 0.0010442387820512827
# I	wish	you	where	care 	 0.0010442387820512827
# I	wish	you	where	dare 	 0.0010442387820512827
# I	wish	you	where	fire 	 0.0010442387820512827
# I	wish	you	where	free 	 0.0010442387820512827
# I	wish	you	where	hard 	 0.0010442387820512827
# I	wish	you	where	harm 	 0.0010442387820512827
# I	wish	you	where	hate 	 0.0010442387820512827
# I	wish	you	where	have 	 0.0010442387820512827
# I	wish	you	where	head 	 0.0010442387820512827
# I	wish	you	where	hear 	 0.0010442387820512827
# I	wish	you	where	heir 	 0.0010442387820512827
# I	wish	you	where	help 	 0.0010442387820512827
# I	wish	you	where	hers 	 0.0010442387820512827
# I	wish	you	where	home 	 0.0010442387820512827
# I	wish	you	where	hope 	 0.0010442387820512827
# I	wish	you	where	hurt 	 0.0010442387820512827
# I	wish	you	where	more 	 0.0010442387820512827
# I	wish	you	where	sure 	 0.0010442387820512827
# I	wish	you	where	very 	 0.0010442387820512827
# I	wish	you	where	were 	 0.0010442387820512827
# I	wish	you	where	Serle 	 0.0010442387820512827
# I	wish	you	where	There 	 0.0010442387820512827
# I	wish	you	where	These 	 0.0010442387820512827
# I	wish	you	where	Where 	 0.0010442387820512827
# I	wish	you	where	_her_ 	 0.0010442387820512827
# I	wish	you	where	cheer 	 0.0010442387820512827
# I	wish	you	where	heard 	 0.0010442387820512827
# I	wish	you	where	heart 	 0.0010442387820512827
# I	wish	you	where	share 	 0.0010442387820512827
# I	wish	you	where	there 	 0.0010442387820512827
# I	wish	you	where	these 	 0.0010442387820512827
# I	wish	you	where	three 	 0.0010442387820512827
# I	wish	you	where	where 	 0.0010442387820512827

# %%
nltk.download('punkt')

sents = nltk.corpus.gutenberg.sents('austen-emma.txt')
text = []
for s in tqdm(sents):
    text.append(s[:-1]) # except ending point

from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm.models import StupidBackoff

n=3
lm = StupidBackoff(alpha=0.4, order=n)
train, vocab = padded_everygram_pipeline(n, text)
lm.fit(train, vocab)
print(lm.counts)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100%|██████████| 7752/7752 [00:00<00:00, 17890.61it/s]
# <NgramCounter with 3 ngram orders and 623964 ngrams>

# %%
def P(W, verbose=False):
    S = ['<s>', '<s>',] + W + ['</s>'] 
    if verbose: print(S)
    num_words = len(S)
    PW = 1.0
    for i in range(2,num_words-1): # omit </s> because likelihoods don't have it
        score = lm.score(S[i], [S[i-2], S[i-1]])
        if verbose: print('P({} | {}, {}) = {}'.format(S[i], S[i-2], S[i-1], score))
        PW *= score
    return PW

print('X =', X)
score = P(X, verbose=True)
print('P(X) = {}'.format(score))
for i in range(len(CX)):
    print('\nW = CX[i] = {}'.format(CX[i]))
    score = P(CX[i], verbose=True)
    print('P(W) = {}'.format(score))
# Out:
# X = ['I', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(X) = 1.1475972685804098e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1475972685804098e-11
#
# W = CX[i] = ['A', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'A', 'wish', 'you', 'where', 'here', '</s>']
# P(A | <s>, <s>) = 0.011996904024767802
# P(wish | <s>, A) = 9.937888198757765e-05
# P(you | A, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2559652429973822e-15
#
# W = CX[i] = ['a', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'a', 'wish', 'you', 'where', 'here', '</s>']
# P(a | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, a) = 0.00026631158455392814
# P(you | a, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.8095085058862247e-16
#
# W = CX[i] = ['s', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 's', 'wish', 'you', 'where', 'here', '</s>']
# P(s | <s>, <s>) = 0.000691944006674701
# P(wish | <s>, s) = 0.0004287245444801715
# P(you | s, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.1250979180599283e-16
#
# W = CX[i] = ['Ah', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'Ah', 'wish', 'you', 'where', 'here', '</s>']
# P(Ah | <s>, <s>) = 0.0007739938080495357
# P(wish | <s>, Ah) = 9.937888198757765e-05
# P(you | Ah, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 8.103001567725047e-17
#
# W = CX[i] = ['An', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'An', 'wish', 'you', 'where', 'here', '</s>']
# P(An | <s>, <s>) = 0.0011609907120743034
# P(wish | <s>, An) = 9.937888198757765e-05
# P(you | An, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.215450235158757e-16
#
# W = CX[i] = ['As', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'As', 'wish', 'you', 'where', 'here', '</s>']
# P(As | <s>, <s>) = 0.004901960784313725
# P(wish | <s>, As) = 9.937888198757765e-05
# P(you | As, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.13190099289253e-16
#
# W = CX[i] = ['At', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'At', 'wish', 'you', 'where', 'here', '</s>']
# P(At | <s>, <s>) = 0.00348297213622291
# P(wish | <s>, At) = 9.937888198757765e-05
# P(you | At, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.646350705476271e-16
#
# W = CX[i] = ['By', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'By', 'wish', 'you', 'where', 'here', '</s>']
# P(By | <s>, <s>) = 0.0011609907120743034
# P(wish | <s>, By) = 9.937888198757765e-05
# P(you | By, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.215450235158757e-16
#
# W = CX[i] = ['He', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'He', 'wish', 'you', 'where', 'here', '</s>']
# P(He | <s>, <s>) = 0.04618163054695562
# P(wish | <s>, He) = 9.937888198757765e-05
# P(you | He, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.834790935409278e-15
#
# W = CX[i] = ['IV', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'IV', 'wish', 'you', 'where', 'here', '</s>']
# P(IV | <s>, <s>) = 0.0
# P(wish | <s>, IV) = 9.937888198757765e-05
# P(you | IV, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 0.0
#
# W = CX[i] = ['If', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'If', 'wish', 'you', 'where', 'here', '</s>']
# P(If | <s>, <s>) = 0.009545923632610939
# P(wish | <s>, If) = 9.937888198757765e-05
# P(you | If, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 9.993701933527558e-16
#
# W = CX[i] = ['In', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'In', 'wish', 'you', 'where', 'here', '</s>']
# P(In | <s>, <s>) = 0.00696594427244582
# P(wish | <s>, In) = 9.937888198757765e-05
# P(you | In, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 7.292701410952542e-16
#
# W = CX[i] = ['It', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'It', 'wish', 'you', 'where', 'here', '</s>']
# P(It | <s>, <s>) = 0.0380546955624355
# P(wish | <s>, It) = 9.937888198757765e-05
# P(you | It, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.983975770798148e-15
#
# W = CX[i] = ['Mr', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'Mr', 'wish', 'you', 'where', 'here', '</s>']
# P(Mr | <s>, <s>) = 0.023864809081527348
# P(wish | <s>, Mr) = 9.937888198757765e-05
# P(you | Mr, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.498425483381889e-15
#
# W = CX[i] = ['My', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'My', 'wish', 'you', 'where', 'here', '</s>']
# P(My | <s>, <s>) = 0.006707946336429308
# P(wish | <s>, My) = 9.937888198757765e-05
# P(you | My, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 7.022601358695041e-16
#
# W = CX[i] = ['No', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'No', 'wish', 'you', 'where', 'here', '</s>']
# P(No | <s>, <s>) = 0.005159958720330237
# P(wish | <s>, No) = 9.937888198757765e-05
# P(you | No, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.402001045150032e-16
#
# W = CX[i] = ['Oh', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'Oh', 'wish', 'you', 'where', 'here', '</s>']
# P(Oh | <s>, <s>) = 0.005288957688338493
# P(wish | <s>, Oh) = 9.937888198757765e-05
# P(you | Oh, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.537051071278782e-16
#
# W = CX[i] = ['To', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'To', 'wish', 'you', 'where', 'here', '</s>']
# P(To | <s>, <s>) = 0.0045149638802889575
# P(wish | <s>, To) = 9.937888198757765e-05
# P(you | To, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.726750914506278e-16
#
# W = CX[i] = ['We', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'We', 'wish', 'you', 'where', 'here', '</s>']
# P(We | <s>, <s>) = 0.007739938080495356
# P(wish | <s>, We) = 9.937888198757765e-05
# P(you | We, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 8.103001567725046e-16
#
# W = CX[i] = ['am', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'am', 'wish', 'you', 'where', 'here', '</s>']
# P(am | <s>, <s>) = 0.00031296931491610276
# P(wish | <s>, am) = 9.937888198757765e-05
# P(you | am, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.2765001774441984e-17
#
# W = CX[i] = ['an', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'an', 'wish', 'you', 'where', 'here', '</s>']
# P(an | <s>, <s>) = 0.0003352183183461574
# P(wish | <s>, an) = 9.937888198757765e-05
# P(you | an, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.509426730343075e-17
#
# W = CX[i] = ['as', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'as', 'wish', 'you', 'where', 'here', '</s>']
# P(as | <s>, <s>) = 0.00025799793601651185
# P(wish | <s>, as) = 9.937888198757765e-05
# P(you | as, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.7010005225750152e-17
#
# W = CX[i] = ['at', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'at', 'wish', 'you', 'where', 'here', '</s>']
# P(at | <s>, <s>) = 0.0003869969040247678
# P(wish | <s>, at) = 9.937888198757765e-05
# P(you | at, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.051500783862523e-17
#
# W = CX[i] = ['be', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'be', 'wish', 'you', 'where', 'here', '</s>']
# P(be | <s>, <s>) = 0.0014610178919069253
# P(wish | <s>, be) = 9.937888198757765e-05
# P(you | be, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.5295510307026234e-16
#
# W = CX[i] = ['by', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'by', 'wish', 'you', 'where', 'here', '</s>']
# P(by | <s>, <s>) = 0.00012899896800825592
# P(wish | <s>, by) = 9.937888198757765e-05
# P(you | by, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.3505002612875076e-17
#
# W = CX[i] = ['do', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'do', 'wish', 'you', 'where', 'here', '</s>']
# P(do | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, do) = 9.937888198757765e-05
# P(you | do, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 6.75250130643754e-17
#
# W = CX[i] = ['go', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'go', 'wish', 'you', 'where', 'here', '</s>']
# P(go | <s>, <s>) = 0.00012899896800825592
# P(wish | <s>, go) = 9.937888198757765e-05
# P(you | go, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.3505002612875076e-17
#
# W = CX[i] = ['he', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'he', 'wish', 'you', 'where', 'here', '</s>']
# P(he | <s>, <s>) = 0.0010319917440660474
# P(wish | <s>, he) = 9.937888198757765e-05
# P(you | he, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.0804002090300061e-16
#
# W = CX[i] = ['if', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'if', 'wish', 'you', 'where', 'here', '</s>']
# P(if | <s>, <s>) = 0.0005159958720330237
# P(wish | <s>, if) = 9.937888198757765e-05
# P(you | if, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.4020010451500304e-17
#
# W = CX[i] = ['in', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'in', 'wish', 'you', 'where', 'here', '</s>']
# P(in | <s>, <s>) = 0.00012899896800825592
# P(wish | <s>, in) = 9.937888198757765e-05
# P(you | in, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.3505002612875076e-17
#
# W = CX[i] = ['is', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'is', 'wish', 'you', 'where', 'here', '</s>']
# P(is | <s>, <s>) = 0.0009047928061555577
# P(wish | <s>, is) = 9.937888198757765e-05
# P(you | is, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 9.472346484554319e-17
#
# W = CX[i] = ['it', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'it', 'wish', 'you', 'where', 'here', '</s>']
# P(it | <s>, <s>) = 0.0005159958720330237
# P(wish | <s>, it) = 9.937888198757765e-05
# P(you | it, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.4020010451500304e-17
#
# W = CX[i] = ['me', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'me', 'wish', 'you', 'where', 'here', '</s>']
# P(me | <s>, <s>) = 0.0004182812644850283
# P(wish | <s>, me) = 9.937888198757765e-05
# P(you | me, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.3790191944988813e-17
#
# W = CX[i] = ['my', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'my', 'wish', 'you', 'where', 'here', '</s>']
# P(my | <s>, <s>) = 0.001805985552115583
# P(wish | <s>, my) = 0.001938610662358643
# P(you | my, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.6882402127730726e-15
#
# W = CX[i] = ['no', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'no', 'wish', 'you', 'where', 'here', '</s>']
# P(no | <s>, <s>) = 0.003998968008255934
# P(wish | <s>, no) = 0.0006493506493506495
# P(you | no, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.7355303588011164e-15
#
# W = CX[i] = ['of', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'of', 'wish', 'you', 'where', 'here', '</s>']
# P(of | <s>, <s>) = 0.00025799793601651185
# P(wish | <s>, of) = 9.937888198757765e-05
# P(you | of, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.7010005225750152e-17
#
# W = CX[i] = ['on', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'on', 'wish', 'you', 'where', 'here', '</s>']
# P(on | <s>, <s>) = 0.0005020858440715676
# P(wish | <s>, on) = 9.937888198757765e-05
# P(you | on, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.25637587708465e-17
#
# W = CX[i] = ['or', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'or', 'wish', 'you', 'where', 'here', '</s>']
# P(or | <s>, <s>) = 0.0003869969040247678
# P(wish | <s>, or) = 9.937888198757765e-05
# P(you | or, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.051500783862523e-17
#
# W = CX[i] = ['so', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'so', 'wish', 'you', 'where', 'here', '</s>']
# P(so | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, so) = 0.0004329004329004329
# P(you | so, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.9414304933345334e-16
#
# W = CX[i] = ['to', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'to', 'wish', 'you', 'where', 'here', '</s>']
# P(to | <s>, <s>) = 0.0005159958720330237
# P(wish | <s>, to) = 0.0005402276673741077
# P(you | to, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.9365498639224793e-16
#
# W = CX[i] = ['up', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'up', 'wish', 'you', 'where', 'here', '</s>']
# P(up | <s>, <s>) = 0.0001409103550570131
# P(wish | <s>, up) = 9.937888198757765e-05
# P(you | up, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.4752015016928857e-17
#
# W = CX[i] = ['us', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'us', 'wish', 'you', 'where', 'here', '</s>']
# P(us | <s>, <s>) = 0.00010753684991193103
# P(wish | <s>, us) = 9.937888198757765e-05
# P(you | us, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1258116723445703e-17
#
# W = CX[i] = ['we', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'we', 'wish', 'you', 'where', 'here', '</s>']
# P(we | <s>, <s>) = 0.0001928246963938074
# P(wish | <s>, we) = 9.937888198757765e-05
# P(you | we, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.0186967917902647e-17
#
# W = CX[i] = ['III', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'III', 'wish', 'you', 'where', 'here', '</s>']
# P(III | <s>, <s>) = 0.0
# P(wish | <s>, III) = 9.937888198757765e-05
# P(you | III, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 0.0
#
# W = CX[i] = ['I', 'is', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'is', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(is | <s>, I) = 0.0009047928061555577
# P(you | I, is) = 0.0012437192917400576
# P(where | is, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.2199284669522774e-15
#
# W = CX[i] = ['I', 'His', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'His', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(His | <s>, I) = 4.227310651710393e-05
# P(you | I, His) = 0.0012437192917400576
# P(where | His, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.037179693576064e-16
#
# W = CX[i] = ['I', 'Tis', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'Tis', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(Tis | <s>, I) = 1.48326689533698e-06
# P(you | I, Tis) = 0.0012437192917400576
# P(where | Tis, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.639226995003733e-18
#
# W = CX[i] = ['I', 'his', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'his', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(his | <s>, I) = 0.0008068971910633171
# P(you | I, his) = 0.0012437192917400576
# P(where | his, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.9797394852820314e-15
#
# W = CX[i] = ['I', 'was', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'was', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(was | <s>, I) = 0.03538461538461538
# P(you | I, was) = 0.00016771488469601676
# P(where | was, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1707214022560863e-14
#
# W = CX[i] = ['I', 'win', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'win', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(win | <s>, I) = 7.4163344766849e-07
# P(you | I, win) = 0.0012437192917400576
# P(where | win, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.8196134975018665e-18
#
# W = CX[i] = ['I', 'Miss', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'Miss', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(Miss | <s>, I) = 0.00043904700101974605
# P(you | I, Miss) = 0.0012437192917400576
# P(where | Miss, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.0772111905211053e-15
#
# W = CX[i] = ['I', 'Nash', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'Nash', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(Nash | <s>, I) = 9.64123481969037e-06
# P(you | I, Nash) = 0.0012437192917400576
# P(where | Nash, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.365497546752427e-17
#
# W = CX[i] = ['I', 'With', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'With', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(With | <s>, I) = 2.22490034300547e-05
# P(you | I, With) = 0.013333333333333334
# P(where | With, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.852167798912533e-16
#
# W = CX[i] = ['I', 'fish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'fish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(fish | <s>, I) = 1.48326689533698e-06
# P(you | I, fish) = 0.0012437192917400576
# P(where | fish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.639226995003733e-18
#
# W = CX[i] = ['I', 'high', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'high', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(high | <s>, I) = 1.3349402058032818e-05
# P(you | I, high) = 0.0012437192917400576
# P(where | high, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.2753042955033604e-17
#
# W = CX[i] = ['I', 'miss', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'miss', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(miss | <s>, I) = 5.19143413367943e-06
# P(you | I, miss) = 0.0012437192917400576
# P(where | miss, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2737294482513067e-17
#
# W = CX[i] = ['I', 'rich', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'rich', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(rich | <s>, I) = 1.038286826735886e-05
# P(you | I, rich) = 0.0012437192917400576
# P(where | rich, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.5474588965026134e-17
#
# W = CX[i] = ['I', 'sigh', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'sigh', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(sigh | <s>, I) = 1.409103550570131e-05
# P(you | I, sigh) = 0.0012437192917400576
# P(where | sigh, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.457265645253547e-17
#
# W = CX[i] = ['I', 'wife', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wife', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wife | <s>, I) = 5.043107444145732e-05
# P(you | I, wife) = 0.0012437192917400576
# P(where | wife, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2373371783012696e-16
#
# W = CX[i] = ['I', 'will', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'will', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(will | <s>, I) = 0.027692307692307693
# P(you | I, will) = 0.0014311270125223615
# P(where | will, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 7.818164392759399e-14
#
# W = CX[i] = ['I', 'wine', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wine', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wine | <s>, I) = 4.44980068601094e-06
# P(you | I, wine) = 0.0012437192917400576
# P(where | wine, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.0917680985011202e-17
#
# W = CX[i] = ['I', 'with', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'with', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(with | <s>, I) = 0.0008803189023824974
# P(you | I, with) = 0.010109519797809606
# P(where | with, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.75565033967376e-14
#
# W = CX[i] = ['I', 'which', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'which', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(which | <s>, I) = 0.00040938166311300646
# P(you | I, which) = 0.004347826086956522
# P(where | which, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.5113006793475197e-15
#
# W = CX[i] = ['I', 'wished', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wished', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wished | <s>, I) = 0.0001260239445494644
# P(you | I, wished) = 0.008333333333333333
# P(where | wished, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.0717592826766134e-15
#
# W = CX[i] = ['I', 'wishes', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wishes', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wishes | <s>, I) = 1.4832668953369799e-05
# P(you | I, wishes) = 0.0012437192917400576
# P(where | wishes, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.6392269950037337e-17
#
# W = CX[i] = ['I', 'wish', 'No', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'No', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(No | I, wish) = 9.344581440622973e-05
# P(where | wish, No) = 5.265597478446279e-05
# P(here | No, where) = 9.863724853990915e-05
# P(W) = 6.886957147506489e-16
#
# W = CX[i] = ['I', 'wish', 'To', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'To', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(To | I, wish) = 4.153147306943544e-05
# P(where | wish, To) = 5.265597478446279e-05
# P(here | To, where) = 9.863724853990915e-05
# P(W) = 3.0608698433362174e-16
#
# W = CX[i] = ['I', 'wish', 'do', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'do', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(do | I, wish) = 0.0004301473996477241
# P(where | wish, do) = 5.265597478446279e-05
# P(here | do, where) = 9.863724853990915e-05
# P(W) = 3.1701866234553675e-15
#
# W = CX[i] = ['I', 'wish', 'go', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'go', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(go | I, wish) = 9.567071474923519e-05
# P(where | wish, go) = 5.265597478446279e-05
# P(here | go, where) = 9.863724853990915e-05
# P(W) = 7.050932317685214e-16
#
# W = CX[i] = ['I', 'wish', 'no', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'no', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(no | I, wish) = 0.0004568462037637898
# P(where | wish, no) = 0.0006493506493506495
# P(here | no, where) = 9.863724853990915e-05
# P(W) = 4.152113053328443e-14
#
# W = CX[i] = ['I', 'wish', 'of', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'of', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(of | I, wish) = 0.03582089552238806
# P(where | wish, of) = 5.265597478446279e-05
# P(here | of, where) = 9.863724853990915e-05
# P(W) = 2.6400002398774873e-13
#
# W = CX[i] = ['I', 'wish', 'on', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'on', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(on | I, wish) = 0.0029850746268656717
# P(where | wish, on) = 5.265597478446279e-05
# P(here | on, where) = 9.863724853990915e-05
# P(W) = 2.200000199897906e-14
#
# W = CX[i] = ['I', 'wish', 'or', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'or', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(or | I, wish) = 0.00036340038935756013
# P(where | wish, or) = 5.265597478446279e-05
# P(here | or, where) = 9.863724853990915e-05
# P(W) = 2.6782611129191905e-15
#
# W = CX[i] = ['I', 'wish', 'so', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'so', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(so | I, wish) = 0.0006852693056456846
# P(where | wish, so) = 5.265597478446279e-05
# P(here | so, where) = 9.863724853990915e-05
# P(W) = 5.050435241504758e-15
#
# W = CX[i] = ['I', 'wish', 'to', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'to', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(to | I, wish) = 0.08059701492537313
# P(where | wish, to) = 7.717538105344396e-05
# P(here | to, where) = 9.863724853990915e-05
# P(W) = 8.705978893892888e-13
#
# W = CX[i] = ['I', 'wish', 'For', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'For', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(For | I, wish) = 1.928246963938074e-05
# P(where | wish, For) = 5.265597478446279e-05
# P(here | For, where) = 9.863724853990915e-05
# P(W) = 1.421118141548958e-16
#
# W = CX[i] = ['I', 'wish', 'How', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'How', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(How | I, wish) = 8.009641234819692e-05
# P(where | wish, How) = 5.265597478446279e-05
# P(here | How, where) = 9.863724853990915e-05
# P(W) = 5.903106126434133e-16
#
# W = CX[i] = ['I', 'wish', 'Not', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'Not', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(Not | I, wish) = 2.8923704459071105e-05
# P(where | wish, Not) = 5.265597478446279e-05
# P(here | Not, where) = 9.863724853990915e-05
# P(W) = 2.131677212323437e-16
#
# W = CX[i] = ['I', 'wish', 'Now', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'Now', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(Now | I, wish) = 2.6698804116065635e-05
# P(where | wish, Now) = 5.265597478446279e-05
# P(here | Now, where) = 9.863724853990915e-05
# P(W) = 1.9677020421447107e-16
#
# W = CX[i] = ['I', 'wish', 'You', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'You', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(You | I, wish) = 0.00022471493464355243
# P(where | wish, You) = 5.265597478446279e-05
# P(here | You, where) = 9.863724853990915e-05
# P(W) = 1.6561492188051316e-15
#
# W = CX[i] = ['I', 'wish', 'boy', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'boy', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(boy | I, wish) = 9.64123481969037e-06
# P(where | wish, boy) = 5.265597478446279e-05
# P(here | boy, where) = 9.863724853990915e-05
# P(W) = 7.10559070774479e-17
#
# W = CX[i] = ['I', 'wish', 'cow', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'cow', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(cow | I, wish) = 2.22490034300547e-06
# P(where | wish, cow) = 5.265597478446279e-05
# P(here | cow, where) = 9.863724853990915e-05
# P(W) = 1.6397517017872595e-17
#
# W = CX[i] = ['I', 'wish', 'for', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'for', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(for | I, wish) = 0.026865671641791045
# P(where | wish, for) = 5.265597478446279e-05
# P(here | for, where) = 9.863724853990915e-05
# P(W) = 1.9800001799081152e-13
#
# W = CX[i] = ['I', 'wish', 'got', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'got', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(got | I, wish) = 2.6698804116065635e-05
# P(where | wish, got) = 5.265597478446279e-05
# P(here | got, where) = 9.863724853990915e-05
# P(W) = 1.9677020421447107e-16
#
# W = CX[i] = ['I', 'wish', 'how', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'how', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(how | I, wish) = 0.00019504959673681283
# P(where | wish, how) = 5.265597478446279e-05
# P(here | how, where) = 9.863724853990915e-05
# P(W) = 1.4375156585668304e-15
#
# W = CX[i] = ['I', 'wish', 'joy', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'joy', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(joy | I, wish) = 1.3349402058032818e-05
# P(where | wish, joy) = 5.265597478446279e-05
# P(here | joy, where) = 9.863724853990915e-05
# P(W) = 9.838510210723554e-17
#
# W = CX[i] = ['I', 'wish', 'nor', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'nor', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(nor | I, wish) = 4.672290720311487e-05
# P(where | wish, nor) = 5.265597478446279e-05
# P(here | nor, where) = 9.863724853990915e-05
# P(W) = 3.4434785737532443e-16
#
# W = CX[i] = ['I', 'wish', 'not', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'not', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(not | I, wish) = 0.0015581718735514973
# P(where | wish, not) = 5.265597478446279e-05
# P(here | not, where) = 9.863724853990915e-05
# P(W) = 1.1483727751516771e-14
#
# W = CX[i] = ['I', 'wish', 'now', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'now', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(now | I, wish) = 0.0029850746268656717
# P(where | wish, now) = 5.265597478446279e-05
# P(here | now, where) = 9.863724853990915e-05
# P(W) = 2.200000199897906e-14
#
# W = CX[i] = ['I', 'wish', 'our', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'our', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(our | I, wish) = 0.03125
# P(where | wish, our) = 5.265597478446279e-05
# P(here | our, where) = 9.863724853990915e-05
# P(W) = 2.3031252092681206e-13
#
# W = CX[i] = ['I', 'wish', 'out', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'out', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(out | I, wish) = 0.00015722629090571987
# P(where | wish, out) = 5.265597478446279e-05
# P(here | out, where) = 9.863724853990915e-05
# P(W) = 1.1587578692629967e-15
#
# W = CX[i] = ['I', 'wish', 'son', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'son', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(son | I, wish) = 3.411513859275053e-05
# P(where | wish, son) = 5.265597478446279e-05
# P(here | son, where) = 9.863724853990915e-05
# P(W) = 2.5142859427404635e-16
#
# W = CX[i] = ['I', 'wish', 'too', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'too', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(too | I, wish) = 0.00018763326226012793
# P(where | wish, too) = 5.265597478446279e-05
# P(here | too, where) = 9.863724853990915e-05
# P(W) = 1.3828572685072553e-15
#
# W = CX[i] = ['I', 'wish', 'yes', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'yes', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(yes | I, wish) = 2.744043756373413e-05
# P(where | wish, yes) = 5.265597478446279e-05
# P(here | yes, where) = 9.863724853990915e-05
# P(W) = 2.0223604322042866e-16
#
# W = CX[i] = ['I', 'wish', 'yet', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'yet', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(yet | I, wish) = 7.861314545285994e-05
# P(where | wish, yet) = 5.265597478446279e-05
# P(here | yet, where) = 9.863724853990915e-05
# P(W) = 5.793789346314984e-16
#
# W = CX[i] = ['I', 'wish', 'Your', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'Your', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(Your | I, wish) = 2.002410308704923e-05
# P(where | wish, Your) = 5.265597478446279e-05
# P(here | Your, where) = 9.863724853990915e-05
# P(W) = 1.4757765316085334e-16
#
# W = CX[i] = ['I', 'wish', 'four', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'four', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(four | I, wish) = 2.150736998238621e-05
# P(where | wish, four) = 5.265597478446279e-05
# P(here | four, where) = 9.863724853990915e-05
# P(W) = 1.5850933117276838e-16
#
# W = CX[i] = ['I', 'wish', 'hour', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'hour', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(hour | I, wish) = 6.155557615648467e-05
# P(where | wish, hour) = 5.265597478446279e-05
# P(here | hour, where) = 9.863724853990915e-05
# P(W) = 4.536646374944751e-16
#
# W = CX[i] = ['I', 'wish', 'your', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'your', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(your | I, wish) = 0.03125
# P(where | wish, your) = 5.265597478446279e-05
# P(here | your, where) = 9.863724853990915e-05
# P(W) = 2.3031252092681206e-13
#
# W = CX[i] = ['I', 'wish', '_you_', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', '_you_', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(_you_ | I, wish) = 1.112450171502735e-05
# P(where | wish, _you_) = 5.265597478446279e-05
# P(here | _you_, where) = 9.863724853990915e-05
# P(W) = 8.198758508936296e-17
#
# W = CX[i] = ['I', 'wish', 'young', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'young', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(young | I, wish) = 0.0001409103550570131
# P(where | wish, young) = 5.265597478446279e-05
# P(here | young, where) = 9.863724853990915e-05
# P(W) = 1.0385094111319309e-15
#
# W = CX[i] = ['I', 'wish', 'youth', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'youth', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(youth | I, wish) = 8.15796792435339e-06
# P(where | wish, youth) = 5.265597478446279e-05
# P(here | youth, where) = 9.863724853990915e-05
# P(W) = 6.012422906553284e-17
#
# W = CX[i] = ['I', 'wish', 'you', 'her', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'her', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(her | wish, you) = 0.0017658292388986745
# P(here | you, her) = 0.0003359932801343974
# P(W) = 2.8940159690366134e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'here', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'here', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(here | wish, you) = 9.863724853990915e-05
# P(here | you, here) = 9.863724853990915e-05
# P(W) = 4.745735466421492e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'hers', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'hers', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(hers | wish, you) = 1.4832668953369799e-05
# P(here | you, hers) = 9.863724853990915e-05
# P(W) = 7.13644431040826e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'were', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'were', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(were | wish, you) = 0.010256410256410256
# P(here | you, were) = 0.046511627906976744
# P(W) = 2.3269044616873836e-07
#
# W = CX[i] = ['I', 'wish', 'you', 'when', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'when', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(when | wish, you) = 0.00023138963567256884
# P(here | you, when) = 9.863724853990915e-05
# P(W) = 1.1132853124236885e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'There', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'There', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(There | wish, you) = 9.567071474923519e-05
# P(here | you, There) = 9.863724853990915e-05
# P(W) = 4.603006580213327e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'These', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'These', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(These | wish, you) = 1.3349402058032818e-05
# P(here | you, These) = 9.863724853990915e-05
# P(W) = 6.422799879367433e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'Where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'Where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(Where | wish, you) = 1.186613516269584e-05
# P(here | you, Where) = 9.863724853990915e-05
# P(W) = 5.709155448326608e-13
#
# W = CX[i] = ['I', 'wish', 'you', '_her_', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', '_her_', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(_her_ | wish, you) = 1.409103550570131e-05
# P(here | you, _her_) = 9.863724853990915e-05
# P(W) = 6.779622094887847e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'cheer', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'cheer', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(cheer | wish, you) = 2.96653379067396e-06
# P(here | you, cheer) = 9.863724853990915e-05
# P(W) = 1.427288862081652e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'share', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'share', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(share | wish, you) = 1.112450171502735e-05
# P(here | you, share) = 9.863724853990915e-05
# P(W) = 5.352333232806195e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'there', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'there', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(there | wish, you) = 0.0007155635062611808
# P(here | you, there) = 9.863724853990915e-05
# P(W) = 3.4427918057412304e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'these', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'these', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(these | wish, you) = 3.559840548808752e-05
# P(here | you, these) = 9.863724853990915e-05
# P(W) = 1.7127466344979825e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'three', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'three', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(three | wish, you) = 5.043107444145732e-05
# P(here | you, three) = 9.863724853990915e-05
# P(W) = 2.4263910655388083e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'while', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'while', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(while | wish, you) = 8.380457958653935e-05
# P(here | you, while) = 9.863724853990915e-05
# P(W) = 4.0320910353806666e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'whole', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'whole', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(whole | wish, you) = 5.636414202280524e-05
# P(here | you, whole) = 9.863724853990915e-05
# P(W) = 2.711848837955139e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'whose', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'whose', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(whose | wish, you) = 2.8923704459071105e-05
# P(here | you, whose) = 9.863724853990915e-05
# P(W) = 1.3916066405296106e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'he']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'he', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(he | you, where) = 0.033802816901408454
# P(W) = 3.932796273274452e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Her']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Her', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Her | you, where) = 6.526374339482712e-05
# P(W) = 7.593124784592187e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'are']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'are', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(are | you, where) = 0.011267605633802818
# P(W) = 1.3109320910914838e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'her']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'her', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(her | you, where) = 0.0017658292388986745
# P(W) = 2.0544579672856812e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'see']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'see', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(see | you, where) = 0.0001631593584870678
# P(W) = 1.8982811961480467e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'bore']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'bore', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(bore | you, where) = 5.19143413367943e-06
# P(W) = 6.039985624107421e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'care']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'care', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(care | you, where) = 3.782330583109299e-05
# P(W) = 4.400560954706835e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'dare']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'dare', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(dare | you, where) = 4.375637341244091e-05
# P(W) = 5.090845026033398e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'fire']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'fire', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(fire | you, where) = 1.186613516269584e-05
# P(W) = 1.3805681426531248e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'free']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'free', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(free | you, where) = 3.7081672383424498e-06
# P(W) = 4.314275445791015e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hard']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hard', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hard | you, where) = 8.89960137202188e-06
# P(W) = 1.0354261069898435e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'harm']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'harm', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(harm | you, where) = 9.64123481969037e-06
# P(W) = 1.121711615905664e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hate']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hate', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hate | you, where) = 2.96653379067396e-06
# P(W) = 3.451420356632812e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'have']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'have', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(have | you, where) = 0.0009648651154167054
# P(W) = 1.1225744709948221e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'head']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'head', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(head | you, where) = 2.9665337906739598e-05
# P(W) = 3.451420356632812e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hear']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hear', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hear | you, where) = 7.4163344766849e-05
# P(W) = 8.62855089158203e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'heir']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'heir', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(heir | you, where) = 2.22490034300547e-06
# P(W) = 2.588565267474609e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'help']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'help', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(help | you, where) = 2.8923704459071105e-05
# P(W) = 3.3651348477169914e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hers']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hers', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hers | you, where) = 1.4832668953369799e-05
# P(W) = 1.725710178316406e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'home']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'home', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(home | you, where) = 9.64123481969037e-05
# P(W) = 1.121711615905664e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hope']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hope', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hope | you, where) = 0.00010605358301659406
# P(W) = 1.2338827774962302e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hurt']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hurt', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hurt | you, where) = 5.93306758134792e-06
# P(W) = 6.902840713265624e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'more']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'more', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(more | you, where) = 0.00034411791971817934
# P(W) = 4.003647613694062e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'sure']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'sure', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(sure | you, where) = 0.00015129322332437195
# P(W) = 1.760224381882734e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'very']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'very', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(very | you, where) = 0.0008536200982664319
# P(W) = 9.931462076210917e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'were']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'were', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(were | you, where) = 0.00043830536757207754
# P(W) = 5.0994735769249797e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Serle']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Serle', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Serle | you, where) = 2.22490034300547e-06
# P(W) = 2.588565267474609e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'There']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'There', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(There | you, where) = 9.567071474923519e-05
# P(W) = 1.1130830650140817e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'These']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'These', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(These | you, where) = 1.3349402058032818e-05
# P(W) = 1.5531391604847652e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Where | you, where) = 1.186613516269584e-05
# P(W) = 1.3805681426531248e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', '_her_']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', '_her_', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(_her_ | you, where) = 1.409103550570131e-05
# P(W) = 1.6394246694005858e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'cheer']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'cheer', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(cheer | you, where) = 2.96653379067396e-06
# P(W) = 3.451420356632812e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'heard']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'heard', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(heard | you, where) = 8.89960137202188e-05
# P(W) = 1.0354261069898436e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'heart']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'heart', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(heart | you, where) = 4.894780754612034e-05
# P(W) = 5.69484358844414e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'share']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'share', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(share | you, where) = 1.112450171502735e-05
# P(W) = 1.2942826337373046e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'there']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'there', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(there | you, where) = 0.011267605633802818
# P(W) = 1.3109320910914838e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'these']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'these', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(these | you, where) = 0.005633802816901409
# P(W) = 6.554660455457419e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'three']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'three', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(three | you, where) = 5.043107444145732e-05
# P(W) = 5.867414606275781e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(where | you, where) = 5.265597478446279e-05
# P(W) = 6.126271133023242e-12

# %%
priors = []
for W in CX:
    priors.append(P(W))
    
posteriors = np.array(priors)*np.array(likelihoods)
idx_best_post = np.argmax(posteriors)

for i in range(num_candidates):
    best = '<----' if i==idx_best_post else ''
    print('\t'.join(CX[i]), '\tlikelihood = {}\tprior = {}\tposterior = {} {}'
          .format(likelihoods[i], priors[i], posteriors[i],best))

print('\nThe original sentence was:')
print('\t' + ' '.join(X))
print('The right sentence is:')
print('\t' + ' '.join(CX[idx_best_post]))
# Out:
# I	wish	you	where	here 	likelihood = 0.7737809374999999	prior = 1.1475972685804098e-11	posterior = 8.879888903545887e-12
# A	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.2559652429973822e-15	posterior = 1.1624903865956106e-18
# a	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.8095085058862247e-16	posterior = 1.6748363494005602e-19
# s	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 3.1250979180599283e-16	posterior = 2.8925133933202287e-19
# Ah	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 8.103001567725047e-17	posterior = 7.499937978036197e-20
# An	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.215450235158757e-16	posterior = 1.1249906967054295e-19
# As	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 5.13190099289253e-16	posterior = 4.749960719422925e-19
# At	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 3.646350705476271e-16	posterior = 3.374972090116289e-19
# By	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.215450235158757e-16	posterior = 1.1249906967054295e-19
# He	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 4.834790935409278e-15	posterior = 4.474962993561598e-18
# IV	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 0.0	posterior = 0.0
# If	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 9.993701933527558e-16	posterior = 9.249923506244643e-19
# In	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 7.292701410952542e-16	posterior = 6.749944180232578e-19
# It	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 3.983975770798148e-15	posterior = 3.687469505867797e-18
# Mr	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.498425483381889e-15	posterior = 2.3124808765611605e-18
# My	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 7.022601358695041e-16	posterior = 6.499946247631371e-19
# No	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 5.402001045150032e-16	posterior = 4.999958652024132e-19
# Oh	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 5.537051071278782e-16	posterior = 5.124957618324735e-19
# To	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 4.726750914506278e-16	posterior = 4.374963820521115e-19
# We	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 8.103001567725046e-16	posterior = 7.499937978036196e-19
# am	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 3.2765001774441984e-17	posterior = 3.0326475825618304e-20
# an	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 3.509426730343075e-17	posterior = 3.248238642933524e-20
# as	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.7010005225750152e-17	posterior = 2.4999793260120653e-20
# at	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 4.051500783862523e-17	posterior = 3.7499689890180986e-20
# be	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.5295510307026234e-16	posterior = 1.4157146297741244e-19
# by	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.3505002612875076e-17	posterior = 1.2499896630060327e-20
# do	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 6.75250130643754e-17	posterior = 6.249948315030165e-20
# go	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.3505002612875076e-17	posterior = 1.2499896630060327e-20
# he	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.0804002090300061e-16	posterior = 9.999917304048261e-20
# if	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 5.4020010451500304e-17	posterior = 4.9999586520241307e-20
# in	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.3505002612875076e-17	posterior = 1.2499896630060327e-20
# is	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 9.472346484554319e-17	posterior = 8.767369788448893e-20
# it	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 5.4020010451500304e-17	posterior = 4.9999586520241307e-20
# me	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 4.3790191944988813e-17	posterior = 4.053111934987849e-20
# my	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 3.6882402127730726e-15	posterior = 3.413743982732954e-18
# no	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.7355303588011164e-15	posterior = 2.5319392889866516e-18
# of	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.7010005225750152e-17	posterior = 2.4999793260120653e-20
# on	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 5.25637587708465e-17	posterior = 4.86517159572123e-20
# or	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 4.051500783862523e-17	posterior = 3.7499689890180986e-20
# so	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.9414304933345334e-16	posterior = 2.7225153645017755e-19
# to	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.9365498639224793e-16	posterior = 2.717997974547171e-19
# up	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.4752015016928857e-17	posterior = 1.3654100490207292e-20
# us	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 1.1258116723445703e-17	posterior = 1.0420234584631878e-20
# we	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 2.0186967917902647e-17	posterior = 1.8684558565546824e-20
# III	wish	you	where	here 	likelihood = 0.0009255752840909097	prior = 0.0	posterior = 0.0
# I	is	you	where	here 	likelihood = 0.0019393005952380966	prior = 2.2199284669522774e-15	posterior = 4.3051085973465466e-18
# I	His	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.037179693576064e-16	posterior = 2.0114031971209276e-19
# I	Tis	you	where	here 	likelihood = 0.0019393005952380966	prior = 3.639226995003733e-18	posterior = 7.05755507761729e-21
# I	his	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.9797394852820314e-15	posterior = 3.839309962223806e-18
# I	was	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.1707214022560863e-14	posterior = 2.2703807122532072e-17
# I	win	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.8196134975018665e-18	posterior = 3.528777538808645e-21
# I	Miss	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.0772111905211053e-15	posterior = 2.0890363029747183e-18
# I	Nash	you	where	here 	likelihood = 0.0019393005952380966	prior = 2.365497546752427e-17	posterior = 4.587410800451239e-20
# I	With	you	where	here 	likelihood = 0.0019393005952380966	prior = 5.852167798912533e-16	posterior = 1.1349112495864298e-18
# I	fish	you	where	here 	likelihood = 0.0019393005952380966	prior = 3.639226995003733e-18	posterior = 7.05755507761729e-21
# I	high	you	where	here 	likelihood = 0.0019393005952380966	prior = 3.2753042955033604e-17	posterior = 6.351799569855561e-20
# I	miss	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.2737294482513067e-17	posterior = 2.4701442771660515e-20
# I	rich	you	where	here 	likelihood = 0.0019393005952380966	prior = 2.5474588965026134e-17	posterior = 4.940288554332103e-20
# I	sigh	you	where	here 	likelihood = 0.0019393005952380966	prior = 3.457265645253547e-17	posterior = 6.704677323736425e-20
# I	wife	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.2373371783012696e-16	posterior = 2.399568726389879e-19
# I	will	you	where	here 	likelihood = 0.0019393005952380966	prior = 7.818164392759399e-14	posterior = 1.5161770860547593e-16
# I	wine	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.0917680985011202e-17	posterior = 2.1172665232851873e-20
# I	with	you	where	here 	likelihood = 0.0019393005952380966	prior = 1.75565033967376e-14	posterior = 3.404733748759289e-17
# I	which	you	where	here 	likelihood = 0.0019393005952380966	prior = 3.5113006793475197e-15	posterior = 6.8094674975185775e-18
# I	wished	you	where	here 	likelihood = 0.0019393005952380966	prior = 2.0717592826766134e-15	posterior = 4.017764010084809e-18
# I	wishes	you	where	here 	likelihood = 0.0019393005952380966	prior = 3.6392269950037337e-17	posterior = 7.05755507761729e-20
# I	wish	No	where	here 	likelihood = 0.0011006841216216225	prior = 6.886957147506489e-16	posterior = 7.580364378548934e-19
# I	wish	To	where	here 	likelihood = 0.0011006841216216225	prior = 3.0608698433362174e-16	posterior = 3.3690508349106377e-19
# I	wish	do	where	here 	likelihood = 0.0011006841216216225	prior = 3.1701866234553675e-15	posterior = 3.489374079014588e-18
# I	wish	go	where	here 	likelihood = 0.0011006841216216225	prior = 7.050932317685214e-16	posterior = 7.760849244704861e-19
# I	wish	no	where	here 	likelihood = 0.0011006841216216225	prior = 4.152113053328443e-14	posterior = 4.57016490897649e-17
# I	wish	of	where	here 	likelihood = 0.0011006841216216225	prior = 2.6400002398774873e-13	posterior = 2.905806345110425e-16
# I	wish	on	where	here 	likelihood = 0.0011006841216216225	prior = 2.200000199897906e-14	posterior = 2.4215052875920207e-17
# I	wish	or	where	here 	likelihood = 0.0011006841216216225	prior = 2.6782611129191905e-15	posterior = 2.9479194805468084e-18
# I	wish	so	where	here 	likelihood = 0.0011006841216216225	prior = 5.050435241504758e-15	posterior = 5.5589338776025515e-18
# I	wish	to	where	here 	likelihood = 0.0011006841216216225	prior = 8.705978893892888e-13	posterior = 9.582532731680878e-16
# I	wish	For	where	here 	likelihood = 0.0011006841216216225	prior = 1.421118141548958e-16	posterior = 1.5642021733513674e-19
# I	wish	How	where	here 	likelihood = 0.0011006841216216225	prior = 5.903106126434133e-16	posterior = 6.497455181613372e-19
# I	wish	Not	where	here 	likelihood = 0.0011006841216216225	prior = 2.131677212323437e-16	posterior = 2.346303260027051e-19
# I	wish	Now	where	here 	likelihood = 0.0011006841216216225	prior = 1.9677020421447107e-16	posterior = 2.1658183938711236e-19
# I	wish	You	where	here 	likelihood = 0.0011006841216216225	prior = 1.6561492188051316e-15	posterior = 1.8228971481748624e-18
# I	wish	boy	where	here 	likelihood = 0.0011006841216216225	prior = 7.10559070774479e-17	posterior = 7.821010866756837e-20
# I	wish	cow	where	here 	likelihood = 0.0011006841216216225	prior = 1.6397517017872595e-17	posterior = 1.8048486615592703e-20
# I	wish	for	where	here 	likelihood = 0.0011006841216216225	prior = 1.9800001799081152e-13	posterior = 2.1793547588328183e-16
# I	wish	got	where	here 	likelihood = 0.0011006841216216225	prior = 1.9677020421447107e-16	posterior = 2.1658183938711236e-19
# I	wish	how	where	here 	likelihood = 0.0011006841216216225	prior = 1.4375156585668304e-15	posterior = 1.5822506599669598e-18
# I	wish	joy	where	here 	likelihood = 0.0011006841216216225	prior = 9.838510210723554e-17	posterior = 1.0829091969355618e-19
# I	wish	nor	where	here 	likelihood = 0.0011006841216216225	prior = 3.4434785737532443e-16	posterior = 3.790182189274467e-19
# I	wish	not	where	here 	likelihood = 0.0011006841216216225	prior = 1.1483727751516771e-14	posterior = 1.2639956793120087e-17
# I	wish	now	where	here 	likelihood = 0.0011006841216216225	prior = 2.200000199897906e-14	posterior = 2.4215052875920207e-17
# I	wish	our	where	here 	likelihood = 0.0011006841216216225	prior = 2.3031252092681206e-13	posterior = 2.535013347947897e-16
# I	wish	out	where	here 	likelihood = 0.0011006841216216225	prior = 1.1587578692629967e-15	posterior = 1.2754263875018844e-18
# I	wish	son	where	here 	likelihood = 0.0011006841216216225	prior = 2.5142859427404635e-16	posterior = 2.76743461439088e-19
# I	wish	too	where	here 	likelihood = 0.0011006841216216225	prior = 1.3828572685072553e-15	posterior = 1.5220890379149845e-18
# I	wish	yes	where	here 	likelihood = 0.0011006841216216225	prior = 2.0223604322042866e-16	posterior = 2.2259800159231e-19
# I	wish	yet	where	here 	likelihood = 0.0011006841216216225	prior = 5.793789346314984e-16	posterior = 6.377131937509422e-19
# I	wish	Your	where	here 	likelihood = 0.0011006841216216225	prior = 1.4757765316085334e-16	posterior = 1.624363795403343e-19
# I	wish	four	where	here 	likelihood = 0.0011006841216216225	prior = 1.5850933117276838e-16	posterior = 1.7446870395072942e-19
# I	wish	hour	where	here 	likelihood = 0.0011006841216216225	prior = 4.536646374944751e-16	posterior = 4.993414630313982e-19
# I	wish	your	where	here 	likelihood = 0.0011006841216216225	prior = 2.3031252092681206e-13	posterior = 2.535013347947897e-16
# I	wish	_you_	where	here 	likelihood = 0.0011006841216216225	prior = 8.198758508936296e-17	posterior = 9.02424330779635e-20
# I	wish	young	where	here 	likelihood = 0.0011006841216216225	prior = 1.0385094111319309e-15	posterior = 1.1430708189875378e-18
# I	wish	youth	where	here 	likelihood = 0.0011006841216216225	prior = 6.012422906553284e-17	posterior = 6.617778425717324e-20
# I	wish	you	her	here 	likelihood = 0.0023956066176470604	prior = 2.8940159690366134e-10	posterior = 6.932923807000381e-13
# I	wish	you	here	here 	likelihood = 0.0023956066176470604	prior = 4.745735466421492e-12	posterior = 1.1368915288961685e-14
# I	wish	you	hers	here 	likelihood = 0.0023956066176470604	prior = 7.13644431040826e-13	posterior = 1.7096113216483741e-15
# I	wish	you	were	here 	likelihood = 0.0023956066176470604	prior = 2.3269044616873836e-07	posterior = 5.574347727050767e-10 <----
# I	wish	you	when	here 	likelihood = 0.0023956066176470604	prior = 1.1132853124236885e-11	posterior = 2.6669936617714632e-14
# I	wish	you	There	here 	likelihood = 0.0023956066176470604	prior = 4.603006580213327e-12	posterior = 1.1026993024632011e-14
# I	wish	you	These	here 	likelihood = 0.0023956066176470604	prior = 6.422799879367433e-13	posterior = 1.5386501894835365e-15
# I	wish	you	Where	here 	likelihood = 0.0023956066176470604	prior = 5.709155448326608e-13	posterior = 1.3676890573186992e-15
# I	wish	you	_her_	here 	likelihood = 0.0023956066176470604	prior = 6.779622094887847e-13	posterior = 1.6241307555659553e-15
# I	wish	you	cheer	here 	likelihood = 0.0023956066176470604	prior = 1.427288862081652e-13	posterior = 3.419222643296748e-16
# I	wish	you	share	here 	likelihood = 0.0023956066176470604	prior = 5.352333232806195e-13	posterior = 1.2822084912362806e-15
# I	wish	you	there	here 	likelihood = 0.0023956066176470604	prior = 3.4427918057412304e-11	posterior = 8.247574833014764e-14
# I	wish	you	these	here 	likelihood = 0.0023956066176470604	prior = 1.7127466344979825e-12	posterior = 4.103067171956098e-15
# I	wish	you	three	here 	likelihood = 0.0023956066176470604	prior = 2.4263910655388083e-12	posterior = 5.812678493604471e-15
# I	wish	you	while	here 	likelihood = 0.0023956066176470604	prior = 4.0320910353806666e-12	posterior = 9.659303967313312e-15
# I	wish	you	whole	here 	likelihood = 0.0023956066176470604	prior = 2.711848837955139e-12	posterior = 6.496523022263821e-15
# I	wish	you	whose	here 	likelihood = 0.0023956066176470604	prior = 1.3916066405296106e-12	posterior = 3.333742077214329e-15
# I	wish	you	where	he 	likelihood = 0.0010442387820512827	prior = 3.932796273274452e-09	posterior = 4.106778390459938e-12
# I	wish	you	where	Her 	likelihood = 0.0010442387820512827	prior = 7.593124784592187e-12	posterior = 7.929035377025954e-15
# I	wish	you	where	are 	likelihood = 0.0010442387820512827	prior = 1.3109320910914838e-09	posterior = 1.3689261301533123e-12
# I	wish	you	where	her 	likelihood = 0.0010442387820512827	prior = 2.0544579672856812e-10	posterior = 2.145344685533954e-13
# I	wish	you	where	see 	likelihood = 0.0010442387820512827	prior = 1.8982811961480467e-11	posterior = 1.9822588442564885e-14
# I	wish	you	where	bore 	likelihood = 0.0010442387820512827	prior = 6.039985624107421e-13	posterior = 6.30718723172519e-16
# I	wish	you	where	care 	likelihood = 0.0010442387820512827	prior = 4.400560954706835e-12	posterior = 4.595236411685495e-15
# I	wish	you	where	dare 	likelihood = 0.0010442387820512827	prior = 5.090845026033398e-12	posterior = 5.316057809596946e-15
# I	wish	you	where	fire 	likelihood = 0.0010442387820512827	prior = 1.3805681426531248e-12	posterior = 1.4416427958229006e-15
# I	wish	you	where	free 	likelihood = 0.0010442387820512827	prior = 4.314275445791015e-13	posterior = 4.505133736946565e-16
# I	wish	you	where	hard 	likelihood = 0.0010442387820512827	prior = 1.0354261069898435e-12	posterior = 1.0812320968671754e-15
# I	wish	you	where	harm 	likelihood = 0.0010442387820512827	prior = 1.121711615905664e-12	posterior = 1.1713347716061068e-15
# I	wish	you	where	hate 	likelihood = 0.0010442387820512827	prior = 3.451420356632812e-13	posterior = 3.6041069895572516e-16
# I	wish	you	where	have 	likelihood = 0.0010442387820512827	prior = 1.1225744709948221e-10	posterior = 1.172235798353496e-13
# I	wish	you	where	head 	likelihood = 0.0010442387820512827	prior = 3.451420356632812e-12	posterior = 3.604106989557252e-15
# I	wish	you	where	hear 	likelihood = 0.0010442387820512827	prior = 8.62855089158203e-12	posterior = 9.01026747389313e-15
# I	wish	you	where	heir 	likelihood = 0.0010442387820512827	prior = 2.588565267474609e-13	posterior = 2.7030802421679386e-16
# I	wish	you	where	help 	likelihood = 0.0010442387820512827	prior = 3.3651348477169914e-12	posterior = 3.5140043148183197e-15
# I	wish	you	where	hers 	likelihood = 0.0010442387820512827	prior = 1.725710178316406e-12	posterior = 1.802053494778626e-15
# I	wish	you	where	home 	likelihood = 0.0010442387820512827	prior = 1.121711615905664e-11	posterior = 1.1713347716061067e-14
# I	wish	you	where	hope 	likelihood = 0.0010442387820512827	prior = 1.2338827774962302e-11	posterior = 1.2884682487667173e-14
# I	wish	you	where	hurt 	likelihood = 0.0010442387820512827	prior = 6.902840713265624e-13	posterior = 7.208213979114503e-16
# I	wish	you	where	more 	likelihood = 0.0010442387820512827	prior = 4.003647613694062e-11	posterior = 4.180764107886412e-14
# I	wish	you	where	sure 	likelihood = 0.0010442387820512827	prior = 1.760224381882734e-11	posterior = 1.838094564674198e-14
# I	wish	you	where	very 	likelihood = 0.0010442387820512827	prior = 9.931462076210917e-11	posterior = 1.0370817862450991e-13
# I	wish	you	where	were 	likelihood = 0.0010442387820512827	prior = 5.0994735769249797e-11	posterior = 5.325068077070839e-14
# I	wish	you	where	Serle 	likelihood = 0.0010442387820512827	prior = 2.588565267474609e-13	posterior = 2.7030802421679386e-16
# I	wish	you	where	There 	likelihood = 0.0010442387820512827	prior = 1.1130830650140817e-11	posterior = 1.1623245041322134e-14
# I	wish	you	where	These 	likelihood = 0.0010442387820512827	prior = 1.5531391604847652e-12	posterior = 1.621848145300763e-15
# I	wish	you	where	Where 	likelihood = 0.0010442387820512827	prior = 1.3805681426531248e-12	posterior = 1.4416427958229006e-15
# I	wish	you	where	_her_ 	likelihood = 0.0010442387820512827	prior = 1.6394246694005858e-12	posterior = 1.7119508200396945e-15
# I	wish	you	where	cheer 	likelihood = 0.0010442387820512827	prior = 3.451420356632812e-13	posterior = 3.6041069895572516e-16
# I	wish	you	where	heard 	likelihood = 0.0010442387820512827	prior = 1.0354261069898436e-11	posterior = 1.0812320968671754e-14
# I	wish	you	where	heart 	likelihood = 0.0010442387820512827	prior = 5.69484358844414e-12	posterior = 5.946776532769466e-15
# I	wish	you	where	share 	likelihood = 0.0010442387820512827	prior = 1.2942826337373046e-12	posterior = 1.3515401210839693e-15
# I	wish	you	where	there 	likelihood = 0.0010442387820512827	prior = 1.3109320910914838e-09	posterior = 1.3689261301533123e-12
# I	wish	you	where	these 	likelihood = 0.0010442387820512827	prior = 6.554660455457419e-10	posterior = 6.844630650766561e-13
# I	wish	you	where	three 	likelihood = 0.0010442387820512827	prior = 5.867414606275781e-12	posterior = 6.126981882247328e-15
# I	wish	you	where	where 	likelihood = 0.0010442387820512827	prior = 6.126271133023242e-12	posterior = 6.397289906464122e-15
#
# The original sentence was:
# 	I wish you where here
# The right sentence is:
# 	I wish you were here

# %% [markdown]
# As we can see we have many more options, as we let the maximum distance be 2 instead of 1

# %% [markdown]
# ### 3. and what is the effect of  𝛼  ? change it to 0.9, 0.8...

# %%
alphas = [0.9, 0.8, 0.5, 0.1] ##########CHANGE###########
for alpha in alphas:
    alpha = alpha
    likelihoods = []
    for W in CX:
        PXW = 1.0
        #print(X,W)
        for x,w in zip(X,W):
            if w==x:
                pxw = alpha
            else:
                close_to_x = close_words[x] # includes x itself
                pxw = (1-alpha) / (len(close_to_x) - 1) # so we substract 1
            PXW *= pxw
        likelihoods.append(PXW)

    likelihoods = np.array(likelihoods)
    idx_most_likely = likelihoods.argmax()
    print('Sentence with highest likelihood is the written one, X:')
    print('\t'.join(CX[idx_most_likely]), '\t', likelihoods[idx_most_likely])
    print('\n\nLikelihoods\n')
    num_candidates = len(CX)
    for i in range(1,num_candidates): #the 1 is not to print again the likelihood of X as wehave just printed before
        print('\t'.join(CX[i]), '\t', likelihoods[i])


    print('X =', X)
    score = P(X, verbose=True)
    print('P(X) = {}'.format(score))
    for i in range(len(CX)):
        print('\nW = CX[i] = {}'.format(CX[i]))
        score = P(CX[i], verbose=True)
        print('P(W) = {}'.format(score))


    priors = []
    for W in CX:
        priors.append(P(W))
        
    posteriors = np.array(priors)*np.array(likelihoods)
    idx_best_post = np.argmax(posteriors)

    for i in range(num_candidates):
        best = '<----' if i==idx_best_post else ''
        print('\t'.join(CX[i]), '\tlikelihood = {}\tprior = {}\tposterior = {} {}'
            .format(likelihoods[i], priors[i], posteriors[i],best))

    print('\nThe original sentence was:')
    print('\t' + ' '.join(X))
    print('The right sentence is:')
    print('\t' + ' '.join(CX[idx_best_post]))


    for _ in range(len(alphas)):    
        print('\n\n','-'*50, '\n\n')
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
# W = CX[i] = ['an', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'an', 'wish', 'you', 'where', 'here', '</s>']
# P(an | <s>, <s>) = 0.0003352183183461574
# P(wish | <s>, an) = 9.937888198757765e-05
# P(you | an, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.509426730343075e-17
#
# W = CX[i] = ['as', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'as', 'wish', 'you', 'where', 'here', '</s>']
# P(as | <s>, <s>) = 0.00025799793601651185
# P(wish | <s>, as) = 9.937888198757765e-05
# P(you | as, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.7010005225750152e-17
#
# W = CX[i] = ['at', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'at', 'wish', 'you', 'where', 'here', '</s>']
# P(at | <s>, <s>) = 0.0003869969040247678
# P(wish | <s>, at) = 9.937888198757765e-05
# P(you | at, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.051500783862523e-17
#
# W = CX[i] = ['be', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'be', 'wish', 'you', 'where', 'here', '</s>']
# P(be | <s>, <s>) = 0.0014610178919069253
# P(wish | <s>, be) = 9.937888198757765e-05
# P(you | be, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.5295510307026234e-16
#
# W = CX[i] = ['by', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'by', 'wish', 'you', 'where', 'here', '</s>']
# P(by | <s>, <s>) = 0.00012899896800825592
# P(wish | <s>, by) = 9.937888198757765e-05
# P(you | by, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.3505002612875076e-17
#
# W = CX[i] = ['do', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'do', 'wish', 'you', 'where', 'here', '</s>']
# P(do | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, do) = 9.937888198757765e-05
# P(you | do, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 6.75250130643754e-17
#
# W = CX[i] = ['go', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'go', 'wish', 'you', 'where', 'here', '</s>']
# P(go | <s>, <s>) = 0.00012899896800825592
# P(wish | <s>, go) = 9.937888198757765e-05
# P(you | go, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.3505002612875076e-17
#
# W = CX[i] = ['he', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'he', 'wish', 'you', 'where', 'here', '</s>']
# P(he | <s>, <s>) = 0.0010319917440660474
# P(wish | <s>, he) = 9.937888198757765e-05
# P(you | he, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.0804002090300061e-16
#
# W = CX[i] = ['if', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'if', 'wish', 'you', 'where', 'here', '</s>']
# P(if | <s>, <s>) = 0.0005159958720330237
# P(wish | <s>, if) = 9.937888198757765e-05
# P(you | if, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.4020010451500304e-17
#
# W = CX[i] = ['in', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'in', 'wish', 'you', 'where', 'here', '</s>']
# P(in | <s>, <s>) = 0.00012899896800825592
# P(wish | <s>, in) = 9.937888198757765e-05
# P(you | in, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.3505002612875076e-17
#
# W = CX[i] = ['is', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'is', 'wish', 'you', 'where', 'here', '</s>']
# P(is | <s>, <s>) = 0.0009047928061555577
# P(wish | <s>, is) = 9.937888198757765e-05
# P(you | is, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 9.472346484554319e-17
#
# W = CX[i] = ['it', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'it', 'wish', 'you', 'where', 'here', '</s>']
# P(it | <s>, <s>) = 0.0005159958720330237
# P(wish | <s>, it) = 9.937888198757765e-05
# P(you | it, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.4020010451500304e-17
#
# W = CX[i] = ['me', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'me', 'wish', 'you', 'where', 'here', '</s>']
# P(me | <s>, <s>) = 0.0004182812644850283
# P(wish | <s>, me) = 9.937888198757765e-05
# P(you | me, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.3790191944988813e-17
#
# W = CX[i] = ['my', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'my', 'wish', 'you', 'where', 'here', '</s>']
# P(my | <s>, <s>) = 0.001805985552115583
# P(wish | <s>, my) = 0.001938610662358643
# P(you | my, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.6882402127730726e-15
#
# W = CX[i] = ['no', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'no', 'wish', 'you', 'where', 'here', '</s>']
# P(no | <s>, <s>) = 0.003998968008255934
# P(wish | <s>, no) = 0.0006493506493506495
# P(you | no, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.7355303588011164e-15
#
# W = CX[i] = ['of', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'of', 'wish', 'you', 'where', 'here', '</s>']
# P(of | <s>, <s>) = 0.00025799793601651185
# P(wish | <s>, of) = 9.937888198757765e-05
# P(you | of, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.7010005225750152e-17
#
# W = CX[i] = ['on', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'on', 'wish', 'you', 'where', 'here', '</s>']
# P(on | <s>, <s>) = 0.0005020858440715676
# P(wish | <s>, on) = 9.937888198757765e-05
# P(you | on, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.25637587708465e-17
#
# W = CX[i] = ['or', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'or', 'wish', 'you', 'where', 'here', '</s>']
# P(or | <s>, <s>) = 0.0003869969040247678
# P(wish | <s>, or) = 9.937888198757765e-05
# P(you | or, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 4.051500783862523e-17
#
# W = CX[i] = ['so', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'so', 'wish', 'you', 'where', 'here', '</s>']
# P(so | <s>, <s>) = 0.0006449948400412797
# P(wish | <s>, so) = 0.0004329004329004329
# P(you | so, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.9414304933345334e-16
#
# W = CX[i] = ['to', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'to', 'wish', 'you', 'where', 'here', '</s>']
# P(to | <s>, <s>) = 0.0005159958720330237
# P(wish | <s>, to) = 0.0005402276673741077
# P(you | to, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.9365498639224793e-16
#
# W = CX[i] = ['up', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'up', 'wish', 'you', 'where', 'here', '</s>']
# P(up | <s>, <s>) = 0.0001409103550570131
# P(wish | <s>, up) = 9.937888198757765e-05
# P(you | up, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.4752015016928857e-17
#
# W = CX[i] = ['us', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'us', 'wish', 'you', 'where', 'here', '</s>']
# P(us | <s>, <s>) = 0.00010753684991193103
# P(wish | <s>, us) = 9.937888198757765e-05
# P(you | us, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1258116723445703e-17
#
# W = CX[i] = ['we', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'we', 'wish', 'you', 'where', 'here', '</s>']
# P(we | <s>, <s>) = 0.0001928246963938074
# P(wish | <s>, we) = 9.937888198757765e-05
# P(you | we, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.0186967917902647e-17
#
# W = CX[i] = ['III', 'wish', 'you', 'where', 'here']
# ['<s>', '<s>', 'III', 'wish', 'you', 'where', 'here', '</s>']
# P(III | <s>, <s>) = 0.0
# P(wish | <s>, III) = 9.937888198757765e-05
# P(you | III, wish) = 0.04477611940298508
# P(where | wish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 0.0
#
# W = CX[i] = ['I', 'is', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'is', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(is | <s>, I) = 0.0009047928061555577
# P(you | I, is) = 0.0012437192917400576
# P(where | is, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.2199284669522774e-15
#
# W = CX[i] = ['I', 'His', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'His', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(His | <s>, I) = 4.227310651710393e-05
# P(you | I, His) = 0.0012437192917400576
# P(where | His, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.037179693576064e-16
#
# W = CX[i] = ['I', 'Tis', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'Tis', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(Tis | <s>, I) = 1.48326689533698e-06
# P(you | I, Tis) = 0.0012437192917400576
# P(where | Tis, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.639226995003733e-18
#
# W = CX[i] = ['I', 'his', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'his', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(his | <s>, I) = 0.0008068971910633171
# P(you | I, his) = 0.0012437192917400576
# P(where | his, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.9797394852820314e-15
#
# W = CX[i] = ['I', 'was', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'was', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(was | <s>, I) = 0.03538461538461538
# P(you | I, was) = 0.00016771488469601676
# P(where | was, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.1707214022560863e-14
#
# W = CX[i] = ['I', 'win', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'win', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(win | <s>, I) = 7.4163344766849e-07
# P(you | I, win) = 0.0012437192917400576
# P(where | win, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.8196134975018665e-18
#
# W = CX[i] = ['I', 'Miss', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'Miss', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(Miss | <s>, I) = 0.00043904700101974605
# P(you | I, Miss) = 0.0012437192917400576
# P(where | Miss, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.0772111905211053e-15
#
# W = CX[i] = ['I', 'Nash', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'Nash', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(Nash | <s>, I) = 9.64123481969037e-06
# P(you | I, Nash) = 0.0012437192917400576
# P(where | Nash, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.365497546752427e-17
#
# W = CX[i] = ['I', 'With', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'With', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(With | <s>, I) = 2.22490034300547e-05
# P(you | I, With) = 0.013333333333333334
# P(where | With, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 5.852167798912533e-16
#
# W = CX[i] = ['I', 'fish', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'fish', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(fish | <s>, I) = 1.48326689533698e-06
# P(you | I, fish) = 0.0012437192917400576
# P(where | fish, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.639226995003733e-18
#
# W = CX[i] = ['I', 'high', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'high', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(high | <s>, I) = 1.3349402058032818e-05
# P(you | I, high) = 0.0012437192917400576
# P(where | high, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.2753042955033604e-17
#
# W = CX[i] = ['I', 'miss', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'miss', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(miss | <s>, I) = 5.19143413367943e-06
# P(you | I, miss) = 0.0012437192917400576
# P(where | miss, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2737294482513067e-17
#
# W = CX[i] = ['I', 'rich', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'rich', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(rich | <s>, I) = 1.038286826735886e-05
# P(you | I, rich) = 0.0012437192917400576
# P(where | rich, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.5474588965026134e-17
#
# W = CX[i] = ['I', 'sigh', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'sigh', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(sigh | <s>, I) = 1.409103550570131e-05
# P(you | I, sigh) = 0.0012437192917400576
# P(where | sigh, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.457265645253547e-17
#
# W = CX[i] = ['I', 'wife', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wife', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wife | <s>, I) = 5.043107444145732e-05
# P(you | I, wife) = 0.0012437192917400576
# P(where | wife, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.2373371783012696e-16
#
# W = CX[i] = ['I', 'will', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'will', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(will | <s>, I) = 0.027692307692307693
# P(you | I, will) = 0.0014311270125223615
# P(where | will, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 7.818164392759399e-14
#
# W = CX[i] = ['I', 'wine', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wine', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wine | <s>, I) = 4.44980068601094e-06
# P(you | I, wine) = 0.0012437192917400576
# P(where | wine, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.0917680985011202e-17
#
# W = CX[i] = ['I', 'with', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'with', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(with | <s>, I) = 0.0008803189023824974
# P(you | I, with) = 0.010109519797809606
# P(where | with, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 1.75565033967376e-14
#
# W = CX[i] = ['I', 'which', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'which', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(which | <s>, I) = 0.00040938166311300646
# P(you | I, which) = 0.004347826086956522
# P(where | which, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.5113006793475197e-15
#
# W = CX[i] = ['I', 'wished', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wished', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wished | <s>, I) = 0.0001260239445494644
# P(you | I, wished) = 0.008333333333333333
# P(where | wished, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 2.0717592826766134e-15
#
# W = CX[i] = ['I', 'wishes', 'you', 'where', 'here']
# ['<s>', '<s>', 'I', 'wishes', 'you', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wishes | <s>, I) = 1.4832668953369799e-05
# P(you | I, wishes) = 0.0012437192917400576
# P(where | wishes, you) = 0.0002385211687537269
# P(here | you, where) = 9.863724853990915e-05
# P(W) = 3.6392269950037337e-17
#
# W = CX[i] = ['I', 'wish', 'No', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'No', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(No | I, wish) = 9.344581440622973e-05
# P(where | wish, No) = 5.265597478446279e-05
# P(here | No, where) = 9.863724853990915e-05
# P(W) = 6.886957147506489e-16
#
# W = CX[i] = ['I', 'wish', 'To', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'To', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(To | I, wish) = 4.153147306943544e-05
# P(where | wish, To) = 5.265597478446279e-05
# P(here | To, where) = 9.863724853990915e-05
# P(W) = 3.0608698433362174e-16
#
# W = CX[i] = ['I', 'wish', 'do', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'do', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(do | I, wish) = 0.0004301473996477241
# P(where | wish, do) = 5.265597478446279e-05
# P(here | do, where) = 9.863724853990915e-05
# P(W) = 3.1701866234553675e-15
#
# W = CX[i] = ['I', 'wish', 'go', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'go', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(go | I, wish) = 9.567071474923519e-05
# P(where | wish, go) = 5.265597478446279e-05
# P(here | go, where) = 9.863724853990915e-05
# P(W) = 7.050932317685214e-16
#
# W = CX[i] = ['I', 'wish', 'no', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'no', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(no | I, wish) = 0.0004568462037637898
# P(where | wish, no) = 0.0006493506493506495
# P(here | no, where) = 9.863724853990915e-05
# P(W) = 4.152113053328443e-14
#
# W = CX[i] = ['I', 'wish', 'of', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'of', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(of | I, wish) = 0.03582089552238806
# P(where | wish, of) = 5.265597478446279e-05
# P(here | of, where) = 9.863724853990915e-05
# P(W) = 2.6400002398774873e-13
#
# W = CX[i] = ['I', 'wish', 'on', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'on', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(on | I, wish) = 0.0029850746268656717
# P(where | wish, on) = 5.265597478446279e-05
# P(here | on, where) = 9.863724853990915e-05
# P(W) = 2.200000199897906e-14
#
# W = CX[i] = ['I', 'wish', 'or', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'or', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(or | I, wish) = 0.00036340038935756013
# P(where | wish, or) = 5.265597478446279e-05
# P(here | or, where) = 9.863724853990915e-05
# P(W) = 2.6782611129191905e-15
#
# W = CX[i] = ['I', 'wish', 'so', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'so', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(so | I, wish) = 0.0006852693056456846
# P(where | wish, so) = 5.265597478446279e-05
# P(here | so, where) = 9.863724853990915e-05
# P(W) = 5.050435241504758e-15
#
# W = CX[i] = ['I', 'wish', 'to', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'to', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(to | I, wish) = 0.08059701492537313
# P(where | wish, to) = 7.717538105344396e-05
# P(here | to, where) = 9.863724853990915e-05
# P(W) = 8.705978893892888e-13
#
# W = CX[i] = ['I', 'wish', 'For', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'For', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(For | I, wish) = 1.928246963938074e-05
# P(where | wish, For) = 5.265597478446279e-05
# P(here | For, where) = 9.863724853990915e-05
# P(W) = 1.421118141548958e-16
#
# W = CX[i] = ['I', 'wish', 'How', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'How', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(How | I, wish) = 8.009641234819692e-05
# P(where | wish, How) = 5.265597478446279e-05
# P(here | How, where) = 9.863724853990915e-05
# P(W) = 5.903106126434133e-16
#
# W = CX[i] = ['I', 'wish', 'Not', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'Not', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(Not | I, wish) = 2.8923704459071105e-05
# P(where | wish, Not) = 5.265597478446279e-05
# P(here | Not, where) = 9.863724853990915e-05
# P(W) = 2.131677212323437e-16
#
# W = CX[i] = ['I', 'wish', 'Now', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'Now', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(Now | I, wish) = 2.6698804116065635e-05
# P(where | wish, Now) = 5.265597478446279e-05
# P(here | Now, where) = 9.863724853990915e-05
# P(W) = 1.9677020421447107e-16
#
# W = CX[i] = ['I', 'wish', 'You', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'You', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(You | I, wish) = 0.00022471493464355243
# P(where | wish, You) = 5.265597478446279e-05
# P(here | You, where) = 9.863724853990915e-05
# P(W) = 1.6561492188051316e-15
#
# W = CX[i] = ['I', 'wish', 'boy', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'boy', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(boy | I, wish) = 9.64123481969037e-06
# P(where | wish, boy) = 5.265597478446279e-05
# P(here | boy, where) = 9.863724853990915e-05
# P(W) = 7.10559070774479e-17
#
# W = CX[i] = ['I', 'wish', 'cow', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'cow', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(cow | I, wish) = 2.22490034300547e-06
# P(where | wish, cow) = 5.265597478446279e-05
# P(here | cow, where) = 9.863724853990915e-05
# P(W) = 1.6397517017872595e-17
#
# W = CX[i] = ['I', 'wish', 'for', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'for', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(for | I, wish) = 0.026865671641791045
# P(where | wish, for) = 5.265597478446279e-05
# P(here | for, where) = 9.863724853990915e-05
# P(W) = 1.9800001799081152e-13
#
# W = CX[i] = ['I', 'wish', 'got', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'got', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(got | I, wish) = 2.6698804116065635e-05
# P(where | wish, got) = 5.265597478446279e-05
# P(here | got, where) = 9.863724853990915e-05
# P(W) = 1.9677020421447107e-16
#
# W = CX[i] = ['I', 'wish', 'how', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'how', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(how | I, wish) = 0.00019504959673681283
# P(where | wish, how) = 5.265597478446279e-05
# P(here | how, where) = 9.863724853990915e-05
# P(W) = 1.4375156585668304e-15
#
# W = CX[i] = ['I', 'wish', 'joy', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'joy', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(joy | I, wish) = 1.3349402058032818e-05
# P(where | wish, joy) = 5.265597478446279e-05
# P(here | joy, where) = 9.863724853990915e-05
# P(W) = 9.838510210723554e-17
#
# W = CX[i] = ['I', 'wish', 'nor', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'nor', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(nor | I, wish) = 4.672290720311487e-05
# P(where | wish, nor) = 5.265597478446279e-05
# P(here | nor, where) = 9.863724853990915e-05
# P(W) = 3.4434785737532443e-16
#
# W = CX[i] = ['I', 'wish', 'not', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'not', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(not | I, wish) = 0.0015581718735514973
# P(where | wish, not) = 5.265597478446279e-05
# P(here | not, where) = 9.863724853990915e-05
# P(W) = 1.1483727751516771e-14
#
# W = CX[i] = ['I', 'wish', 'now', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'now', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(now | I, wish) = 0.0029850746268656717
# P(where | wish, now) = 5.265597478446279e-05
# P(here | now, where) = 9.863724853990915e-05
# P(W) = 2.200000199897906e-14
#
# W = CX[i] = ['I', 'wish', 'our', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'our', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(our | I, wish) = 0.03125
# P(where | wish, our) = 5.265597478446279e-05
# P(here | our, where) = 9.863724853990915e-05
# P(W) = 2.3031252092681206e-13
#
# W = CX[i] = ['I', 'wish', 'out', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'out', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(out | I, wish) = 0.00015722629090571987
# P(where | wish, out) = 5.265597478446279e-05
# P(here | out, where) = 9.863724853990915e-05
# P(W) = 1.1587578692629967e-15
#
# W = CX[i] = ['I', 'wish', 'son', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'son', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(son | I, wish) = 3.411513859275053e-05
# P(where | wish, son) = 5.265597478446279e-05
# P(here | son, where) = 9.863724853990915e-05
# P(W) = 2.5142859427404635e-16
#
# W = CX[i] = ['I', 'wish', 'too', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'too', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(too | I, wish) = 0.00018763326226012793
# P(where | wish, too) = 5.265597478446279e-05
# P(here | too, where) = 9.863724853990915e-05
# P(W) = 1.3828572685072553e-15
#
# W = CX[i] = ['I', 'wish', 'yes', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'yes', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(yes | I, wish) = 2.744043756373413e-05
# P(where | wish, yes) = 5.265597478446279e-05
# P(here | yes, where) = 9.863724853990915e-05
# P(W) = 2.0223604322042866e-16
#
# W = CX[i] = ['I', 'wish', 'yet', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'yet', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(yet | I, wish) = 7.861314545285994e-05
# P(where | wish, yet) = 5.265597478446279e-05
# P(here | yet, where) = 9.863724853990915e-05
# P(W) = 5.793789346314984e-16
#
# W = CX[i] = ['I', 'wish', 'Your', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'Your', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(Your | I, wish) = 2.002410308704923e-05
# P(where | wish, Your) = 5.265597478446279e-05
# P(here | Your, where) = 9.863724853990915e-05
# P(W) = 1.4757765316085334e-16
#
# W = CX[i] = ['I', 'wish', 'four', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'four', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(four | I, wish) = 2.150736998238621e-05
# P(where | wish, four) = 5.265597478446279e-05
# P(here | four, where) = 9.863724853990915e-05
# P(W) = 1.5850933117276838e-16
#
# W = CX[i] = ['I', 'wish', 'hour', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'hour', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(hour | I, wish) = 6.155557615648467e-05
# P(where | wish, hour) = 5.265597478446279e-05
# P(here | hour, where) = 9.863724853990915e-05
# P(W) = 4.536646374944751e-16
#
# W = CX[i] = ['I', 'wish', 'your', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'your', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(your | I, wish) = 0.03125
# P(where | wish, your) = 5.265597478446279e-05
# P(here | your, where) = 9.863724853990915e-05
# P(W) = 2.3031252092681206e-13
#
# W = CX[i] = ['I', 'wish', '_you_', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', '_you_', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(_you_ | I, wish) = 1.112450171502735e-05
# P(where | wish, _you_) = 5.265597478446279e-05
# P(here | _you_, where) = 9.863724853990915e-05
# P(W) = 8.198758508936296e-17
#
# W = CX[i] = ['I', 'wish', 'young', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'young', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(young | I, wish) = 0.0001409103550570131
# P(where | wish, young) = 5.265597478446279e-05
# P(here | young, where) = 9.863724853990915e-05
# P(W) = 1.0385094111319309e-15
#
# W = CX[i] = ['I', 'wish', 'youth', 'where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'youth', 'where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(youth | I, wish) = 8.15796792435339e-06
# P(where | wish, youth) = 5.265597478446279e-05
# P(here | youth, where) = 9.863724853990915e-05
# P(W) = 6.012422906553284e-17
#
# W = CX[i] = ['I', 'wish', 'you', 'her', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'her', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(her | wish, you) = 0.0017658292388986745
# P(here | you, her) = 0.0003359932801343974
# P(W) = 2.8940159690366134e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'here', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'here', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(here | wish, you) = 9.863724853990915e-05
# P(here | you, here) = 9.863724853990915e-05
# P(W) = 4.745735466421492e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'hers', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'hers', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(hers | wish, you) = 1.4832668953369799e-05
# P(here | you, hers) = 9.863724853990915e-05
# P(W) = 7.13644431040826e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'were', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'were', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(were | wish, you) = 0.010256410256410256
# P(here | you, were) = 0.046511627906976744
# P(W) = 2.3269044616873836e-07
#
# W = CX[i] = ['I', 'wish', 'you', 'when', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'when', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(when | wish, you) = 0.00023138963567256884
# P(here | you, when) = 9.863724853990915e-05
# P(W) = 1.1132853124236885e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'There', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'There', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(There | wish, you) = 9.567071474923519e-05
# P(here | you, There) = 9.863724853990915e-05
# P(W) = 4.603006580213327e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'These', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'These', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(These | wish, you) = 1.3349402058032818e-05
# P(here | you, These) = 9.863724853990915e-05
# P(W) = 6.422799879367433e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'Where', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'Where', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(Where | wish, you) = 1.186613516269584e-05
# P(here | you, Where) = 9.863724853990915e-05
# P(W) = 5.709155448326608e-13
#
# W = CX[i] = ['I', 'wish', 'you', '_her_', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', '_her_', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(_her_ | wish, you) = 1.409103550570131e-05
# P(here | you, _her_) = 9.863724853990915e-05
# P(W) = 6.779622094887847e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'cheer', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'cheer', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(cheer | wish, you) = 2.96653379067396e-06
# P(here | you, cheer) = 9.863724853990915e-05
# P(W) = 1.427288862081652e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'share', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'share', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(share | wish, you) = 1.112450171502735e-05
# P(here | you, share) = 9.863724853990915e-05
# P(W) = 5.352333232806195e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'there', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'there', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(there | wish, you) = 0.0007155635062611808
# P(here | you, there) = 9.863724853990915e-05
# P(W) = 3.4427918057412304e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'these', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'these', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(these | wish, you) = 3.559840548808752e-05
# P(here | you, these) = 9.863724853990915e-05
# P(W) = 1.7127466344979825e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'three', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'three', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(three | wish, you) = 5.043107444145732e-05
# P(here | you, three) = 9.863724853990915e-05
# P(W) = 2.4263910655388083e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'while', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'while', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(while | wish, you) = 8.380457958653935e-05
# P(here | you, while) = 9.863724853990915e-05
# P(W) = 4.0320910353806666e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'whole', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'whole', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(whole | wish, you) = 5.636414202280524e-05
# P(here | you, whole) = 9.863724853990915e-05
# P(W) = 2.711848837955139e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'whose', 'here']
# ['<s>', '<s>', 'I', 'wish', 'you', 'whose', 'here', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(whose | wish, you) = 2.8923704459071105e-05
# P(here | you, whose) = 9.863724853990915e-05
# P(W) = 1.3916066405296106e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'he']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'he', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(he | you, where) = 0.033802816901408454
# P(W) = 3.932796273274452e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Her']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Her', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Her | you, where) = 6.526374339482712e-05
# P(W) = 7.593124784592187e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'are']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'are', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(are | you, where) = 0.011267605633802818
# P(W) = 1.3109320910914838e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'her']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'her', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(her | you, where) = 0.0017658292388986745
# P(W) = 2.0544579672856812e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'see']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'see', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(see | you, where) = 0.0001631593584870678
# P(W) = 1.8982811961480467e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'bore']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'bore', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(bore | you, where) = 5.19143413367943e-06
# P(W) = 6.039985624107421e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'care']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'care', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(care | you, where) = 3.782330583109299e-05
# P(W) = 4.400560954706835e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'dare']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'dare', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(dare | you, where) = 4.375637341244091e-05
# P(W) = 5.090845026033398e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'fire']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'fire', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(fire | you, where) = 1.186613516269584e-05
# P(W) = 1.3805681426531248e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'free']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'free', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(free | you, where) = 3.7081672383424498e-06
# P(W) = 4.314275445791015e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hard']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hard', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hard | you, where) = 8.89960137202188e-06
# P(W) = 1.0354261069898435e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'harm']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'harm', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(harm | you, where) = 9.64123481969037e-06
# P(W) = 1.121711615905664e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hate']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hate', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hate | you, where) = 2.96653379067396e-06
# P(W) = 3.451420356632812e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'have']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'have', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(have | you, where) = 0.0009648651154167054
# P(W) = 1.1225744709948221e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'head']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'head', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(head | you, where) = 2.9665337906739598e-05
# P(W) = 3.451420356632812e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hear']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hear', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hear | you, where) = 7.4163344766849e-05
# P(W) = 8.62855089158203e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'heir']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'heir', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(heir | you, where) = 2.22490034300547e-06
# P(W) = 2.588565267474609e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'help']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'help', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(help | you, where) = 2.8923704459071105e-05
# P(W) = 3.3651348477169914e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hers']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hers', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hers | you, where) = 1.4832668953369799e-05
# P(W) = 1.725710178316406e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'home']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'home', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(home | you, where) = 9.64123481969037e-05
# P(W) = 1.121711615905664e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hope']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hope', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hope | you, where) = 0.00010605358301659406
# P(W) = 1.2338827774962302e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'hurt']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'hurt', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(hurt | you, where) = 5.93306758134792e-06
# P(W) = 6.902840713265624e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'more']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'more', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(more | you, where) = 0.00034411791971817934
# P(W) = 4.003647613694062e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'sure']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'sure', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(sure | you, where) = 0.00015129322332437195
# P(W) = 1.760224381882734e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'very']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'very', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(very | you, where) = 0.0008536200982664319
# P(W) = 9.931462076210917e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'were']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'were', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(were | you, where) = 0.00043830536757207754
# P(W) = 5.0994735769249797e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Serle']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Serle', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Serle | you, where) = 2.22490034300547e-06
# P(W) = 2.588565267474609e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'There']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'There', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(There | you, where) = 9.567071474923519e-05
# P(W) = 1.1130830650140817e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'These']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'These', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(These | you, where) = 1.3349402058032818e-05
# P(W) = 1.5531391604847652e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'Where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'Where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(Where | you, where) = 1.186613516269584e-05
# P(W) = 1.3805681426531248e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', '_her_']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', '_her_', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(_her_ | you, where) = 1.409103550570131e-05
# P(W) = 1.6394246694005858e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'cheer']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'cheer', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(cheer | you, where) = 2.96653379067396e-06
# P(W) = 3.451420356632812e-13
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'heard']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'heard', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(heard | you, where) = 8.89960137202188e-05
# P(W) = 1.0354261069898436e-11
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'heart']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'heart', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(heart | you, where) = 4.894780754612034e-05
# P(W) = 5.69484358844414e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'share']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'share', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(share | you, where) = 1.112450171502735e-05
# P(W) = 1.2942826337373046e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'there']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'there', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(there | you, where) = 0.011267605633802818
# P(W) = 1.3109320910914838e-09
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'these']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'these', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(these | you, where) = 0.005633802816901409
# P(W) = 6.554660455457419e-10
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'three']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'three', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(three | you, where) = 5.043107444145732e-05
# P(W) = 5.867414606275781e-12
#
# W = CX[i] = ['I', 'wish', 'you', 'where', 'where']
# ['<s>', '<s>', 'I', 'wish', 'you', 'where', 'where', '</s>']
# P(I | <s>, <s>) = 0.08384932920536636
# P(wish | <s>, I) = 0.016923076923076923
# P(you | I, wish) = 0.34375
# P(where | wish, you) = 0.0002385211687537269
# P(where | you, where) = 5.265597478446279e-05
# P(W) = 6.126271133023242e-12
# I	wish	you	where	here 	likelihood = 0.32768000000000014	prior = 1.1475972685804098e-11	posterior = 3.7604467296842886e-12
# A	wish	you	where	here 	likelihood = 0.0018618181818181815	prior = 1.2559652429973822e-15	posterior = 2.3383789251442165e-18
# a	wish	you	where	here 	likelihood = 0.0018618181818181815	prior = 1.8095085058862247e-16	posterior = 3.3689758364136253e-19
# ...
# me	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 4.3790191944988813e-17	posterior = 8.95708471602044e-23
# my	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 3.6882402127730726e-15	posterior = 7.544127707944922e-21
# no	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 2.7355303588011164e-15	posterior = 5.595403006638648e-21
# of	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 2.7010005225750152e-17	posterior = 5.524773796176168e-23
# on	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 5.25637587708465e-17	posterior = 1.0751677930400422e-22
# or	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 4.051500783862523e-17	posterior = 8.287160694264253e-23
# so	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 2.9414304933345334e-16	posterior = 6.0165623727297285e-22
# to	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 2.9365498639224793e-16	posterior = 6.006579267114163e-22
# up	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 1.4752015016928857e-17	posterior = 3.017457617099085e-23
# us	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 1.1258116723445703e-17	posterior = 2.3027966025229848e-23
# we	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 2.0186967917902647e-17	posterior = 4.1291525286619055e-23
# III	wish	you	where	here 	likelihood = 2.0454545454545457e-06	prior = 0.0	posterior = 0.0
# I	is	you	where	here 	likelihood = 4.285714285714286e-06	prior = 2.2199284669522774e-15	posterior = 9.51397914408119e-21
# I	His	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.037179693576064e-16	posterior = 4.445055829611704e-22
# I	Tis	you	where	here 	likelihood = 4.285714285714286e-06	prior = 3.639226995003733e-18	posterior = 1.5596687121444574e-23
# I	his	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.9797394852820314e-15	posterior = 8.48459779406585e-21
# I	was	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.1707214022560863e-14	posterior = 5.0173774382403705e-20
# I	win	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.8196134975018665e-18	posterior = 7.798343560722287e-24
# I	Miss	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.0772111905211053e-15	posterior = 4.616619387947595e-21
# I	Nash	you	where	here 	likelihood = 4.285714285714286e-06	prior = 2.365497546752427e-17	posterior = 1.0137846628938974e-22
# I	With	you	where	here 	likelihood = 4.285714285714286e-06	prior = 5.852167798912533e-16	posterior = 2.5080719138196574e-21
# I	fish	you	where	here 	likelihood = 4.285714285714286e-06	prior = 3.639226995003733e-18	posterior = 1.5596687121444574e-23
# I	high	you	where	here 	likelihood = 4.285714285714286e-06	prior = 3.2753042955033604e-17	posterior = 1.4037018409300117e-22
# I	miss	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.2737294482513067e-17	posterior = 5.4588404925056e-23
# I	rich	you	where	here 	likelihood = 4.285714285714286e-06	prior = 2.5474588965026134e-17	posterior = 1.09176809850112e-22
# I	sigh	you	where	here 	likelihood = 4.285714285714286e-06	prior = 3.457265645253547e-17	posterior = 1.4816852765372346e-22
# I	wife	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.2373371783012696e-16	posterior = 5.302873621291156e-22
# I	will	you	where	here 	likelihood = 4.285714285714286e-06	prior = 7.818164392759399e-14	posterior = 3.350641882611171e-19
# I	wine	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.0917680985011202e-17	posterior = 4.6790061364333733e-23
# I	with	you	where	here 	likelihood = 4.285714285714286e-06	prior = 1.75565033967376e-14	posterior = 7.524215741458973e-20
# I	which	you	where	here 	likelihood = 4.285714285714286e-06	prior = 3.5113006793475197e-15	posterior = 1.5048431482917944e-20
# I	wished	you	where	here 	likelihood = 4.285714285714286e-06	prior = 2.0717592826766134e-15	posterior = 8.878968354328344e-21
# I	wishes	you	where	here 	likelihood = 4.285714285714286e-06	prior = 3.6392269950037337e-17	posterior = 1.5596687121444575e-22
# I	wish	No	where	here 	likelihood = 2.4324324324324337e-06	prior = 6.886957147506489e-16	posterior = 1.6752057926367144e-21
# I	wish	To	where	here 	likelihood = 2.4324324324324337e-06	prior = 3.0608698433362174e-16	posterior = 7.445359078385397e-22
# I	wish	do	where	here 	likelihood = 2.4324324324324337e-06	prior = 3.1701866234553675e-15	posterior = 7.711264759756303e-21
# I	wish	go	where	here 	likelihood = 2.4324324324324337e-06	prior = 7.050932317685214e-16	posterior = 1.7150916448423503e-21
# I	wish	no	where	here 	likelihood = 2.4324324324324337e-06	prior = 4.152113053328443e-14	posterior = 1.0099734454042165e-19
# I	wish	of	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.6400002398774873e-13	posterior = 6.421622205107405e-19
# I	wish	on	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.200000199897906e-14	posterior = 5.351351837589504e-20
# I	wish	or	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.6782611129191905e-15	posterior = 6.5146891935872236e-21
# I	wish	so	where	here 	likelihood = 2.4324324324324337e-06	prior = 5.050435241504758e-15	posterior = 1.2284842479335904e-20
# I	wish	to	where	here 	likelihood = 2.4324324324324337e-06	prior = 8.705978893892888e-13	posterior = 2.1176705417577308e-18
# I	wish	For	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.421118141548958e-16	posterior = 3.4567738578217917e-22
# I	wish	How	where	here 	likelihood = 2.4324324324324337e-06	prior = 5.903106126434133e-16	posterior = 1.4358906794028982e-21
# I	wish	Not	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.131677212323437e-16	posterior = 5.185160786732687e-22
# I	wish	Now	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.9677020421447107e-16	posterior = 4.786302264676326e-22
# I	wish	You	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.6561492188051316e-15	posterior = 4.028471072769241e-21
# I	wish	boy	where	here 	likelihood = 2.4324324324324337e-06	prior = 7.10559070774479e-17	posterior = 1.7283869289108958e-22
# I	wish	cow	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.6397517017872595e-17	posterior = 3.9885852205636064e-23
# I	wish	for	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.9800001799081152e-13	posterior = 4.816216653830553e-19
# I	wish	got	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.9677020421447107e-16	posterior = 4.786302264676326e-22
# I	wish	how	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.4375156585668304e-15	posterior = 3.496659710027427e-21
# I	wish	joy	where	here 	likelihood = 2.4324324324324337e-06	prior = 9.838510210723554e-17	posterior = 2.393151132338163e-22
# I	wish	nor	where	here 	likelihood = 2.4324324324324337e-06	prior = 3.4434785737532443e-16	posterior = 8.376028963183572e-22
# I	wish	not	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.1483727751516771e-14	posterior = 2.793339182801378e-20
# I	wish	now	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.200000199897906e-14	posterior = 5.351351837589504e-20
# I	wish	our	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.3031252092681206e-13	posterior = 5.602196454976513e-19
# I	wish	out	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.1587578692629967e-15	posterior = 2.8186002225316154e-21
# I	wish	son	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.5142859427404635e-16	posterior = 6.11583067153086e-22
# I	wish	too	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.3828572685072553e-15	posterior = 3.363706869341974e-21
# I	wish	yes	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.0223604322042866e-16	posterior = 4.919255105361781e-22
# I	wish	yet	where	here 	likelihood = 2.4324324324324337e-06	prior = 5.793789346314984e-16	posterior = 1.4093001112658077e-21
# I	wish	Your	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.4757765316085334e-16	posterior = 3.5897266985072454e-22
# I	wish	four	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.5850933117276838e-16	posterior = 3.855632379878152e-22
# I	wish	hour	where	here 	likelihood = 2.4324324324324337e-06	prior = 4.536646374944751e-16	posterior = 1.1035085776892644e-21
# I	wish	your	where	here 	likelihood = 2.4324324324324337e-06	prior = 2.3031252092681206e-13	posterior = 5.602196454976513e-19
# I	wish	_you_	where	here 	likelihood = 2.4324324324324337e-06	prior = 8.198758508936296e-17	posterior = 1.9942926102818028e-22
# I	wish	young	where	here 	likelihood = 2.4324324324324337e-06	prior = 1.0385094111319309e-15	posterior = 2.526103973023617e-21
# I	wish	youth	where	here 	likelihood = 2.4324324324324337e-06	prior = 6.012422906553284e-17	posterior = 1.4624812475399889e-22
# I	wish	you	her	here 	likelihood = 5.294117647058825e-06	prior = 2.8940159690366134e-10	posterior = 1.532126101254678e-15
# I	wish	you	here	here 	likelihood = 5.294117647058825e-06	prior = 4.745735466421492e-12	posterior = 2.5124481881054963e-17
# I	wish	you	hers	here 	likelihood = 5.294117647058825e-06	prior = 7.13644431040826e-13	posterior = 3.778117576098492e-18
# I	wish	you	were	here 	likelihood = 5.294117647058825e-06	prior = 2.3269044616873836e-07	posterior = 1.2318905973639093e-12 <----
# I	wish	you	when	here 	likelihood = 5.294117647058825e-06	prior = 1.1132853124236885e-11	posterior = 5.893863418713646e-17
# I	wish	you	There	here 	likelihood = 5.294117647058825e-06	prior = 4.603006580213327e-12	posterior = 2.4368858365835267e-17
# I	wish	you	These	here 	likelihood = 5.294117647058825e-06	prior = 6.422799879367433e-13	posterior = 3.400305818488642e-18
# I	wish	you	Where	here 	likelihood = 5.294117647058825e-06	prior = 5.709155448326608e-13	posterior = 3.0224940608787932e-18
# I	wish	you	_her_	here 	likelihood = 5.294117647058825e-06	prior = 6.779622094887847e-13	posterior = 3.589211697293567e-18
# I	wish	you	cheer	here 	likelihood = 5.294117647058825e-06	prior = 1.427288862081652e-13	posterior = 7.556235152196983e-19
# I	wish	you	share	here 	likelihood = 5.294117647058825e-06	prior = 5.352333232806195e-13	posterior = 2.8335881820738688e-18
# I	wish	you	there	here 	likelihood = 5.294117647058825e-06	prior = 3.4427918057412304e-11	posterior = 1.8226544853924164e-16
# I	wish	you	these	here 	likelihood = 5.294117647058825e-06	prior = 1.7127466344979825e-12	posterior = 9.06748218263638e-18
# I	wish	you	three	here 	likelihood = 5.294117647058825e-06	prior = 2.4263910655388083e-12	posterior = 1.284559975873487e-17
# I	wish	you	while	here 	likelihood = 5.294117647058825e-06	prior = 4.0320910353806666e-12	posterior = 2.1346364304956476e-17
# I	wish	you	whole	here 	likelihood = 5.294117647058825e-06	prior = 2.711848837955139e-12	posterior = 1.4356846789174268e-17
# I	wish	you	whose	here 	likelihood = 5.294117647058825e-06	prior = 1.3916066405296106e-12	posterior = 7.367329273392058e-18
# I	wish	you	where	he 	likelihood = 2.3076923076923085e-06	prior = 3.932796273274452e-09	posterior = 9.075683707556431e-15
# I	wish	you	where	Her 	likelihood = 2.3076923076923085e-06	prior = 7.593124784592187e-12	posterior = 1.7522595656751205e-17
# I	wish	you	where	are 	likelihood = 2.3076923076923085e-06	prior = 1.3109320910914838e-09	posterior = 3.0252279025188096e-15
# I	wish	you	where	her 	likelihood = 2.3076923076923085e-06	prior = 2.0544579672856812e-10	posterior = 4.741056847582343e-16
# I	wish	you	where	see 	likelihood = 2.3076923076923085e-06	prior = 1.8982811961480467e-11	posterior = 4.3806489141878014e-17
# I	wish	you	where	bore 	likelihood = 2.3076923076923085e-06	prior = 6.039985624107421e-13	posterior = 1.3938428363324822e-18
# I	wish	you	where	care 	likelihood = 2.3076923076923085e-06	prior = 4.400560954706835e-12	posterior = 1.0155140664708085e-17
# I	wish	you	where	dare 	likelihood = 2.3076923076923085e-06	prior = 5.090845026033398e-12	posterior = 1.1748103906230922e-17
# I	wish	you	where	fire 	likelihood = 2.3076923076923085e-06	prior = 1.3805681426531248e-12	posterior = 3.185926483045674e-18
# I	wish	you	where	free 	likelihood = 2.3076923076923085e-06	prior = 4.314275445791015e-13	posterior = 9.95602025951773e-19
# I	wish	you	where	hard 	likelihood = 2.3076923076923085e-06	prior = 1.0354261069898435e-12	posterior = 2.389444862284255e-18
# I	wish	you	where	harm 	likelihood = 2.3076923076923085e-06	prior = 1.121711615905664e-12	posterior = 2.58856526747461e-18
# I	wish	you	where	hate 	likelihood = 2.3076923076923085e-06	prior = 3.451420356632812e-13	posterior = 7.964816207614185e-19
# I	wish	you	where	have 	likelihood = 2.3076923076923085e-06	prior = 1.1225744709948221e-10	posterior = 2.5905564715265134e-16
# I	wish	you	where	head 	likelihood = 2.3076923076923085e-06	prior = 3.451420356632812e-12	posterior = 7.964816207614184e-18
# I	wish	you	where	hear 	likelihood = 2.3076923076923085e-06	prior = 8.62855089158203e-12	posterior = 1.9912040519035463e-17
# I	wish	you	where	heir 	likelihood = 2.3076923076923085e-06	prior = 2.588565267474609e-13	posterior = 5.973612155710638e-19
# I	wish	you	where	help 	likelihood = 2.3076923076923085e-06	prior = 3.3651348477169914e-12	posterior = 7.765695802423829e-18
# I	wish	you	where	hers 	likelihood = 2.3076923076923085e-06	prior = 1.725710178316406e-12	posterior = 3.982408103807092e-18
# I	wish	you	where	home 	likelihood = 2.3076923076923085e-06	prior = 1.121711615905664e-11	posterior = 2.58856526747461e-17
# I	wish	you	where	hope 	likelihood = 2.3076923076923085e-06	prior = 1.2338827774962302e-11	posterior = 2.847421794222071e-17
# I	wish	you	where	hurt 	likelihood = 2.3076923076923085e-06	prior = 6.902840713265624e-13	posterior = 1.592963241522837e-18
# I	wish	you	where	more 	likelihood = 2.3076923076923085e-06	prior = 4.003647613694062e-11	posterior = 9.239186800832454e-17
# I	wish	you	where	sure 	likelihood = 2.3076923076923085e-06	prior = 1.760224381882734e-11	posterior = 4.062056265883234e-17
# I	wish	you	where	very 	likelihood = 2.3076923076923085e-06	prior = 9.931462076210917e-11	posterior = 2.2918758637409815e-16
# I	wish	you	where	were 	likelihood = 2.3076923076923085e-06	prior = 5.0994735769249797e-11	posterior = 1.1768015946749958e-16
# I	wish	you	where	Serle 	likelihood = 2.3076923076923085e-06	prior = 2.588565267474609e-13	posterior = 5.973612155710638e-19
# I	wish	you	where	There 	likelihood = 2.3076923076923085e-06	prior = 1.1130830650140817e-11	posterior = 2.568653226955574e-17
# I	wish	you	where	These 	likelihood = 2.3076923076923085e-06	prior = 1.5531391604847652e-12	posterior = 3.584167293426382e-18
# I	wish	you	where	Where 	likelihood = 2.3076923076923085e-06	prior = 1.3805681426531248e-12	posterior = 3.185926483045674e-18
# I	wish	you	where	_her_ 	likelihood = 2.3076923076923085e-06	prior = 1.6394246694005858e-12	posterior = 3.7832876986167375e-18
# I	wish	you	where	cheer 	likelihood = 2.3076923076923085e-06	prior = 3.451420356632812e-13	posterior = 7.964816207614185e-19
# I	wish	you	where	heard 	likelihood = 2.3076923076923085e-06	prior = 1.0354261069898436e-11	posterior = 2.3894448622842554e-17
# I	wish	you	where	heart 	likelihood = 2.3076923076923085e-06	prior = 5.69484358844414e-12	posterior = 1.3141946742563406e-17
# I	wish	you	where	share 	likelihood = 2.3076923076923085e-06	prior = 1.2942826337373046e-12	posterior = 2.9868060778553193e-18
# I	wish	you	where	there 	likelihood = 2.3076923076923085e-06	prior = 1.3109320910914838e-09	posterior = 3.0252279025188096e-15
# I	wish	you	where	these 	likelihood = 2.3076923076923085e-06	prior = 6.554660455457419e-10	posterior = 1.5126139512594048e-15
# I	wish	you	where	three 	likelihood = 2.3076923076923085e-06	prior = 5.867414606275781e-12	posterior = 1.3540187552944114e-17
# I	wish	you	where	where 	likelihood = 2.3076923076923085e-06	prior = 6.126271133023242e-12	posterior = 1.413754876851518e-17
#
# The original sentence was:
# 	I wish you where here
# The right sentence is:
# 	I wish you were here
#
#
#  --------------------------------------------------
#
#
#
#
#  --------------------------------------------------
#
#
#
#
#  --------------------------------------------------
#
#
#
#
#  --------------------------------------------------

# %% [markdown]
# ###4. make a long (>20) list of sentences each with 1 or 2 mispelled words to assess the speller : does it really work ?

# %%
sentences = [
    "The qucik brown fox jumps over the lazy dog.",
    "She gaev her all to the project.",
    "The sun also raser.",
    "He was born in Decembr.",
    "I would like two scoops of ice creem please.",
    "The boook on the shelf is red.",
    "The train arived at the staion late.",
    "I love going to the beech in summer.",
    "They're going to the movies tonigth.",
    "I can't believe it's already Aprill.",
    "I enjoy reding mystery novels.",
    "She has a pet cat named Whiskerrs.",
    "My favorit color is bleu.",
    "He plays the guita very well.",
    "The cake smeels delicious.",
    "I'm excited to see the balet tonigt.",
    "This sandwich is really tastey.",
    "I'm going to take a shower before bedd.",
    "The golfer hit the ball into the water hazad.",
    "I need to buy more tolitepaper."
]

for test_sentence in sentences:
    print(f"Original sentence: {test_sentence}")
    test_sentence = test_sentence[:-1].lower()  # Remove the period at the end and convert to lowercase
    X = test_sentence.split(' ')

    # Check if all words belong to the vocabulary
    for x in X:
        if x not in vocabulary:
            print(f"{x} doesn't belong to the vocabulary, skipping the sentence.")
            continue

    CX = [X]  # no errors
    for i in range(len(X)):  # one misspelled word at a time
        if X[i] in vocabulary:
            for cw in close_words[X[i]]:
                if cw != X[i]:
                    C = X.copy()
                    C[i] = cw
                    CX.append(C)
        else:
            pass  # let it be as it is

    likelihoods = []
    for W in CX:
        PXW = 1.0
        for x, w in zip(X, W):
            if w == x:
                pxw = alpha
            else:
                close_to_x = close_words[x]  # includes x itself
                pxw = (1 - alpha) / (len(close_to_x) - 1)  # so we subtract 1
            PXW *= pxw
        likelihoods.append(PXW)

    likelihoods = np.array(likelihoods)
    idx_most_likely = likelihoods.argmax()

    priors = []
    for W in CX:
        priors.append(P(W))

    posteriors = np.array(priors) * np.array(likelihoods)
    idx_best_post = np.argmax(posteriors)

    print(f"The corrected sentence is: {' '.join(CX[idx_best_post])}.")
    print()
# Out:
# Original sentence: The qucik brown fox jumps over the lazy dog.
# qucik doesn't belong to the vocabulary, skipping the sentence.
# brown doesn't belong to the vocabulary, skipping the sentence.
# fox doesn't belong to the vocabulary, skipping the sentence.
# jumps doesn't belong to the vocabulary, skipping the sentence.
# lazy doesn't belong to the vocabulary, skipping the sentence.
# dog doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the qucik brown fox jumps over the lazy dog.
#
# Original sentence: She gaev her all to the project.
# gaev doesn't belong to the vocabulary, skipping the sentence.
# project doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: she gaev her all to the project.
#
# Original sentence: The sun also raser.
# sun doesn't belong to the vocabulary, skipping the sentence.
# also doesn't belong to the vocabulary, skipping the sentence.
# raser doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the sun also raser.
#
# Original sentence: He was born in Decembr.
# decembr doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: he was born in decembr.
#
# Original sentence: I would like two scoops of ice creem please.
# i doesn't belong to the vocabulary, skipping the sentence.
# scoops doesn't belong to the vocabulary, skipping the sentence.
# ice doesn't belong to the vocabulary, skipping the sentence.
# creem doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i would like two scoops of ice creem please.
#
# Original sentence: The boook on the shelf is red.
# boook doesn't belong to the vocabulary, skipping the sentence.
# shelf doesn't belong to the vocabulary, skipping the sentence.
# red doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the boook on the shelf is red.
#
# Original sentence: The train arived at the staion late.
# arived doesn't belong to the vocabulary, skipping the sentence.
# staion doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the train arived at the staion late.
#
# Original sentence: I love going to the beech in summer.
# i doesn't belong to the vocabulary, skipping the sentence.
# beech doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i love going to the beech in summer.
#
# Original sentence: They're going to the movies tonigth.
# they're doesn't belong to the vocabulary, skipping the sentence.
# movies doesn't belong to the vocabulary, skipping the sentence.
# tonigth doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: they're going to the movies tonigth.
#
# Original sentence: I can't believe it's already Aprill.
# i doesn't belong to the vocabulary, skipping the sentence.
# can't doesn't belong to the vocabulary, skipping the sentence.
# it's doesn't belong to the vocabulary, skipping the sentence.
# aprill doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i can't believe it's already aprill.
#
# Original sentence: I enjoy reding mystery novels.
# i doesn't belong to the vocabulary, skipping the sentence.
# enjoy doesn't belong to the vocabulary, skipping the sentence.
# reding doesn't belong to the vocabulary, skipping the sentence.
# mystery doesn't belong to the vocabulary, skipping the sentence.
# novels doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i enjoy reding mystery novels.
#
# Original sentence: She has a pet cat named Whiskerrs.
# pet doesn't belong to the vocabulary, skipping the sentence.
# cat doesn't belong to the vocabulary, skipping the sentence.
# whiskerrs doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: she has a pet cat named whiskerrs.
#
# Original sentence: My favorit color is bleu.
# favorit doesn't belong to the vocabulary, skipping the sentence.
# color doesn't belong to the vocabulary, skipping the sentence.
# bleu doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: my favorit color is bleu.
#
# Original sentence: He plays the guita very well.
# plays doesn't belong to the vocabulary, skipping the sentence.
# guita doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: he plays the guita very well.
#
# Original sentence: The cake smeels delicious.
# smeels doesn't belong to the vocabulary, skipping the sentence.
# delicious doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the cake smeels delicious.
#
# Original sentence: I'm excited to see the balet tonigt.
# i'm doesn't belong to the vocabulary, skipping the sentence.
# excited doesn't belong to the vocabulary, skipping the sentence.
# balet doesn't belong to the vocabulary, skipping the sentence.
# tonigt doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i'm excited to see the balet tonigt.
#
# Original sentence: This sandwich is really tastey.
# sandwich doesn't belong to the vocabulary, skipping the sentence.
# tastey doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: this sandwich is really tastey.
#
# Original sentence: I'm going to take a shower before bedd.
# i'm doesn't belong to the vocabulary, skipping the sentence.
# shower doesn't belong to the vocabulary, skipping the sentence.
# bedd doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i'm going to take a shower before bedd.
#
# Original sentence: The golfer hit the ball into the water hazad.
# golfer doesn't belong to the vocabulary, skipping the sentence.
# hit doesn't belong to the vocabulary, skipping the sentence.
# ball doesn't belong to the vocabulary, skipping the sentence.
# hazad doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the golfer hit the ball into the water hazad.
#
# Original sentence: I need to buy more tolitepaper.
# i doesn't belong to the vocabulary, skipping the sentence.
# buy doesn't belong to the vocabulary, skipping the sentence.
# tolitepaper doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i need to buy more tolitepaper.

# %% [markdown]
# NO IT DOES NOT WORK AS WORDS AREN´T IN THE VOCABULARY AS IT IS AN OLD BOOK

# %% [markdown]
# ### 5. same for a second list of sentences withouth any spelling error (but different from any one in the selected part of the book), are there any errors ?

# %%
correct_sentences = [
    "The weather today is nice and sunny.",
    "She enjoys reading books in her free time.",
    "He went for a long walk in the park.",
    "The cake needs more sugar to taste better.",
    "I prefer tea over coffee in the morning.",
    "Please hand me the blue pen on the table.",
    "The children played happily in the playground.",
    "It is important to get enough sleep every night.",
    "The movie we watched last night was interesting.",
    "She is looking forward to her vacation next month."
]

for test_sentence in correct_sentences:
    print(f"Original sentence: {test_sentence}")
    test_sentence = test_sentence[:-1].lower()  # Remove the period at the end and convert to lowercase
    X = test_sentence.split(' ')

    # Check if all words belong to the vocabulary
    for x in X:
        if x not in vocabulary:
            print(f"{x} doesn't belong to the vocabulary, skipping the sentence.")
            continue

    CX = [X]  # no errors
    for i in range(len(X)):  # one misspelled word at a time
        if X[i] in vocabulary:
            for cw in close_words[X[i]]:
                if cw != X[i]:
                    C = X.copy()
                    C[i] = cw
                    CX.append(C)
        else:
            pass  # let it be as it is

    likelihoods = []
    for W in CX:
        PXW = 1.0
        for x, w in zip(X, W):
            if w == x:
                pxw = alpha
            else:
                close_to_x = close_words[x]  # includes x itself
                pxw = (1 - alpha) / (len(close_to_x) - 1)  # so we subtract 1
            PXW *= pxw
        likelihoods.append(PXW)

    likelihoods = np.array(likelihoods)
    idx_most_likely = likelihoods.argmax()

    priors = []
    for W in CX:
        priors.append(P(W))

    posteriors = np.array(priors) * np.array(likelihoods)
    idx_best_post = np.argmax(posteriors)

    print(f"The corrected sentence is: {' '.join(CX[idx_best_post])}.")
    print()
# Out:
# Original sentence: The weather today is nice and sunny.
# weather doesn't belong to the vocabulary, skipping the sentence.
# today doesn't belong to the vocabulary, skipping the sentence.
# nice doesn't belong to the vocabulary, skipping the sentence.
# sunny doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the weather today is nice and sunny.
#
# Original sentence: She enjoys reading books in her free time.
# enjoys doesn't belong to the vocabulary, skipping the sentence.
# reading doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: she enjoys reading books in her free time.
#
# Original sentence: He went for a long walk in the park.
# park doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: I went for a long walk in the park.
#
# Original sentence: The cake needs more sugar to taste better.
# needs doesn't belong to the vocabulary, skipping the sentence.
# sugar doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the cake needs more sugar to taste better.
#
# Original sentence: I prefer tea over coffee in the morning.
# i doesn't belong to the vocabulary, skipping the sentence.
# prefer doesn't belong to the vocabulary, skipping the sentence.
# coffee doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: i prefer tea over coffee in the morning.
#
# Original sentence: Please hand me the blue pen on the table.
# hand doesn't belong to the vocabulary, skipping the sentence.
# pen doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: please hand me the be pen on the table.
#
# Original sentence: The children played happily in the playground.
# playground doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the children played happily in the playground.
#
# Original sentence: It is important to get enough sleep every night.
# The corrected sentence is: it is important to get enough see every night.
#
# Original sentence: The movie we watched last night was interesting.
# movie doesn't belong to the vocabulary, skipping the sentence.
# watched doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: the movie we watched last night was interesting.
#
# Original sentence: She is looking forward to her vacation next month.
# vacation doesn't belong to the vocabulary, skipping the sentence.
# month doesn't belong to the vocabulary, skipping the sentence.
# The corrected sentence is: she is looking forward to her vacation not month.

# %% [markdown]
# ### 6. extra points: what if you change the tri-gram language model by the neural network of exercise 2 ?

# %% [markdown]
# An error that I can´t understand occurs with CUDA

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
from torch.utils.data import Dataset, DataLoader


device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)



class FixedWindow(Dataset):
    def __init__(self, words, length_window):
        super().__init__()
        self.length_window = length_window
        # TODO:
        # compute the vocabulary = list of unique words in 'words',
        self.vocabulary = list(set([word for word in words]))
        
        # then assign a unique id number to each word in the vocabulary, 
        self.id_vocabulary = {i: word for i, word in enumerate(self.vocabulary)}
        
        # and finally compute a list of ids, one per word in 'words'
        
        # Create a reverse mapping to convert words to their ids, set the word as key and the id as value
        self.word_to_id = {word: i for i, word in self.id_vocabulary.items()}

        # Compute a list of ids, one per word in 'words'
        self.word_ids = [self.word_to_id[word] for word in words]


    def __len__(self):
        return len(self.word_ids) - self.length_window

    def __getitem__(self, idx):
        #TODO:
        '''
        returns a pair of tensors (first_ids, last_id) where
        first_ids are the ids of the words starting at index
        idx with length length_window-1, and last_id is the
        id at position idx+self.length_window-1, next to first_ids
        '''
        # Get the first_ids list of length length_window - 1
        first_ids_list = self.word_ids[idx: idx + self.length_window - 1]

        # Get the last_id at position idx + self.length_window - 1
        last_id_list = self.word_ids[idx + self.length_window - 1]

        # Convert the lists into tensors using torch.as_tensor()
        first_ids = torch.as_tensor(first_ids_list, dtype=torch.long)
        last_id = torch.as_tensor(last_id_list, dtype=torch.long)

        return first_ids, last_id
# Out:
# cuda:0

# %%
class SimpleNNLM(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim):
        super(SimpleNNLM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.hidden = nn.Linear(embed_dim, hidden_dim)
        self.output = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        embeds = self.embedding(x).sum(dim=1)
        hidden_out = torch.relu(self.hidden(embeds))
        out = self.output(hidden_out)
        return out

# %%
# Load the dataset and create DataLoader
length_window = 5
dataset = FixedWindow(words, length_window)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Create and train the neural network model
vocab_size = len(dataset.vocabulary)
embed_dim = 128
hidden_dim = 128
output_dim = vocab_size

model = SimpleNNLM(vocab_size, embed_dim, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 10
for epoch in range(num_epochs):
    for batch in dataloader:
        inputs, target = batch
        inputs, target = inputs.to(device), target.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()

    print(f'Epoch: {epoch + 1}, Loss: {loss.item()}')


def P_NNLM(W):
    input_ids = [dataset.word_to_id.get(word, -1) for word in W]
    valid_input_ids = [i for i in input_ids if i != -1]
    X = torch.tensor(valid_input_ids).unsqueeze(0).to(device)
    with torch.no_grad():
        pred = model(X)
    probs = torch.nn.functional.softmax(pred, dim=1)
    prob_sequence = 1.0
    for i, w in enumerate(W[1:]):
        if input_ids[i] == -1:  # If the word is not in the vocabulary, assign a low probability
            prob_sequence *= 1e-6
        else:
            prob_sequence *= probs[0][dataset.word_to_id[w]].item()
    return prob_sequence
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-91-28842947374c> in <cell line: 12>()
#      10 output_dim = vocab_size
#      11
# ---> 12 model = SimpleNNLM(vocab_size, embed_dim, hidden_dim, output_dim).to(device)
#      13 criterion = nn.CrossEntropyLoss()
#      14 optimizer = optim.Adam(model.parameters(), lr=0.001)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1143             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#    1144
# -> 1145         return self._apply(convert)
#    1146
#    1147     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     795     def _apply(self, fn):
#     796         for module in self.children():
# --> 797             module._apply(fn)
#     798
#     799         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     818             # `with torch.no_grad():`
#     819             with torch.no_grad():
# --> 820                 param_applied = fn(param)
#     821             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822             if should_use_set_data:
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in convert(t)
#    1141                 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                             non_blocking, memory_format=convert_to_format)
# -> 1143             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#    1144
#    1145         return self._apply(convert)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import numpy as np
import random
import string

def generate_misspelled_word(word):
    letters = string.ascii_letters
    operation = random.choice(["replace", "insert", "delete"])

    if operation == "replace":
        index = random.randint(0, len(word) - 1)
        new_char = random.choice(letters)
        misspelled_word = word[:index] + new_char + word[index + 1:]
    elif operation == "insert":
        index = random.randint(0, len(word))
        new_char = random.choice(letters)
        misspelled_word = word[:index] + new_char + word[index:]
    else:
        index = random.randint(0, len(word) - 1)
        misspelled_word = word[:index] + word[index + 1:]

    return misspelled_word

test_sentences = [
    "The weather today is nice and sunny.",
    "She was tired but continued working.",
    "I love eating chocolate ice cream.",
    "Please take out the trash before leaving.",
    "The new movie was absolutely fantastic.",
    "He always forgets his keys at home.",
    "Let's go to the park this weekend.",
    "The dog chased the squirrel up the tree.",
    "I can't believe how fast time flies.",
    "Make sure to lock the door when you leave.",
]

for sentence in test_sentences:
    words = sentence.split()

    misspelled_indices = random.sample(range(len(words)), random.randint(1, 2))
    misspelled_words = [
        generate_misspelled_word(words[i]) if i in misspelled_indices else words[i]
        for i in range(len(words))
    ]

    misspelled_sentence = " ".join(misspelled_words)
    print("Original sentence:", sentence)
    print("Misspelled sentence:", misspelled_sentence)
    print("Probability:", P_NNLM(misspelled_words))
    print()
