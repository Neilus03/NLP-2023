# %% [markdown]
# <a href="https://colab.research.google.com/github/Neilus03/NLP-2023/blob/main/nlp_exercise1_Neil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tqdm import tqdm
import nltk
nltk.download('punkt')
nltk.download('gutenberg')
nltk.download('cess_cat')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package cess_cat to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cess_cat.zip.
# True

# %% [markdown]
# Load a corpus in Catalan or English. The nltk corpora result from tokenizing and segmenting into sentences large collections of text.
#
# The ``gutenberg`` corpus comes from a set of English literature classics. The ``cess_cat`` corpus comes from https://www.cs.upc.edu/~nlp/wikicorpus/, the "120 Million Word Spanish Corpus" which has a subset in Catalan of 50 million words scrapped from Vikipedia in 2006.

# %%
name_corpus = 'gutenberg'

if name_corpus=='cess_cat':
    from nltk.corpus import cess_cat as corpus
    # clean the corpus of strange words
    words = []
    words_to_remove = ['*0*', '-Fpa-', '-Fpt-']
    for w in tqdm(corpus.words()):
        if w not in words_to_remove:
            words.append(w)

elif name_corpus=='gutenberg':
    from nltk.corpus import gutenberg as corpus
    print(corpus.fileids())
    words = corpus.words()
else:
    assert False

print('corpus {} : {} words, {} sentences'
      .format(name_corpus, len(words), len(corpus.sents())))
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# corpus gutenberg : 2621613 words, 98552 sentences

# %% [markdown]
# Build a language model from bigrams. A LM is just a dictionary
# with key = condition = one word, and value = ``FreqDist``
# object = another dictionary with key = next word, value = number
# of occurrences.
# This is adapted from https://www.nltk.org/book/ch02.html, section 2.4

# %%
grams = list(nltk.bigrams(words))
# also trigrams, ngrams, everygrams(max_len)
cfd = nltk.ConditionalFreqDist(grams)
print(f'List of unique words that act as conditions in the conditional frequency distribution:\n{cfd.conditions()}')
print('-'*20)
for i in [100, 200, 300, 400]:

    print(f'word at position i in the list of conditions:\n{cfd.conditions()[i]}\n')
    print(f'most common pairs (word, frequency) that follow the word printed on the previous line, that is, the most common words that appear after the word at position i:\n{cfd[cfd.conditions()[i]].most_common()}')
    print('--------------')

if name_corpus == 'cess_cat':
    freq_dist =cfd['Una']
elif name_corpus == 'gutenberg':
    freq_dist = cfd['The']

print(f'the pairs (word, frequency) in the frequency distribution stored in freq_dist:\n{freq_dist.items()}\n')
print(f'Word with maximum frequency in the frequency distribution:\n{freq_dist.max()}\n\n')
print(f'List of words in freq_list, were each word appears freq times:\n{sorted(list(freq_dist.elements()))}')
# Out:
# List of unique words that act as conditions in the conditional frequency distribution:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER', 'Woodhouse', ',', 'handsome', 'clever', 'and', 'rich', 'with', 'a', 'comfortable', 'home', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'existence', ';', 'had', 'lived', 'nearly', 'twenty', '-', 'one', 'years', 'in', 'world', 'very', 'little', 'distress', 'or', 'vex', 'her', '.', 'She', 'was', 'youngest', 'two', 'daughters', 'most', 'affectionate', 'indulgent', 'father', 'consequence', 'sister', "'", 's', 'marriage', 'been', 'mistress', 'his', 'house', 'from', 'early', 'period', 'Her', 'mother', 'died', 'too', 'long', 'ago', 'for', 'have', 'more', 'than', 'an', 'indistinct', 'remembrance', 'caresses', 'place', 'supplied', 'excellent', 'woman', 'as', 'governess', 'who', 'fallen', 'short', 'affection', 'Sixteen', 'Miss', 'Taylor', 'Mr', 'family', 'less', 'friend', 'fond', 'both', 'but', 'particularly', 'Between', '_them_', 'it', 'intimacy', 'sisters', 'Even', 'before', 'ceased', 'hold', 'nominal', 'office', 'mildness', 'temper', 'hardly', 'allowed', 'impose', 'any', 'restraint', 'shadow', 'authority', 'being', 'now', 'passed', 'away', 'they', 'living', 'together', 'mutually', 'attached', 'doing', 'just', 'what', 'she', 'liked', 'highly', 'esteeming', 'judgment', 'directed', 'chiefly', 'own', 'The', 'real', 'evils', 'indeed', 'situation', 'were', 'power', 'having', 'rather', 'much', 'way', 'think', 'well', 'herself', 'these', 'disadvantages', 'which', 'threatened', 'alloy', 'many', 'enjoyments', 'danger', 'however', 'at', 'present', 'so', 'unperceived', 'that', 'did', 'not', 'means', 'rank', 'misfortunes', 'Sorrow', 'came', '--', 'gentle', 'sorrow', 'all', 'shape', 'disagreeable', 'consciousness', '.--', 'married', 'It', 'loss', 'first', 'brought', 'grief', 'on', 'wedding', 'day', 'this', 'beloved', 'sat', 'mournful', 'thought', 'continuance', 'over', 'bride', 'people', 'gone', 'left', 'dine', 'no', 'prospect', 'third', 'cheer', 'evening', 'composed', 'himself', 'sleep', 'after', 'dinner', 'usual', 'then', 'only', 'sit', 'lost', 'event', 'every', 'promise', 'happiness', 'Weston', 'man', 'unexceptionable', 'character', 'easy', 'fortune', 'suitable', 'age', 'pleasant', 'manners', 'there', 'satisfaction', 'considering', 'self', 'denying', 'generous', 'friendship', 'always', 'wished', 'promoted', 'match', 'black', 'morning', 'work', 'want', 'would', 'be', 'felt', 'hour', 'recalled', 'past', 'kindness', 'sixteen', 'how', 'taught', 'played', 'five', 'old', 'devoted', 'powers', 'attach', 'amuse', 'health', 'nursed', 'through', 'various', 'illnesses', 'childhood', 'A', 'large', 'debt', 'gratitude', 'owing', 'here', 'intercourse', 'last', 'seven', 'equal', 'footing', 'perfect', 'unreserve', 'soon', 'followed', 'Isabella', 'their', 'each', 'other', 'yet', 'dearer', 'tenderer', 'recollection', 'companion', 'such', 'few', 'possessed', ':', 'intelligent', 'informed', 'useful', 'knowing', 'ways', 'interested', 'its', 'concerns', 'peculiarly', 'pleasure', 'scheme', 'hers', 'whom', 'could', 'speak', 'arose', 'never', 'find', 'fault', 'How', 'bear', 'change', '?--', 'true', 'going', 'half', 'mile', 'them', 'aware', 'great', 'must', 'difference', 'between', 'Mrs', 'advantages', 'natural', 'domestic', 'suffering', 'intellectual', 'solitude', 'dearly', 'loved', 'he', 'He', 'meet', 'conversation', 'rational', 'playful', 'evil', 'actual', 'disparity', 'ages', '(', ')', 'increased', 'constitution', 'habits', 'valetudinarian', 'life', 'without', 'activity', 'mind', 'body', 'older', 'though', 'everywhere', 'friendliness', 'heart', 'amiable', 'talents', 'recommended', 'him', 'time', 'comparatively', 'removed', 'matrimony', 'settled', 'London', 'miles', 'off', 'beyond', 'daily', 'reach', 'October', 'November', 'struggled', 'Hartfield', 'Christmas', 'next', 'visit', 'husband', 'children', 'fill', 'give', 'society', 'again', 'Highbury', 'populous', 'village', 'almost', 'amounting', 'town', 'spite', 'separate', 'lawn', 'shrubberies', 'nam ...
# --------------------
# word at position i in the list of conditions:
# fond
#
# most common pairs (word, frequency) that follow the word printed on the previous line, that is, the most common words that appear after the word at position i:
# [('of', 112), (',', 11), ('and', 3), ('she', 2), ('attachment', 2), ('."', 2), ('report', 1), (';--', 1), ('affection', 1), ('solicitude', 1), ('praise', 1), ('dependence', 1), ('parents', 1), ('partiality', 1), ('regrets', 1), ('regret', 1), ('mother', 1), ('he', 1), ('--', 1), ('daughter', 1), ('father', 1), ('.', 1), ('faith', 1), ('pride', 1), ('hopes', 1), ('impertinence', 1), ('Records', 1)]
# --------------
# word at position i in the list of conditions:
# thought
#
# most common pairs (word, frequency) that follow the word printed on the previous line, that is, the most common words that appear after the word at position i:
# [('of', 172), ('it', 130), (',', 129), ('I', 74), ('he', 65), ('that', 57), ('to', 46), ('you', 42), ('the', 36), ('.', 28), ('Alice', 26), ('she', 23), ('so', 18), ('him', 14), ('for', 14), ('was', 14), ('her', 13), (';', 13), ('we', 12), ('herself', 11), ('there', 11), ('only', 10), ('about', 10), ('this', 9), ('a', 9), ('they', 9), ('how', 9), ('Emma', 8), ('in', 8), ('as', 7), ('his', 7), ('at', 7), ('them', 7), ('or', 7), ('very', 6), ('--', 6), ('and', 6), ('on', 6), ('my', 6), ('can', 6), ('no', 5), (',"', 5), ('would', 5), ('not', 5), ('proper', 5), ('nothing', 4), ('with', 4), ('himself', 4), ('something', 4), ('myself', 4), ('is', 4), ('had', 4), ('Ahab', 4), ('much', 3), ('more', 3), ('seriously', 3), ('but', 3), ('such', 3), ('well', 3), ('your', 3), ('which', 3), ('over', 3), ('some', 3), (':', 3), (',--', 3), ('poor', 3), ('when', 2), ('highly', 2), ('might', 2), ('me', 2), ('less', 2), ('most', 2), ('our', 2), ('evil', 2), ('good', 2), ('best', 2), ('made', 2), ('Prince', 2), ('."', 2), (')', 2), ('by', 2), ('Susan', 2), ('Starbuck', 2), ('-', 2), ('?', 2), ('To', 2), ('perfect', 1), ('Mr', 1), ('Harriet', 1), ('!--', 1), ('necessary', 1), ('must', 1), ('almost', 1), ('Miss', 1), ('extravagant', 1), ('each', 1), ('principally', 1), ('beyond', 1), ('either', 1), ('than', 1), ('first', 1), ('.--', 1), ('differently', 1), ('unreasonably', 1), ('infinitely', 1), ('hers', 1), ('unworthy', 1), ('unimportant', 1), ('Captain', 1), ('then', 1), ('occur', 1), ('could', 1), ('nobody', 1), ('Mrs', 1), ('Elinor', 1), ('struck', 1), ('another', 1), ('Edward', 1), ('Fanny', 1), ('scorn', 1), ('afar', 1), ('upon', 1), ('beforehand', 1), ('thereon', 1), ('within', 1), ('worthy', 1), ('A', 1), ('out', 1), ('interesting', 1), ('Buster', 1), ('all', 1), ('those', 1), ('),', 1), ('decidedly', 1), ('atheism', 1), ('may', 1), ('people', 1), ('vaguely', 1), ('life', 1), ('kindly', 1), ('somehow', 1), ('hazily', 1), ('Father', 1), ('what', 1), ('little', 1), ('irrational', 1), ('their', 1), ('many', 1), ('Laura', 1), ('Finsbury', 1), ('extremely', 1), ('ignorant', 1), ('perhaps', 1), ('likely', 1), ('Piedro', 1), ('excellent', 1), ('fit', 1), ('Loveit', 1), ('themselves', 1), ('ye', 1), ('coming', 1), ('Flask', 1), ('turn', 1), ('capable', 1), ('Daggoo', 1), ('will', 1), ('from', 1), ('Both', 1), ('one', 1), ('Of', 1), ('?)', 1), ('infirm', 1), ('Impossible', 1), ('So', 1), ('All', 1), ('Thee', 1), ('Less', 1), ('denied', 1), ('be', 1), ('death', 1), ('No', 1), ('Horrid', 1), ('Was', 1), ('Ophir', 1), ('It', 1), ("'", 1), ('thy', 1), ('After', 1), ('He', 1), ('honest', 1), ('The', 1), ('O', 1), ('impalpable', 1), ('yourself', 1), ('great', 1), ('been', 1), ('if', 1), ('begins', 1)]
# --------------
# word at position i in the list of conditions:
# few
#
# most common pairs (word, frequency) that follow the word printed on the previous line, that is, the most common words that appear after the word at position i:
# [('minutes', 86), ('days', 53), ('moments', 43), ('hours', 23), ('of', 20), ('weeks', 19), (',', 19), ('words', 18), ('months', 17), ('yards', 15), ('years', 13), ('.', 13), ('lines', 10), ('seconds', 9), ('who', 8), ('men', 8), ('steps', 8), ('people', 7), ('miles', 7), ('inches', 7), ('things', 6), ('turns', 5), ('in', 5), ('are', 5), (';', 4), ('hundred', 4), ('friends', 4), ('paces', 4), ('feet', 4), ('flakes', 3), ('little', 3), ('stars', 3), ('shillings', 3), ('hints', 2), ('difficulties', 2), ('other', 2), ('more', 2), ('occasions', 2), ('as', 2), ('old', 2), ('sentences', 2), ('and', 2), (':', 2), ('that', 2), ('final', 2), ('doors', 2), ('remaining', 2), ('possessed', 1), ('sixpences', 1), ('odd', 1), ('decisive', 1), ('first', 1), ('inferior', 1), ('married', 1), ('vagaries', 1), ('brief', 1), ('places', 1), ('parties', 1), ('clever', 1), ('downright', 1), ('awkward', 1), ('opportunities', 1), ('ornaments', 1), ('to', 1), ('pearls', 1), ('persons', 1), ('hardships', 1), ('whispers', 1), ('lace', 1), ('among', 1), ('navy', 1), ('smiles', 1), ('compliments', 1), ('articles', 1), ('exceptions', 1), ('fervent', 1), ('objects', 1), ('changes', 1), ('alterations', 1), ('faint', 1), ('thousand', 1), ('painful', 1), ('girls', 1), ('syllables', 1), ('or', 1), ('thou', 1), ('ye', 1), ('sheep', 1), ('therein', 1), ('?', 1), ('there', 1), ('chosen', 1), ('sick', 1), ('small', 1), ('stripes', 1), ('names', 1), ('times', 1), ('sticks', 1), ('knelt', 1), ('mornings', 1), ('chords', 1), ('doubted', 1), ('windows', 1), ('feverish', 1), ('cries', 1), ('trees', 1), ('very', 1), ('certain', 1), ('mounted', 1), ('districts', 1), ('dirty', 1), ('indistinct', 1), ('pathological', 1), ('flowers', 1), ('coloured', 1), ('scraps', 1), ('formal', 1), ('lessons', 1), ('really', 1), ('strips', 1), ('holidays', 1), ('seagulls', 1), ('shapeless', 1), ('despotisms', 1), ('glances', 1), ('wicked', 1), ('posts', 1), ('stones', 1), ('strawberries', 1), ('questions', 1), ('birds', 1), ('know', 1), ('loaves', 1), ('reverend', 1), ('fair', 1), ('guineas', 1), ('young', 1), ('plants', 1), ('raspberries', 1), ('macaroons', 1), ('bruises', 1), ('soft', 1), ('bottles', 1), ('tools', 1), ('braces', 1), ('yet', 1), ('treat', 1), ('pence', 1), ('grapes', 1), ('figs', 1), ('sugar', 1), ('drawings', 1), ('tears', 1), ('misfortunes', 1), ('happy', 1), ('ever', 1), ('pieces', 1), ('shades', 1), ('porpoises', 1), ('pictures', 1), ('quiet', 1), ('green', 1), (':--', 1), ('scientific', 1), ('sorts', 1), ('mortals', 1), ('perhaps', 1), ('foibles', 1), ('aspects', 1), ('whale', 1), ('ripples', 1), ('rapid', 1), ('sleepers', 1), ('sidelong', 1), ('vast', 1), ('supposed', 1), ('scattered', 1), ('strokes', 1), ('breaths', 1), ('along', 1), ('known', 1), ('grains', 1), ('hands', 1), ('fierce', 1), ('interior', 1), ('whalemen', 1), ('disordered', 1), ('drops', 1), ('long', 1), ('indolent', 1), ('thoughts', 1), ('fleeting', 1), ('keen', 1), ('splintered', 1), ('coppers', 1), ('unknown', 1), ('sometimes', 1), ('escaped', 1), ('His', 1), ('Precepts', 1), ('thy', 1), ('diffused', 1), ('light', 1), ('embraces', 1), ('fell', 1), ('large', 1), ('idly', 1), ('quadrillions', 1), ('octillions', 1), ('will', 1), (')', 1), ('carols', 1), ('noticed', 1), ('ragged', 1), ('sands', 1), ('the', 1), ('shreds', 1), ('equals', 1), ('bubbles', 1), ('see', 1)]
# --------------
# word at position i in the list of conditions:
# populous
#
# most common pairs (word, frequency) that follow the word printed on the previous line, that is, the most common words that appear after the word at position i:
# [(',', 4), ('cities', 2), ('city', 2), ('village', 1), (':', 1), ('No', 1), ('streets', 1), ('river', 1), ('North', 1), ('youth', 1), ('pavements', 1), ('states', 1), ('towns', 1), ('millions', 1)]
# --------------
# the pairs (word, frequency) in the frequency distribution stored in freq_dist:
# dict_items([('real', 7), ('danger', 6), ('wedding', 4), ('event', 6), ('want', 2), ('evil', 8), ('Woodhouses', 1), ('carriage', 9), ('backgammon', 1), ('chances', 1), ('boy', 13), ('aunt', 3), ('compliments', 1), ('simplicity', 1), ('acquaintance', 2), ('friends', 2), ('happiness', 2), ('Children', 1), ('next', 47), ('yeomanry', 1), ('misfortune', 2), ('young', 38), ('older', 1), ('longer', 1), ('list', 2), ('shape', 17), ('corner', 1), ('sitting', 2), ('same', 40), ('expression', 2), ('only', 32), ('naivete', 1), ('very', 27), ('style', 2), ('symptoms', 1), ('looking', 1), ('business', 3), ('attentions', 1), ('idea', 18), ('advantage', 2), ('sphere', 1), ('result', 5), ('possibility', 3), ('dread', 2), ('Picture', 1), ('stupidest', 1), ('speech', 3), ('strangest', 1), ('course', 2), ('two', 48), ('most', 13), ('best', 14), ('couplet', 1), ('hood', 1), ('name', 14), ('children', 120), ('lane', 2), ('wants', 1), ('room', 8), ('lovers', 1), ('coming', 3), ('bustle', 2), ('extreme', 1), ('beginning', 5), ('evening', 12), ('brothers', 1), ('plan', 3), ('neighbourhood', 2), ('gruel', 1), ('ejaculation', 1), ('cold', 3), ('preparing', 1), ('folly', 2), ('contrivances', 1), ('difficulty', 2), ('case', 5), ('introduction', 1), ('horror', 3), ('compliment', 1), ('hair', 2), ('picture', 4), ('landed', 1), ('first', 71), ('distressing', 1), ('youth', 3), ('weather', 9), ('ground', 6), ('confession', 2), ('affection', 3), ('Churchills', 2), ('house', 15), ('mention', 1), ('expense', 2), ('marriage', 1), ('good', 14), ('like', 3), ('muffin', 1), ('information', 1), ('shower', 1), ('charming', 1), ('pain', 4), ('charm', 3), ('unhappiness', 1), ('quarter', 2), ('refreshment', 1), ('worn', 1), ('morning', 15), ('clock', 10), ('Frank', 1), ('word', 51), ('son', 27), ('man', 68), ('circumstance', 2), ('Coles', 3), ('regular', 1), ('bare', 2), ('dews', 1), ('ladies', 6), ('sooner', 2), ('party', 10), ('less', 3), ('conversation', 2), ('arrival', 2), ('conviction', 1), ('unpersuadable', 1), ('rest', 34), ('more', 17), ('interest', 4), ('pleasure', 1), ('strength', 3), ('visit', 6), ('other', 43), ('truth', 9), ('Coxes', 1), ('scene', 2), ('rivet', 1), ('apples', 1), ('appearance', 5), ('listeners', 1), ('doors', 3), ('Crown', 1), ('old', 60), ('preparations', 3), ('substance', 3), ('loss', 1), ('woman', 15), ('rich', 11), ('grounds', 4), ('laurels', 1), ('advantages', 2), ('dignity', 2), ('tone', 2), ('kindness', 2), ('change', 7), ('decree', 1), ('extent', 1), ('persons', 1), ('preparatory', 2), ('day', 19), ('post', 3), ('kind', 4), ('spring', 2), ('thing', 17), ('regularity', 1), ('clerks', 1), ('public', 2), ('varieties', 2), ('whole', 45), ('fact', 14), ('remaining', 3), ('difference', 6), ('Enscombe', 1), ('time', 19), ('mistake', 1), ('ball', 4), ('anxious', 2), ('move', 1), ('baked', 1), ('impertinence', 2), ('fever', 1), ('iron', 2), ('pleasantness', 1), ('terror', 1), ('last', 20), ('gipsies', 2), ('service', 1), ('Eltons', 2), ('Randalls', 1), ('gentlemen', 3), ('dream', 2), ('quietness', 1), ('joke', 1), ('year', 1), ('nature', 3), ('invitation', 4), ('pertinacity', 1), ('considerable', 1), ('shade', 1), ('heat', 4), ('greatest', 3), ('black', 7), ('wretchedness', 1), ('touch', 2), ('contrast', 3), ('intention', 1), ('following', 6), ('great', 39), ('character', 3), ('answer', 6), ('present', 7), ('Campbells', 1), ('intelligence', 2), ('impression', 1), ('second', 13), ('superior', 3), ('bitter', 1), ('blunders', 1), ('attachment', 2), ('power', 6), ('quiet', 2), ('consequence', 10), ('error', 1), ('consciousness', 1), ('prospect', 5), ('child', 10), ('"', 1), ('feelings', 1), ('manner', 4), ('delightful', 3), ('Box', 1), ('delicacy', 1), ('hasty', 2), ('subject', 2), ('impossibility', 1), ('fear', 13), ('magistrates', 2), ('wish', 1), ('housekeeper', 4), ('smile', 3), ('fate', 1), ('news', 3), ('joy', 4), ('sole', 1), ('disguise', 1), ('shame', 1), ('others', 13), ('stain', 1), ('intimacy', 2), ('Mr', 2), ('intermediate', 1), ('heir' ...
#
# Word with maximum frequency in the frequency distribution:
# LORD
#
#
# List of words in freq_list, were each word appears freq times:
# ['"', '72d', 'Abbey', 'Abbey', 'Abbey', 'Absence', 'Actors', 'Acts', 'Admiral', 'Admiral', 'Admiral', 'Admiral', 'Admiral', 'Admiral', 'Admiral', 'Admiralty', 'Adventures', 'Adversary', 'Advocate', 'Affidavit', 'Alabama', 'Albatross', 'Albino', 'Algerine', 'Almighty', 'Almighty', 'Amalekites', 'American', 'American', 'American', 'American', 'American', 'Angel', 'Angel', 'Angel', 'Antipathies', 'Apocalypse', 'Apostate', 'Apostate', 'Apparition', 'Arch', 'Arch', 'Arch', 'Archers', 'Archers', 'Archers', 'Artilleryman', 'Asiatic', 'Assessour', 'Attorney', 'Australian', 'Author', 'Authors', 'Ayre', 'BRANCH', 'Baby', 'Babylonians', 'Bachelor', 'Ball', 'Ball', 'Banyan', 'Bar', 'Barke', 'Baronet', 'Barren', 'Base', 'Bath', 'Battering', 'Bell', 'Biblic', 'Bird', 'Blacksmith', 'Blanket', 'Bloody', 'Bloody', 'Board', 'Bombay', 'Bombay', 'Book', 'Book', 'Book', 'Book', 'Book', 'Book', 'Book', 'Book', 'Book', 'Book', 'Book', 'Border', 'Bottle', 'Box', 'Brahmin', 'Brahmin', 'Brahmins', 'Bravest', 'Brest', 'Bride', 'British', 'Bruno', 'Bullock', 'Burgomaster', 'Cabin', 'Cabin', 'Cachalot', 'Calming', 'Camel', 'Campbells', 'Candles', 'Canker', 'Cannons', 'Cape', 'Captain', 'Captain', 'Carpenter', 'Carpet', 'Carriages', 'Cassock', 'Castaway', 'Castle', 'Cat', 'Cat', 'Cat', 'Cat', 'Caterpillar', 'Caterpillar', 'Catholic', 'Centenarian', 'Centenarian', 'Cesterne', 'Chaldeans', 'Chaldeans', 'Chaldeans', 'Chamberlain', 'Chamberlain', 'Chamberlain', 'Chamberlain', 'Chamberlain', 'Champion', 'Champion', 'Chapel', 'Chart', 'Chase', 'Chase', 'Chase', 'Cherubim', 'Children', 'Choice', 'Christ', 'Christ', 'Christian', 'Church', 'Church', 'Church', 'Church', 'Church', 'Church', 'Churchills', 'Churchills', 'Cid', 'City', 'City', 'Clocke', 'Clod', 'Cloud', 'Cloud', 'Cloud', 'Coarse', 'Cocke', 'Coles', 'Coles', 'Coles', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Colonel', 'Common', 'Commonplace', 'Congress', 'Conquerors', 'Continent', 'Cooper', 'Count', 'Count', 'Counterpane', 'Country', 'Courtiers', 'Coxes', 'Creation', 'Cretians', 'Crofts', 'Crofts', 'Crofts', 'Crofts', 'Crofts', 'Crofts', 'Crofts', 'Crofts', 'Cross', 'Cross', 'Cross', 'Crossed', 'Crossed', 'Crotch', 'Crown', 'Crusaders', 'Cry', 'Curtain', 'DEVIL', 'Dagda', 'Dalliance', 'Dart', 'Dashwoods', 'Dashwoods', 'Dashwoods', 'Dead', 'Dead', 'Deadmans', 'Decanter', 'Deck', 'Deck', 'Deck', 'Deep', 'Deity', 'Delight', 'Deuill', 'Devil', 'Devil', 'Diamond', 'Dismantled', 'Doctor', 'Doctor', 'Doctor', 'Doctor', 'Doctor', 'Doctor', 'Dormouse', 'Dormouse', 'Dormouse', 'Dormouse', 'Dormouse', 'Doubloon', 'Duchess', 'Duchess', 'Duchess', 'Duchess', 'Ducks', 'Duel', 'Duke', 'Duke', 'Duke', 'Duke', 'Duke', 'Duke', 'Duke', 'Duke', 'Dutchman', 'Dying', 'Dying', 'Eagle', 'Earth', 'Earth', 'Earth', 'Eerie', 'Elector', 'Elector', 'Elector', 'Elephant', 'Eltons', 'Eltons', 'Emims', 'Emperor', 'Emperor', 'Emperor', 'End', 'Enemies', 'Enemy', 'Enemy', 'Enemy', 'English', 'English', 'English', 'English', 'English', 'English', 'English', 'Enscombe', 'Epistle', 'Epistle', 'Epistle', 'Epistle', 'Epistle', 'Epistle', 'Epistle', 'Epistle', 'Eternal', 'Eton', 'Etonians', 'Eye', 'Eyres', 'FUTURE', 'Fairy', 'Father', 'Female', 'Female', 'Field', 'Fiend', 'Fiend', 'Fiend', 'Fifth', 'Filial', 'Fin', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'First', 'Fish', 'Footman', 'Forecastle', 'Forge', 'Fortunes', 'Forty', 'Fossil', 'Fountain', 'Fourth', 'Fourth', 'Fox', 'Frank', 'French', 'French', 'Frenchman', 'Frog', 'Frogs', 'Frogs', 'Funeral', 'Gallowes', 'Gam', 'Games', 'General', 'General', 'General', 'Genius', 'German', 'German', 'Ghost', 'Gilder', 'Glow', 'Goal', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'God', 'Gods', 'Gods', 'Gods', 'Gods', 'Gospel', 'Gospel', 'Gospel', 'Gospel', 'Government', 'Grand', 'Great',  ...

# %% [markdown]
# Sample text from the language model

# %%
import random

def sample_bigram_model(cfd_bigrams, last_word, num_words=15):
    generated_text = [last_word]
    for _ in range(num_words - 1):
        next_word = random.choices(list(cfd_bigrams[last_word].keys()), weights=list(cfd_bigrams[last_word].values()))[0]
        generated_text.append(next_word)
        last_word = next_word
    return ' '.join(generated_text)

if name_corpus=='cess_cat':
    print(sample_bigram_model(cfd, 'El', 100))
    print(sample_bigram_model(cfd, 'La', 100))
    print(sample_bigram_model(cfd, 'Per', 100))
else:
    print(sample_bigram_model(cfd, 'The', 100))
    print(sample_bigram_model(cfd, 'For', 100))
# Out:
# The doubts of the moment she settled before of sunset . She is possibly find your banker ' d and three minutes ; and Zilthai , on the evening , My Likeness Earth ; for the fire out of the carpenter ' s nose . Did I have strengthened the same mouth to Emma found him . " Rather than the empty . See my horse block . 6 : Aye me ?" asked Marianne considered it still under the tumultuous city , beneath the only person ! Britons ! Cooling airs and their sons of more , he ,
# For that Mr . Then Daniel a strange , but to our friends ; and silver voice ; and their movements of honour all nations , Marianne saw for something from the Word over us . And Samson . But come were seen ; but a penny . 21 Woe unto you on a furious as soon ready to speak just told you think was driving these , she replied very sure , nor any other fish blades crossed the month , and the ocean without a blessing , and from his seisure many LAYS here ." " not thine

# %% [markdown]
# Extension of previous function to tri, 4... n-grams is long and complicated
# because conditions of cfd are not one word but lists of pairs, triplets, n-1 words. In addition, the probability of not finding the previous 2, 3..n
# generated words among the conditions (ngrams) is very high. So better rely
# on the ``lm`` package of nltk. It has also support for adding ``<s>``, ``</s>`` symbols to sentences (padding), different types of smoothing and backoff, and sampling text.
#
# Build a proper language model with support for ``<s>``, ``</s>``, smoothing, backoff, sampling and computation of perplexity. See how here
# https://www.nltk.org/api/nltk.lm.html

# %%
if name_corpus=='cess_cat':
    text = []
    words_to_remove = ['*0*', '-Fpa-', '-Fpt-']
    #for s in tqdm(corpus.sents()[:1000]): # debug or quickly train the network
    for s in tqdm(corpus.sents()):
        new_s = [w for w in s if w not in words_to_remove]
        text.append(new_s[:-1]) # except ending point
else:
    text = []
    for s in tqdm(corpus.sents()):
        text.append(s[:-1]) # except ending point
# Out:
#  11%|█         | 10937/98552 [00:00<00:06, 13127.53it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-95e2aba73149> in <cell line: 1>()
#       8 else:
#       9     text = []
# ---> 10     for s in tqdm(corpus.sents()):
#      11         text.append(s[:-1]) # except ending point
#      12
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in __iter__(self)
#    1186                     dt = cur_t - last_print_t
#    1187                     if dt >= mininterval and cur_t >= min_start_t:
# -> 1188                         self.update(n - last_print_n)
#    1189                         last_print_n = self.last_print_n
#    1190                         last_print_t = self.last_print_t
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in update(self, n)
#    1237                     self._ema_dn(dn)
#    1238                     self._ema_dt(dt)
# -> 1239                 self.refresh(lock_args=self.lock_args)
#    1240                 if self.dynamic_miniters:
#    1241                     # If no `miniters` was specified, adjust automatically to the
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in refresh(self, nolock, lock_args)
#    1342             else:
#    1343                 self._lock.acquire()
# -> 1344         self.display()
#    1345         if not nolock:
#    1346             self._lock.release()
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in display(self, msg, pos)
#    1490         if pos:
#    1491             self.moveto(pos)
# -> 1492         self.sp(self.__str__() if msg is None else msg)
#    1493         if pos:
#    1494             self.moveto(-pos)
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in print_status(s)
#     345         def print_status(s):
#     346             len_s = disp_len(s)
# --> 347             fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     348             last_len[0] = len_s
#     349
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in fp_write(s)
#     338
#     339         def fp_write(s):
# --> 340             fp.write(str(s))
#     341             fp_flush()
#     342
#
# /usr/local/lib/python3.9/dist-packages/tqdm/utils.py in inner(*args, **kwargs)
#     125         def inner(*args, **kwargs):
#     126             try:
# --> 127                 return func(*args, **kwargs)
#     128             except OSError as e:
#     129                 if e.errno != 5:
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.9/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.9/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm.models import MLE, Laplace, StupidBackoff
# TODO:
for n in [3,4,5]:
    for model_type in [StupidBackoff, MLE, Laplace]:
        if model_type == StupidBackoff:
            model = model_type(order = n, alpha=0.4)
        else:
            model = model_type(n)
        
        train_data, padded_sents = padded_everygram_pipeline(n, text)
        
        #Train the model
        model.fit(train_data, padded_sents)

        # Sample a text with 100 words
        generated_text = ' '.join(model.generate(100, random_seed=42))

        model_name = "MLE" if isinstance(model, MLE) else "Laplace" if isinstance(model, Laplace) else "StupidBackoff" 
        
        print(f"Model: {model_name}, n={n}\n")
        print(generated_text)
        print("-------------------------------------------------")

# Compare results, which combination seems more realistic?

# %% [markdown]
# `MLE` with n=4 or 5 and `StupidBackoff` with n=4 or 5 are the most realistic, as they make the most sense to me
