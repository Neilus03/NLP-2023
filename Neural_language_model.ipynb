# %% [markdown]
# <a href="https://colab.research.google.com/github/Neilus03/NLP-2023/blob/main/Neural_language_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tqdm import tqdm
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import nltk
nltk.download('cess_cat')
# Out:
# [nltk_data] Downloading package cess_cat to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cess_cat.zip.
# True

# %%
from nltk.corpus import cess_cat as corpus

words = []
words_to_remove = ['*0*', '-Fpa-', '-Fpt-']
#for s in tqdm(corpus.sents()[:1000]): # debug or quickly train the network
for s in tqdm(corpus.sents()):
    new_s = ['<s>'] + s[:-1] + ['</s>']
    new_s = [w for w in new_s if w not in words_to_remove]
    words.extend(new_s)
# Out:
# 100%|██████████| 17104/17104 [00:17<00:00, 1005.01it/s]

# %%
from torch.utils.data import Dataset, DataLoader

class FixedWindow(Dataset):
    def __init__(self, words, length_window):
        super().__init__()
        self.length_window = length_window
        # TODO:
        # compute the vocabulary = list of unique words in 'words',
        self.vocabulary = list(set([word for word in words]))
        
        # then assign a unique id number to each word in the vocabulary, 
        self.id_vocabulary = {i: word for i, word in enumerate(self.vocabulary)}
        
        # and finally compute a list of ids, one per word in 'words'
        
        # Create a reverse mapping to convert words to their ids, set the word as key and the id as value
        self.word_to_id = {word: i for i, word in self.id_vocabulary.items()}

        # Compute a list of ids, one per word in 'words'
        self.word_ids = [self.word_to_id[word] for word in words]


    def __len__(self):
        return len(self.word_ids) - self.length_window

    def __getitem__(self, idx):
        #TODO:
        '''
        returns a pair of tensors (first_ids, last_id) where
        first_ids are the ids of the words starting at index
        idx with length length_window-1, and last_id is the
        id at position idx+self.length_window-1, next to first_ids
        '''
        # Get the first_ids list of length length_window - 1
        first_ids_list = self.word_ids[idx: idx + self.length_window - 1]

        # Get the last_id at position idx + self.length_window - 1
        last_id_list = self.word_ids[idx + self.length_window - 1]

        # Convert the lists into tensors using torch.as_tensor()
        first_ids = torch.as_tensor(first_ids_list, dtype=torch.long)
        last_id = torch.as_tensor(last_id_list, dtype=torch.long)

        return first_ids, last_id

# %%
length_window = 5
dataset = FixedWindow(words, length_window)

x, y = dataset.__getitem__(10)
#print('x = {}, y = {}'.format(x, y))

batch_size = 1000 # 5 to debug
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True) # shuffle=False to debug

if True:
    for nbatch, (X, y) in enumerate(dataloader):
        print('batch {}'.format(nbatch))
        print('X = {}'.format(X))
        print('y = {}'.format(y))
        for x,z in zip(X.numpy(), y.numpy()):
            print([dataset.id_vocabulary[w] for w in x], end=' ')
            print(dataset.id_vocabulary[z])
        if nbatch==3:
            break
# Out:
# batch 0
# X = tensor([[33979, 34125, 33609, 35288],
#         [12555,  7850, 11575, 22920],
#         [29616, 20266, 31151, 21447],
#         ...,
#         [10646, 18101, 18629, 38830],
#         [21316, 19737,  7739, 23538],
#         [ 2497, 19004, 17332, 29270]])
# y = tensor([24591, 38591,  2653, 33609, 24591, 22920, 26767, 21743, 26833,  5492,
#          7342,  2497, 16069, 21743, 25711,  7047, 19065,  8886,  2653, 29367,
#         18101, 20484, 30894, 34298, 33609,  5417, 12891, 39653,  1870, 29367,
#         33609, 39084,  8688, 20266, 30894, 33609,  4746, 30894, 10478, 23538,
#         25673, 32371, 33609, 20266, 20872,  8688,   917, 35787, 12555,  5023,
#         14490, 12555,  2714, 17950, 17632,  2868, 29047, 29075, 17632, 33979,
#         20266, 26233,  1504, 18301, 33609, 29367,  7275, 33609, 35237,  3964,
#         18132, 21743, 24015,  8287, 26655, 38034, 29047, 33609, 16196, 17632,
#         24591, 31970, 26384,  2497,  2653, 25673,  9591, 27139, 33609, 20824,
#          6454, 30978, 33609, 25673, 30417, 24591, 23538,  4250, 14348, 36197,
#         25673,  3964,  5011, 34732, 20266,  6692, 24363,  9381, 33609, 21774,
#         15893, 34140, 29367, 31343, 12555, 37638,  8688, 23538, 30629, 29367,
#         21447, 18101, 26895, 29047,  2653, 31176, 28677,   539, 29246, 29367,
#         24591, 30306, 29367, 38027,  3791, 25673, 12555, 10627, 17632, 34298,
#         37269, 19845, 35930, 33609, 25673, 38402, 12555, 13810, 10964, 33979,
#         10323,  8347, 27974, 30580,  2497, 17737,  3633, 37787, 33609, 12555,
#         11728, 33930,   726, 25073, 33609, 34298, 31058, 13752, 12278, 19203,
#         23922, 18366,  3633, 11424, 38830, 35792, 12256,   892, 23178, 38830,
#          3964,   193, 35370, 31702, 30116, 24679, 33609, 32963, 25673, 28628,
#         12682, 20629, 20266, 33722, 17337, 21447,  2497,  6743, 37239,  8688,
#         12271, 33609, 10458, 19014, 27215, 11975, 14159, 10627, 11728, 32093,
#         29424, 22617, 24591, 12971, 36686, 18691,  3964,  5564, 33593, 21743,
#         35887, 25673,  8688, 35887, 35640, 17991,  8688, 38265, 26610, 28716,
#         21786,  1687,  8688, 25673, 13581, 17632, 33640,  3422, 23961,  9215,
#         21708, 24335, 24591, 37940,  8055, 33635, 28677, 21888,  2339, 29047,
#          7885, 23538,  1793, 33609,  8688, 37723, 17632, 29903, 33609,  2780,
#         18782, 20871, 18101, 17232, 29367, 23894, 21417,  1437,  2494, 25437,
#         14762, 18101, 21447, 33449,  3005,  2497, 28558, 17632,  5496, 12396,
#         18101, 29367, 12555, 37568,  3964,  4785, 32963, 33609, 29367,  2497,
#         23538, 15863,  1006, 12555, 13069, 37940,  8688,  2497, 29367, 29367,
#         19419, 20266, 23538, 38830,  2760, 20266, 20266, 12555, 29367, 17780,
#         33488, 29367,  2497, 33979, 18657,  6933, 29367, 25178, 12555, 13352,
#         12555,  7364, 17632, 31151, 21447,  8688, 23538, 12769,  8688, 19727,
#         18101, 33609,  9215, 36661, 20266, 25673, 21252, 31513, 33979,  5364,
#         19707, 20266, 34244, 12990, 15108,  2653,   242, 10723,  9215, 29367,
#         12555, 39128, 12691, 30027, 29367, 38830, 29367,   735, 29367, 19527,
#         33640, 33609, 13826, 22750, 29102, 15679, 30718,  7165, 15394, 27797,
#         30417,  8604, 15775, 34953,  2497, 21743, 13628, 29367, 38834, 30439,
#         17751, 37351,  4287, 29047, 34808, 38401, 12555, 22920, 33609, 30894,
#         14805, 33609, 33529, 32225,  3964, 16513, 13626, 13529, 30841,  5790,
#         37239, 16513, 38897, 28882, 12263, 34125,  6398,  8462, 33610, 28610,
#         26500, 22061, 12555,  3005,   372, 31247, 10627, 14628, 20266, 15785,
#         22061, 30417, 18273, 33837, 17892, 29836, 16925,  2653, 30417, 25775,
#         24406, 11409, 17632, 17777, 27139, 38925, 25289,   650, 21447, 32206,
#         20266, 10299, 33609, 18773, 12555,  5843, 32963, 25673, 13898, 30417,
#         24591, 31343, 30894, 12555, 20904, 20266, 22750,  8306,  8688, 26274,
#         17632, 19037, 15394, 21474,  3005, 34298, 30978, 33609, 23291, 10627,
#         12990, 14006,  7787, 29075, 19500, 34465, 24591, 25673, 33807, 33609,
#         17632,  6350, 27957, 29367, 17632, 17632, 25832, 29367, 15394, 14983,
#         28797, 29367, 25890, 37568,  2641, 31151,  6178, 32058, 13382, 23538,
#         22920,  1246,  1399,  8389,  4749, 25178, 12555, 36631, 32779, 20609,
#         16069,  1883, 30894, 17363,  5282, 33979, 30894, 33609, 12555, 36802,
#         13382,  6524, 29686, 11017, 30894, 22920, 17632, 30417, 33979, 12769,
#         33979, 30894, 28363, 12555, 22920, 29367, 32963, 12555, 17632,  8688,
#         25354,  2653, 19037, 33609, 30634, 20266, 12365, 38056,  3078, 32685,
#         21743,  1938, 25400, 24591, 33609, 31539, 30769, 16513, 15220, 10731,
#         39567,   510, 30978, 27039, 12555, 25673, 23538, 20266, 12555,   892,
#         22920, 16298,  1978, 22920, 12555, 33609, 19255, 31169, 34225, 26284,
#         28635, 18677, 31491,  2497,  2497,  6976, 30894, 38492,  8448, 17632,
#         29367,  6017, 29367, 35887,  8688,  3964, 30894,  7230, 15939, 16513,
#         18101, 29367, 21447,  5649,  4374,  9215, 13894, 20021, 12073,  8976,
#          1934, 34472, 22497, 21786,  6986, 33979, 23922, 22447, 35137, 33609,
#         12981, 31815, 33979, 16069,   826, 30894, 29367, 37974, 33979,  6378,
#          9334, 25673, 10627,  9838, 17632,  2653, 20266, 12555, 29560, 12555,
#          8688, 32331, 33710, 33530, 35422, 36375, 37928, 18293, 20266,  3742,
#         33609, 29367, 12891,  4031, 38830, 25673, 29367,  4981, 38591, 38972,
#         35369,  8688,  3938, 15346, 13072, 17632,  5241, 10660,  2929, 33164,
#         33850, 29367, 33609,  7448,  6141, 39213,  6141, 25178, 29367, 29367,
#          2497, 12555, 25811, 36750, 32598, 25673, 30417, 31151, 29367, 17689,
#         25263, 12555,  2497, 23589, 17632, 26145,    77, 12555, 12769, 33979,
#         18270, 21539,  7471, 17632, 37239, 33609, 36686, 21292, 18101,  9030,
#          2734, 17632,  8688, 32642, 29270, 36071, 26384, 29047, 13364,  7885,
#         12555, 34265, 21743, 30894, 20266, 24591, 37568, 20040, 29367,  1307,
#         24034, 29367, 14603, 12769, 32715, 21940, 26679, 15863, 18771, 24244,
#          2497, 36686,  5280,  5612, 17332,  8990, 33609, 20266, 11384, 25673,
#         22358, 38983, 32963, 12268, 33609,  5294,  6141, 33609, 16513,   648,
#          9110, 29047, 16513, 17632, 38830, 28154, 29367,  4763, 24591, 20266,
#          2653, 33979, 29367, 26284, 31151, 36375, 13937, 17632,  2255, 19113,
#           905, 29367,   383,  9591, 37127,  4591, 10627, 30894, 26944, 15753,
#         34507, 12555,  3005, 30894, 20266, 34298, 29360, 16513, 25462, 24591,
#         18101, 15569, 12555, 19794, 38404, 25673, 16513,  2274, 25673, 30439,
#         10627, 32963, 20371, 25673,  3017,  6177,  2497, 34743, 16069, 33609,
#          3964, 33609,  8688, 24363, 12555, 20798, 30417, 25877, 12555, 29047,
#         33609, 31115, 39403, 14532, 33979,  9107, 18101, 12469, 10660, 16555,
#         34135, 29047, 21743, 38911, 26406,  5742, 27139,  5627,  2182, 27235,
#         17332, 12555, 33609, 33609, 30894, 25673, 22279, 12555,  7871, 23729,
#         20266,  7384, 17632, 17632, 24400, 17899, 10946, 20850,  5496, 30550,
#          3005,  6440, 22920, 33979, 12555, 18101, 10660, 35071, 17332,  7836,
#         20277, 22008,  2541, 33508,  2497, 29819, 16513, 26927,  8688, 30894,
#         25673, 19507, 33543, 17632, 28055, 34507, 20266, 30894, 24679, 30417,
#          8688, 25673, 32165, 12555,  3561, 20450, 29047,  8031,  6217, 29367,
#          8688, 26076,  7497,  5814,  7885, 29367, 14128, 20266, 20266,   330,
#         24771,  8688, 34520, 15945, 29367, 21717, 30661,  7344, 35823, 33609,
#         20266, 25673, 14853,  8688,  1368,  6746, 34298, 23110, 29367,  2497,
#         33609, 29799,  8688, 36562,  7850, 25331, 30909, 29367, 31037, 29367,
#         29047, 35656, 28309, 24868, 12968, 22920, 26405, 27804,  2497, 22920,
#         38265, 14361, 34298, 34466,  4535, 27566, 30417, 35618, 10627, 37239,
#         35958, 25673,  5496, 36321, 23937, 33609, 19465, 17632, 31855, 30978,
#         29047, 12891, 33110,  2261, 31343, 21886, 35099, 37568, 30894, 30894,
#         24591,  9838, 24656,  2653, 18566, 12769, 24591, 32890, 26553,  2653])
# ["l'", 'objectiu', 'de', 'cobrir'] les
# ['<s>', "L'", 'empresari', 'va'] ser
# ['discurs', 'que', 'més', 'els'] ha
# ['fraccionar', "'", 'el', 'projecte'] de
# ['llicència', 'de', 'coraller', 'a'] les
# ['<s>', 'Un', 'sisè', 'afectat'] va
# [',', 'estan', 'escrits', 'en'] català
# ['que', 'ha', 'fet', 'que'] es
# ['ha', 'reconegut', 'la', 'formació'] com_a
# ['Lliga', '</s>', '<s>', 'Aquest'] partit
# ['trametrà', "l'", 'informe', 'al'] Defensor_del_Pueblo
# ['en', 'el', 'cas', 'de'] la
# ['A', 'la', 'reixa', 'ahir'] no
# ['que', 'hauria', 'insinuat', 'que'] es
# ['han', 'assistit', 'a', "l'"] acte
# ['actituds', 'que', 'al', 'final'] comporti
# ['la', 'recuperació', "d'", 'unes'] antigues
# ['Als', 'Alps', ',', 'el'] vent
# [',', 'entitat', 'que', "s'"] ha
# ['<s>', "D'", 'altra', 'banda'] ,
# ['de', 'Girona', 'per', 'falta'] d'
# ['que', "l'", 'any_1990', 'van'] pintar
# ['convençut', 'que', 'aquesta', 'tendència'] a
# ['al', 'temple', '</s>', '<s>'] El
# ['la', 'patia', "s'", 'havia'] de
# ['el_seu', 'compromís', 'amb', 'dos'] vessants
# ['concretar', '-se', 'en', '553'] persones
# ['Esteve_Vilanova', "'", 'es', 'vol'] fer
# ['normal', ',', "s'", 'està'] parlant
# ['"', 'Hi', 'ha', 'guerres'] ,
# ['ser', 'editor', 'del', 'butlletí'] de
# ['usuaris', '</s>', '<s>', 'La'] nova
# ['al', 'grup', 'financer', 'català'] el
# ['van', 'augmentar', 'un', 'després'] que
# ['<s>', 'Lluís_Gavaldà', 'va', 'dimitir'] a
# ['Enric_Ezquerra', ',', 'director', 'general'] de
# ['anglesa', ',', 'el', 'príncep'] Eduard
# ['la', 'recollida', 'de', 'petroli'] a
# ['en', 'el', 'futur', 'un'] progrés
# ['política', 'econòmica', 'i', 'social'] del
# ['crònica', ',', 'el', 'retrat'] i
# [',', 'una', 'zona', 'de'] caràcter
# ['aquest', 'matí', "l'", 'acte'] de
# ["Museu_d'_Arqueologia_de_Catalunya", 'mostra', 'els', 'aspectes'] que
# ['un', 'particular', 'i', 'sentit'] homenatge
# ['supera', 'els', 'vint', 'infants'] el
# ['tenia', '13', 'anys', ','] segons
# ['de', 'les', 'disposicions', 'legals'] relatives
# ['i', 'el', 'Vallès_Oriental', '</s>'] <s>
# ['país', "'", 'com_a', 'centre'] cultural
# ['nacional', "d'", 'una', 'altra'] manera
# ['aquest', 'retorn', 'documental', '</s>'] <s>
# ['un', 'acte', 'que', 'ha'] qualificat
# ['del', 'Canadà', 'i', 'Holanda'] compren
# [',', 'a', 'casa', "'"] </s>
# ['la', 'freqüència', 'amb', 'què'] portava
# ['Barcelona', 'amb', 'sabor', ','] amb
# ['passat', 'a', 'costar', '825'] pessetes
# ['tornar', '-les', 'a', 'repetir'] </s>
# ['dóna', 'més', 'força', 'a'] l'
# ['ja', 'expressada', 'altres', 'vegades'] que
# ['com_a', 'candidat', ',', 'com'] encara
# ['se', "'l", 'disputaven', 'per'] omplir
# ['és', "l'", 'enemic', 'a'] batre
# ['paella', 'i', 'una', 'exhibició'] de
# ['ciència', '</s>', '<s>', 'Per_últim'] ,
# ['2', 'al', '8_per_cent', 'i'] hem
# ['ha', 'enfortit', 'la', 'programació'] de
# ['<s>', 'El', 'servei', 'de'] FCG
# ['La', 'mobilització', 'per', 'dir'] "
# ['empreses', 'adjudicatàries', 'de', "l'"] Ajuntament
# ['sector', 'de', 'les', 'comunicacions'] es
# ['i', 'Sabin_Intxaurraga', 'Justícia', ','] Inaxio_Oliveri
# ["'", 'és', "l'", 'ideal'] mentre
# ['revitalitzar', 'el', 'moviment', 'associatiu'] dins
# ['informatius', 'amb', 'la', 'marca'] Antena_Local
# ['El', 'vaixell', ',', 'carregat'] amb
# ['mestra', 'consola', 'una', 'nena'] de
# ['disposarà', 'ara', 'de', 'dues'] oportunitats
# ['no', 'és', 'menys', 'contundent'] </s>
# ['La', 'pitjor', 'part', 'de'] les
# ['el', 'moment', 'de', 'la'] detenció
# ['que', "s'", 'haurien', 'extingit'] abans
# [',', "l'", 'ètica', 'i'] la
# ['1957', '</s>', '<s>', 'Sempre'] ha
# ['<s>', 'Els', 'sindicats', 'CCOO'] i
# ['a', 'la', 'junta', "d'"] accionistes
# ["a_conseqüència_d'", 'una', 'mala', 'gestió'] o
# ['ha', 'referit', 'al', 'dèficit'] de
# ['</s>', '<s>', '"', 'Aquesta'] ofensiva
# ['augment', 'no', 'és', 'estadísticament'] significatiu
# ['"', 'perquè', 'penso', 'que'] és
# ['és', 'de', '98', 'milions'] de
# ["l'", 'abast', "d'", 'estudiosos'] i
# ['sis', 'mesos', 'de', 'presó'] un
# ['reiterat', 'que', 'el_seu', 'pare'] les
# ['acordar', 'excloure', 'la', 'professora'] del
# ['Juli_Panyella', ',', 'tot_i_que', 'cap_als'] setanta
# ['amb', 'el', 'PP', ','] Piqué
# ["d'", 'ETA', '</s>', '<s>'] Ara
# ["d'", 'una', 'transferència', 'bancària'] i
# [',', 'no', 'sóc', 'així'] "
# ['la', 'Presa', 'i', 'el'] recent
# ['de', 'canvi', ',', 'va'] afegir
# ['orienta', 'ara', 'a', 'demostrar'] que
# ['que', 'estigui', 'més', 'a'] Madrid
# ['Sito_Pons', 'anunciarà', 'avui', 'que'] el_seu
# ['amb', 'Roman_Luknár', 'una', 'nova'] versió
# ['espanyol', 'i', "l'", 'estacionalitat'] de
# ['tècnic', 'del', 'Mèrida', 'aquesta'] temporada
# ['UDC', ',', 'i', 'ha'] afirmat
# ['de', 'programes', 'musicals', 'a'] Televisió_Espanyola
# ['<s>', 'Entre', 'els', 'famosos'] ,
# ['sobre', "l'", 'estratègia', ','] s'
# ['el', 'proper', 'mes_de_novembre', '</s>'] <s>
# [',', 'que', 'va', 'pujar'] fins_a
# ['paritat', 'amb', 'el', 'dòlar'] el
# ['a', 'honorar', 'la', 'memòria'] del
# ['24.000', 'persones', 'i', 'que'] compten
# ['a', "l'", 'espai', 'que'] ,
# ['Segons', 'han', 'informat', 'avui'] els
# ['globus', ',', 'un', 'circuit'] d'
# ['quan', 'dos', 'vehicles', 'han'] sortit
# ["d'", 'una', 'escultura', 'feta'] amb
# ['El', 'director', 'del', 'Festival_de_Cinema_de_Girona'] ha
# ['<s>', 'Pels', 'regants', 'és'] inadmissible
# ['que', 'els', "'", 'bons'] resultats
# ['amb', 'el', 'PSOE', 'el'] 1993
# ['a', 'la', 'clínica', 'del'] traçat
# ['el', 'desenvolupament', 'econòmic', 'local'] ,
# ['en', 'català', ',', 'de'] les
# ['fills', "d'", 'una', 'gran'] il·lusió
# ['En', 'aquesta', 'tercera', 'edició'] ,
# ['Ajuntament_de_Manlleu', 'clourà', 'demà', 'el'] curs
# ['Audiència_de_Barcelona', ',', 'i', 'els'] joves
# ['comès', 'un', 'error', 'polític'] i
# [',', 'informa', 'Ana_Garbati', '</s>'] <s>
# ['principi', ',', 'serà', 'només'] per
# ['procedent', 'del', 'principat', 'monegasc'] </s>
# ['pel', 'PSOE', '</s>', '<s>'] El
# ['Cúpula_del_Mil·lenni', '-', 'convertirà', 'el'] parc
# [',', 'i', 'en', 'va'] destacar
# ["d'", 'art', 'a', "l'"] Escola_d'_Art_de_la_Diputació_a_Reus
# ["Regidoria_de_l'_Àmbit_de_la_Dona", 'i', 'la', 'Policia_Local'] de
# [',', 'Bèlgica', ',', 'Holanda'] i
# ['el', 'control', 'de', 'la'] via
# ['amb', '15.500', 'pessetes', '</s>'] <s>
# ['les', 'esmenes', 'que', 'pugui'] presentar
# ['ha', "darrere_d'", 'aquesta', 'exquisida'] desinformació
# ['pot', 'causar', 'canvis', 'en'] l'
# ['com', 'el', 'dilema', 'del'] presoner
# ['Sogecable', ',', 'que', 'va'] retrocedir
# ['carrera', '</s>', '<s>', 'La'] carrera
# ["l'", 'Interior', 'de', 'la'] maledicció
# ['catalana', 'Rosa_Regàs', 'ha', 'guanyat'] la
# ['anys', '</s>', '<s>', 'Boada'] sap
# ['i', 'encara', 'en', 'vol'] eliminar
# ['les', 'dues', 'parts', 'tenia'] raó
# [',', 'coordina', "l'", 'actuació'] de
# ['de', 'la', 'comarca', '</s>'] <s>
# [',', 'ja_que', "s'", 'ha'] tancat
# ['el', 'dia_23_de_juliol', 'el', 'cantautor'] canari
# [',', 'ja_que', 'al', 'Parlament'] actual
# ["'", 'vol', 'ser', 'una'] Fira
# ['procés', "d'", 'introducció', 'física'] de
# ['estalvi', 'cauen', '</s>', '<s>'] El
# ['al', 'matrimoni', 'format', 'per'] Antonia_P._Z
# ['"', 'La', 'voluntat', 'popular'] està
# [',', 'ni_molt_menys', ',', "d'"] arreglar
# ['ahir', '</s>', '<s>', 'Per'] la_seva
# [',', 'segons', 'va', 'informar'] ahir
# ['de', 'les', 'previsions', 'del'] Govern_de_l'_Estat
# ['de', 'capital', ',', "per_tal_d'"] eliminar
# ['el', 'missatge', 'que', 'Pep_Sala'] vol
# ['CES', 'aprofitarà', "l'", 'entrada'] al
# ['viabilitat', "d'", 'una', 'piscina'] coberta
# ['del', 'Cap_de_Creus', '</s>', '<s>'] Es
# [',', 'per', 'a', 'ell'] serà
# ['inconcrets', '"', '</s>', '<s>'] Dolores_Vázquez
# ['a', 'la', 'nit', ','] al
# [',', 'meres', '"', 'exageracions'] "
# ['treballar', 'coordinadament', 'i', "d'"] implicar
# ['propiciar', 'una', 'mena', 'de'] partits
# ["l'", 'aixeta', 'de', 'la'] gasolina
# ['</s>', '<s>', 'El', "'"] The_Emerald
# ['<s>', 'És_a_dir', ',', 'que'] encara_que
# ['van', 'ser', 'Juan_Aguilera_González', ','] de
# [',', 'Civit', 'ha', 'destacat'] '
# ['és', '"', 'més', 'internacional'] i
# ['FMI', 'va', 'aprovar', 'ahir'] formalment
# ['empresonat', 'per', 'les_seves', 'opinions'] subversives
# ['prosperi', ',', 'Carod', 'espera'] comptar
# ['IC-V', 'va', 'afirmar', 'ahir'] que
# ["l'", 'accés', 'a', 'la'] Xarxa
# ['se', 'sap', 'com', 'van'] travessar
# ['pessetes', 'per', 'poder', 'començar'] els
# ['Alemanya', ',', 'que', 'és'] la
# ['les', 'delegacions', 'negociadores', 'i'] òrgans
# ['8_de_la_tarda', '</s>', '<s>', "D'"] aquesta
# [',', 'apunta', 'Moya', ','] el
# ["d'", 'exposició', '</s>', '<s>'] Per
# ['sobresortir', 'pel', 'seu', 'domini'] de
# [',', 'al', 'ministeri', 'de'] Foment
# ['el', 'nombre', "d'", 'intervencions'] quirúrgiques
# ['certa', 'relació', 'amb', 'la'] feina
# ['dia', ',', 'per', 'als'] mitjans
# ['de', 'fred', 'causa', 'molts'] incendis
# ['durant', 'el', 'primer', 'trimestre'] per
# ['<s>', 'El', 'Palacio_Balañá', 'ha'] tancat
# ['poeta', ':', 'M._Lluïsa', ','] M._Antònia
# ['del', 'Partit_Popular', 'que', 'feia'] referència
# ['a', 'les', 'empreses', 'de'] serveis
# ['altres', 'temes', 'abans', 'que'] les
# ['oportunitat', 'des_del', 'punt', 'de'] vista
# ['ser', 'com', 'Biaggi', 'va'] aconseguir
# ['va', 'néixer', 'amb', 'un'] capital
# ['i', "l'", '11_de_desembre', 'seran'] "
# ['públic', 'avui', ',', 'Ciments_Molins'] assenyala
# ['capacitat', "d'", 'aglutinar', 'molta'] gent
# ['les', 'protestes', 'si', 'no'] es
# ['de', 'la', 'Noguera', ','] sinó
# ['la', 'cúmbia', 'al', 'rock'] i
# ['i', 'la', 'URV', 'signat'] el
# ["Terres_de_l'_Ebre", 'a', 'provocar', ','] sinó
# [',', 'els', 'governs', 'occidentals'] van
# [';', 'Viscofán', ',', 'el'] 7,69%
# ['de', 'consistir', "'", 'en'] el
# ['escullera', 'de', 'la', 'darrera'] part
# ['zona', 'abdominal', 'de', "l'"] espectador
# ['capaç', 'de', 'forjar', 'aquest'] consens
# [',', 'perquè', 'els', 'moviments'] contra
# ['dòlars', ',', 'enfront_de', 'les'] 0,852
# ['ha', 'presidit', 'aquest', 'migdia'] el
# [',', 'Peter_Maag', 'o', 'Lukas_Foss'] i
# ['hem', 'acostumat', 'a', 'la'] mirada
# ["'", 'de', "l'", 'Eix_Diagonal'] </s>
# ['Barcelonès', "'", '</s>', '<s>'] La
# ['el', 'director', ',', 'de_manera_que'] havia
# ['Embil', ',', 'Arteaga', ','] Riezu
# ["l'", 'alliberament', 'de', 'dos'] dels
# ["l'", 'acte', 'administratiu', 'ara'] anul·lat
# ['en', 'el', 'qual', 'hi'] treballaran
# ['policia', 'autonòmica', 'basca', ','] les
# ['va', 'assenyalar', '</s>', '<s>'] I
# ['consultes', 'i', 'presenta', 'millores'] tècniques
# ['</s>', '<s>', 'Amb', 'la'] decisió
# ['accidents', 'de', 'trànsit', 'amb'] resultats
# [',', 'nosaltres', 'donarem', 'per'] finalitzada
# ['Gumersind', 'que', 'és', 'el'] president
# ['un', 'cas', 'claríssim', 'relacionat'] amb
# ['"', 'el', 'consum', "d'"] aquestes
# ['comptarà', 'amb', 'la', 'intervenció'] del
# ['482', 'habitacions', 'i', '38'] apartaments
# ['esmenes', 'que', "s'", 'han'] de
# ['<s>', 'El', 'Premi_Prudenci_Bertrana', ','] el
# ['de', 'CiU', 'és', 'continuar'] incidint
# ['rem', 'de', 'la', "Universitat_d'_Oxford"] </s>
# ['garanteix', 'sempre', 'la_seva', 'adequada'] subjecció
# ['i', 'delegat', 'del', 'govern'] de
# [',', '6-1', ';', 'i'] Alberto_Martín
# ['pròxim', 'sis_de_juny', '</s>', '<s>'] Òmnium_Cultural
# ['caça', 'i', 'captura', "d'"] alguna
# ['les', 'actuals', 'tendències', 'jazzístiques'] d'
# ['assegura', 'que', '"', 'el'] gruix
# ['125', 'anys', 'de', 'representacions'] ,
# ['començar', 'a', 'cridar', '"'] proclamant
# ['hi', 'ha', 'mitjans', 'que'] ens
# ['hi', 'surtin', 'inclosos', 'puguin'] reclamar
# ['Actualment', ',', 'tan_sols', 'el'] 30%
# ['</s>', '<s>', 'El', '3r'] Encontre
# ['Segòvia', ',', 'fins_a', 'les'] grans
# ['hi', 'participaran', 'organitzacions', 'agràries'] d'
# ['competència', 'podria', 'fer', 'baixar'] els
# ['uns', '25', 'quilòmetres', 'quadrats'] engloba
# ['es', 'va', 'disparar', "l'"] any
# ['director', 'de', 'cinema', 'amb'] la
# ['dies', '</s>', '<s>', 'El'] preu
# ['de', 'la', 'mateixa', 'Agència_Tributària'] </s>
# ['la', 'política', ',', 'però'] quan
# ['constants', 'com', "'", 'et'] tallaré
# ['<s>', 'El', 'portaveu', 'parlamentari'] d'
# ['El', 'diputat', "d'", 'ERC'] ,
# ['direcció', "d'", 'Iberpotash', '</s>'] <s>
# ['un', 'gran', 'feeling', 'i'] una
# ["l'", 'existència', "d'", 'un'] "
# ['té', 'previst', 'rehabilitar', 'i'] condicionar
# ['assenyala', 'que', 'els', 'empleats'] '
# ['preparació', 'de', "l'", 'ordre'] de
# ['inevitable', '"', "l'", 'aturada'] ,
# ['que', 'analitzarà', 'en', 'profunditat'] la
# ['de', "l'", 'Havana', 'i'] del
# ['fins', 'arribar', 'a', 'les'] zones
# ['el', 'creixement', 'de', "l'"] ocupació
# ['locals', 'i', 'bars', '</s>'] <s>
# ['la', 'restauració', 'de', 'la'] Sala_Associativa_Cultural_i_Recreativa
# ['Tercer_Món', '</s>', '<s>', '...'] I
# [',', 'on', 'està', 'situat'] el
# ['El_lápiz_del_carpintero', '</s>', '<s>', 'Explica'] la
# ['desaprofitar', 'una', 'ocasió', 'm_._48'] ,
# ['El', 'Subdelegat_del_Govern', ',', 'Raúl_Navarro'] ,
# ['aquests', 'municipis', 'i', 'que'] ja
# ['les', 'persones', 'immigrades', ','] que
# ['</s>', '<s>', 'Els', 'tècnics'] del
# ['producció', 'industrial', 'als', 'EUA'] al
# ['diaris', '</s>', '<s>', 'A'] La_Vanguardia
# ['representa', '"', 'una', 'figura'] que
# ['en', 'el_seu', 'informe', 'anual'] que
# ['importants', 'del', 'món', '</s>'] <s>
# ['eren', 'veïns', 'de', 'Premià_de_Mar'] ,
# ['formar_part', "d'", 'Unión_Explosivos_Río_Tinto', ','] Ercros
# ['</s>', '<s>', 'Santiago_Álvarez', ','] històric
# ['desviació', 'de', 'la', 'naturalesa'] ,
# ['En', 'el', 'balanç', 'de'] la
# ['a', 'la', 'credibilitat', 'de'] l'
# ['dir', ',', 'entre', 'altres'] coses
# ['actual', '</s>', '<s>', 'El'] llibre
# ['aparegut', 'públicament', 'al', 'desembre'] ,
# ['és', 'la', 'del', 'satèl·lit'] perquè
# ['grup', 'a', 'Madrid', '</s>'] <s>
# ['jugadors', 'davant', 'el', '23'] blau
# ['del', 'pròxim', 'judici', '</s>'] <s>
# [',', 'Costa_Rica', ',', 'un'] 224_%
# ['policials', 'o', 'de', 'bombers'] </s>
# ['ja', 'va', 'presentar', 'fa'] més
# ['en', 'nombrosos', 'assumptes', 'durant'] els
# ['compliments', '</s>', '<s>', 'Un'] el
# ['<s>', 'És', 'el', 'moment'] del
# [',', 'els', 'fets', "s'"] han
# ['els', 'projectes', ',', 'com'] el
# ['que', 'també', 'van', 'quedar'] afectats
# ['<s>', 'Un', 'escrit', '"'] d'
# ['sap', 'que', 'és', 'deutor'] de
# ['diàleg', 'amb', 'els', 'representants'] dels
# ['aquesta', 'nit', 'al', 'Morell'] Tarragonès
# ['primmirat', 'amb', 'projectes', 'municipals'] que
# ['ofereixen', 'els', 'documentals', 'Insectos_en_sociedad'] i
# ['Puccini', '</s>', '<s>', 'El'] concert
# ['conjunt', 'de', 'dirigents', ','] regidors
# ["l'", 'Estat', 'presentades', 'per'] l'
# ['tres', 'llargmetratges', 'que', 'han'] presentat
# ['en', 'la', 'fase', "d'"] atenció
# ['fiscalia', ',', 'això', 'fa'] que
# ['del', 'PSC', "s'", 'ha'] mostrat
# ['del', 'franquisme', '-', 'el'] consistori
# ['dels', 'quals', 'un', "s'"] emportarà
# ['els', 'ducados', 'que', "s'"] ha
# ["l'", 'Audiència', "s'", 'ha'] fet
# ['es', 'prenen', "al_voltant_d'", 'una'] taula
# ['Insisteixo', 'en', "l'", 'eficàcia'] dels
# ['Després', 'de', 'la', 'programació'] ,
# ['gent', 'no', 'entendrà', '</s>'] <s>
# ['dirhem', ',', 'viatjar', 'al'] Marroc
# ['2000', 'i', "'", "Galceran_,_l'_heroi_de_la_guerra_negra"] Columna-Proa
# ['diputat', 'al', 'Congrés', 'per'] Iniciativa_per_Catalunya-Verds
# ['<s>', 'Segons', 'els', 'investigadors'] ,
# ['que', 'es', 'van', 'presentar'] al
# ['deixar', ',', 'fa', 'anys'] ,
# ['"', '</s>', '<s>', 'El'] ministre
# ['Olga_Ros', 'durant', 'dos', 'anys'] ,
# ['del', 'jurat', 'i', 'es'] lliuraran
# ['Iugoslàvia', '</s>', '<s>', "'"] La
# [',', "des_d'", 'un', 'punt'] de
# ['les', 'dotze_del_migdia', 'de', 'la'] plaça
# [',', 'va', 'presentar', 'al'] seu
# ['poder', 'per', 'a', "l'"] Executiu
# ['hospitalaris', 'i', 'ha', 'seguit'] tractaments
# ['del', 'Consorci_de_Promoció_Econòmica_de_la_Paeria', '</s>', '<s>'] Aquesta
# ["s'", 'impartiran', 'durant', 'el'] mes_de_juliol
# ['que', 'no', 'precisa', 'descodificador'] ja_que
# ['torn', 'del', 'creuer', "'"] Adriana
# ['formació', 'bíblica', 'sòlida', 'i'] un
# ['de', "l'", 'anunci', 'del'] Govern
# ['les', 'cartes', 'fins', 'a'] última
# ['tan', 'genial', '</s>', '<s>'] Espanya
# ['del', 'fiscal', 'David_Martínez_Madero', 'demanava'] la
# ['canalització', 'del', 'torrent', 'executades'] es
# ['i', "l'", 'autonomia', 'del'] pacient
# ['situació', 'de', 'mort', 'cerebral'] ,
# ["L'", 'altre', 'moviment', 'integrista'] radical
# ['<s>', 'La', 'Generalitat', 'donarà_suport'] als
# ['les', 'associades', 'a', "l'"] AMEC
# ['<s>', 'De_tota_manera', ',', "l'"] Ajuntament_de_Vilafranca
# ['la', 'Conselleria_de_Medi_Ambient', ',', "s'"] hauria
# ['de', 'la', 'construcció', 'nacional'] amb
# ['escriptura', '</s>', '<s>', 'Triadú'] tenia
# ['estrangers', 'a', 'qui', 'cobrava'] diverses
# ['PP', 'i', 'PSE', '</s>'] <s>
# ['actitud', 'de', 'Mayor', 'i'] va
# ['que', 'en', 'el', 'sector'] de
# ['per', 'a', 'la_seva', 'distribució'] a
# ["d'", 'okupes', ',', 'ha'] perdut
# ['publicar', "l'", 'obra', 'completa'] de
# ['que', 'el', 'vincle', 'entre'] ETA
# ['la_seva', 'degradació', '</s>', '<s>'] Sigui
# ['no', 'va', 'més', 'enllà'] "
# ['per', 'després', 'interpretar', '-les'] en
# ['Jaume_Jovells', '</s>', '<s>', 'Els'] organitzadors
# ['metges', 'que', 'dimarts', 'van'] intervenir
# ['el', 'blues', ',', 'el'] soul
# ['per', 'fer', 'poesia', ','] sinó_que
# ['deixalles', '</s>', '<s>', 'En'] aquesta
# ['que', 'la', 'immigració', 'té'] en
# ['la', 'ciutat', ',', 'tenint_en_compte'] aspectes
# ['home', 'va', 'augmentar', 'el'] consum
# ['245', 'de', 'la', 'llei'] orgànica
# ['itinerants', 'que', 'té', 'com_a'] objectiu
# ['les', 'oficines', ',', 'he'] seguit
# ['des_del', 'Baixador', 'i', 'de'] Manresa_Alta
# ['nostàlgic', ',', 'buscant', 'referents'] comuns
# ['temàtics', 'Media_Park', "s'", 'ha'] integrat
# ['300.292,9', 'milions', 'de', 'pessetes'] 1.804,7
# ['que', 'van', 'provocar', 'la'] mort
# ["Centre_d'_Iniciatives_per_a_l'_Ocupació", 'de', 'Casa_Caritat', '</s>'] <s>
# ['i', 'octubre', 'del', 'mateix'] any
# ['bolígraf', 'Inoxcrom', '-', 'el_seu'] nom
# ['tèrmica', 'que', 'Gas_Natural', 'té'] previst
# ['Galilea', ',', 'nosaltres', 'donarem'] per
# ['Martín', 'no', 'es', 'va'] acostar
# ['Universitat_Pompeu_Fabra', 'Fèlix_Riera', ',', 'la'] que
# ['valors', '</s>', '<s>', 'Segons'] Carod
# ['països', '</s>', '<s>', 'La'] mort
# ['horari', 'normal', 'només', 'obriran'] un
# ['-lo', '</s>', '<s>', 'El'] processat
# ['es', 'pronunciés', 'sobre', 'la'] constitucionalitat
# ['de', 'trens', 'amb', 'un'] import
# ['que', 'cal', 'portar', 'el'] gos
# ['pèrdua', 'de', 'lideratge', 'tant'] fort
# ['1996', '</s>', '<s>', 'Ridao'] ha
# ['sentir', 'la', 'falta', "d'"] un
# ['es', 'va', 'referir', 'al'] Bloc_Nacionalista_Galego
# ['que', 'les', 'negociacions', 'seran'] llargues
# ['per', 'al', 'personal', 'de'] distribució
# ['comissaria', 'del', 'districte', 'Horta-Guinardó'] </s>
# ['població', ',', 'hi', 'ha'] afectades
# ['i', 'només', 'el', 'Barcelonès'] o
# ['ha', 'donat', 'a', "l'"] Ajuntament_de_Monistrol
# ['</s>', '<s>', '"', 'Vaig'] arribar
# ['obligarà', 'a', 'cancel·lar', '238'] vols
# ['de', 'Súria', ',', 'especialment'] els
# ['la', 'més', 'elevada', 'aconseguida'] mai
# ['</s>', '<s>', 'Els', 'cursos'] que
# ['amb', 'dos', 'carrils', 'de'] circulació
# ['Riet-Havana', 'rep', "l'", 'aportació'] de
# ['cristallina', '/', 'de', 'vostra'] capella
# ['comencem', ',', 'millor', '</s>'] <s>
# ['anuals', "'", 'per', 'un'] nou
# ['tenen', 'dificultats', 'per', 'treballar'] '
# ['impactes', 'econòmics', ',', 'socials'] i
# ['de', "l'", 'A-7', 'sentit'] nord
# ['origen', 'pakistanès', ',', 'conduïa'] un
# ['perifèries', 'urbanes', 'i', 'a'] les
# ['inscripcions', 'abans', 'del', '18_de_juny'] s'
# ['altres', 'són', 'els', 'germans'] a
# ['literària', 'dels', 'Països_Catalans', '</s>'] <s>
# ['1870-71', '</s>', '<s>', 'Deixà'] escrits
# ['fi', 'a', 'una', 'guerra'] que
# ['Història', ',', '"', 'pel'] seu
# ['la', 'persecució', "d'", 'un'] sindicat
# ['ho', 'entenguin', 'perquè', "'"] el
# ['Carles_Ocaña_Crespo', ',', 'veí', 'de'] Sabadell
# ['hi', 'vegi', 'forçat', '"'] </s>
# ['a', 'París', ',', 'ha'] explicat
# ['ahir', 'Ferguson', ',', '"'] ja_que
# ['doncs', ',', 'fer', 'comptes'] nous
# ['que', ',', 'com', 'cada'] any
# ['alta', 'velocitat', '</s>', '<s>'] El
# ['novament', 'que', 'el', 'CPIDE'] és
# ['de', 'la', 'secció', 'desena'] de
# ['significaria', 'per', "l'", 'acció'] política
# ['Insalud', 'o', 'el', 'pla'] per
# ['del', 'Barri_Antic', ',', 'el'] consistori
# ['ha', 'rebut', 'el', 'premi'] Crítica_Serra_d'_Or
# ['<s>', 'Les', 'projeccions', "d'"] aquests
# ['puja', 'exactament', 'a', '10.857.600'] pessetes
# ['cohesió', 'social', 'i', 'de'] justícia
# ['<s>', 'El', 'Barça', 'retorna'] avui
# ['situat', 'com', 'una', 'de'] les
# ['activitats', 'per', 'a', 'nens'] i
# ["'", '</s>', '<s>', "'"] Serà
# ['a', 'la', 'localitat', 'bosniana'] de
# ['exigir', 'que', "l'", 'acompanyés'] </s>
# ['a', 'captar', 'els', 'visitants'] finals
# ['recentment', 'com_a', 'festa', "d'"] interès
# ['per', '337', 'vots', 'a_favor'] ,
# ['Felip_Puig', ',', 'al', 'Palau_de_la_Generalitat'] </s>
# ['serveis', "d'", 'inversió', '"'] </s>
# ['al', 'Congrés', 'en', 'la'] qual
# ['borsa', '</s>', '<s>', 'Lagun_Aro'] ,
# ['de', 'tipus', 'mercantil', ','] ja_que
# ['la', 'feina', 'davant', 'la'] incertesa
# ['condicionat', ',', 'perquè', 'és'] allà
# ['de', 'lluita', 'de', 'classes'] ,
# [',', 'va', 'registrar', 'una'] aplicació
# ['Així_mateix', ',', 'es', 'demana'] una
# ['i', 'de', 'ficció', 'per'] crear
# ['</s>', '<s>', 'Les', 'ocupacions'] més
# ['les', 'alteracions', 'cardíaques', 'que'] sovint
# [',', 'una', 'llei', "d'"] incompatibilitats
# ["d'", 'aquestes', 'Jornades', ','] organitzades
# ['va', 'obrir', 'la', 'porta'] del
# ['De_fet', ',', 'la', 'policia'] va
# ['present', 'gira', 'europea', 'de'] Jones
# ['és', 'degut', 'a', 'la'] pervivència
# ['de', 'la', 'vialitat', 'del'] sector
# ['punt', 'segon', 'de', 'la'] votació
# ['decretada', 'per', 'aquest', 'ajuntament'] perquè
# ['coordinadors', 'i', 'organitzadors', '</s>'] <s>
# ['del', 'racisme', 'organitzat', 'i'] facilita
# ['tots', 'els', 'impostos', 'i'] se
# ['insinuen', 'possibilitats', 'concretes', 'que'] podrien
# ['vot', 'catalanista', ',', 'que'] no
# ["d'", 'aplicar', 'una', 'rebaixa'] selectiva
# ['pau', 'que', 'posaven', 'fi'] a
# ['i', 'transportistes', ',', 'els'] conflictes
# ["d'", 'escriptura', 'àrab', 'i'] asiàtica
# ['que', "s'", 'ha', 'begut'] l'
# ['la', 'denúncia', 'i', 'arribar'] a
# ['són', 'sis', 'les', 'persones'] de
# ['sostenible', 'dels', 'boscos', '</s>'] <s>
# ['els', 'altres', 'imputats', ','] qui
# ['participar', 'en', 'unes', 'jornades'] organitzades
# ['i', 'les_seves', 'dues', 'companyes'] estan
# ['<s>', 'La', 'necessitat', 'de'] disposar
# ['aeroports', 'espanyols', 'van', 'seguir'] patint
# ['majoria', 'per', 'qüestions', 'relatives'] a
# ["l'", 'Estat', 'espanyol', 'li'] va
# ['lluita', 'contra', 'els', 'transvasaments'] </s>
# ['exsecretària', 'i', 'querellant', 'per'] un
# ['de', 'plata', ',', 'amb'] l'
# ['cinc_de_la_matinada', 'i', 'els', 'interns'] han
# ['2,5', 'punts', 'més', 'que'] l'
# ['<s>', 'Un', 'home', 'assassina'] a
# [',', 'on', 'es', 'va'] explicar
# ['resistència', 'a', 'mossegades', '</s>'] <s>
# [',', 'quan', 'la', 'Generalitat'] va
# ['<s>', 'Els', 'usuaris', 'demanen'] ,
# ['qualifica', 'com_a', "'", 'incongruent'] '
# ['Estats_Units', 'i', 'Europa', '</s>'] <s>
# ['no', 'va', 'acceptar', "'"] </s>
# ['tren', 'Arco', 'que', 'feia'] el
# ['família', 'de', 'Ieltsin', 'i'] els_seus
# ['naixement', 'de', 'Salvador_Dalí', ','] ha
# ['transparent', '"', ',', 'ha'] explicat
# ['<s>', 'Però', 'la', 'imposició'] de
# ['per', 'accions', '</s>', '<s>'] Que
# ["d'", 'altres', '-', 'i'] que
# ['pitjor', 'part', 'de', 'les'] crítiques
# ['una', 'sala', 'de', 'poble'] costaner
# ['que', ',', 'malgrat', 'les'] discrepàncies
# ['dels', 'immobles', 'que', 'han'] quedat
# ['amb', 'PSC', 'i', 'IC-V'] es
# ['-lo', 'nerviós', '</s>', '<s>'] Però
# ['una', 'conferència', 'sobre', "'"] Jacint_Verdaguer_:_Un_home_difícil_,_un_escriptor_genial
# ['el', '4_de_febrer', ';', 'mentre_que'] les
# ['</s>', '<s>', 'Els', 'governs'] de
# ['quals', "s'", 'adequaria', 'al'] càrrec
# ['dir', 'amb', 'exactitud', 'quines'] dates
# ['grups', "d'", 'interès', 'majoritari'] en
# ['havia', 'als', 'centres', "d'"] ensenyament
# ['organitzava', 'el', 'pla', 'més'] aparatós
# ['convocaran', 'mobilitzacions', 'al', 'sector'] miner
# ['membres', 'de', 'la', 'guerrilla'] islàmica
# ['la', 'Costa_Brava', ',', 'que'] és
# ['¿', 'Potser', 'és', 'perquè'] Lleida
# ['Montjuïc', 'completament', 'ple', '</s>'] <s>
# ['la', 'que', 'vivia', ','] i
# ['a', 'la', 'primera', 'secretaria'] del
# ['assegurar', ',', 'al_seu_torn', ','] que
# ['de', '4.000', 'autònoms', '</s>'] <s>
# ['<s>', 'Alhora', ',', 'Brufau'] serà
# ['del', 'recital', 'que', 'Josep_Carreras'] va
# ['poblacions', 'importants', 'a', "l'"] alta
# ['comissió', 'rogatòria', 'del', 'jutge'] Baltasar_Garzón
# ['en', 'els', 'anys', 'que'] va
# ['la', 'Unió_Europea', "'", '</s>'] <s>
# ['aprofitats', 'que', "s'", 'han'] de
# ['Premi_Lletra', 'de', 'pàgines', 'de'] literatura
# ['Alfredo_Sáenz_Abad', ',', 'vicepresident', 'del'] BBV
# ['qual', "l'", 'organització', 'és'] accionista
# ['van', 'donar_peu', 'a', 'la'] guerra
# ['entre', 'els', 'quals', 'ha'] esmentat
# ['la', 'Parròquia_de_Santa_Maria', ',', 'la'] Regidoria_de_Cultura
# [',', 'canviant', 'només', 'els'] marges
# ['segons', 'va', 'concloure', 'ahir'] la
# ['forma', 'accidental', ',', 'però'] la
# ['a', 'un', 'hospital', 'de'] Viena
# ['instarà', 'el', 'Govern', 'català'] a
# ['i', 'promoció', 'de', 'la'] indústria
# ['realitat', ':', 'vuit', 'periodistes'] comencen
# ['"', ',', 'afirma', 'Vilardell'] </s>
# ['lema', "'", "Per_una_nova_cultura_de_l'_aigua", "'"] ,
# ['baixada', 'acusada', 'de', 'les'] màximes
# ['Corts', 'des_de', "l'", 'any_1986'] ,
# ['la', 'categoria', 'del', 'rival'] sinó
# ['any_2002', ',', 'Maurice_Kacen', ','] el
# ['col·laboració', 'amb', 'Foment', ','] "
# ['aprofitament', 'urbanístic', 'o_bé', 'per'] a
# ["l'", 'any_2001', ',', 'que'] preveia
# ['a', 'la', 'superfície', 'els_seus'] verdaders
# ['van', 'localitzar', 'concentracions', 'anormals'] en
# ['i', '12', 'en', 'la'] d'
# ['a', 'la', 'Cambra', 'navarresa'] ,
# ['domicilis', ',', 'i', 'disminuir'] els
# ['Garrigues_Baixes', 'estan', 'provocant', 'la'] disgregació
# ['xatracs', ',', 'baldrilles', ','] pardeles
# ['líders', 'mundials', 'és', 'un'] dels
# ['en_direcció_a', 'Albània', '</s>', '<s>'] La_Garriga_Espai_Participatiu
# ['conveni', 'és', 'potenciar', 'les'] comarques
# ['requerir', '-li', 'que', "s'"] abstingués
# ['El', 'futur', 'esportiu', 'de'] Marco_Pantani
# ['mercat', 'mundial', 'de', "l'"] automòbil
# ['seus', 'antics', 'col·laboradors', "d'"] Hisenda
# [',', 'en', 'declaracions', 'a'] Libération
# ['de', 'pessetes', 'al', "Parc_Natural_del_Delta_de_l'_Ebre"] contra
# ['veure', 'que', 'tant', 'Artur_Mas'] com
# ['<s>', 'Com_a', 'novetat', ','] l'
# [',', 'segons', 'van', 'informar'] ahir
# ['les', 'dues', 'vies', 'de'] sanció
# ['figura', ',', 'els', "'"] Assentaments_Rurals_d'_Interès_Forestals
# ['<s>', 'Treballa', 'com_a', 'professor'] de
# ['li', 'hem', 'preparat', 'res'] especial
# ['sense', 'cobertura', '</s>', '<s>'] Entre
# ['Dragados', 'i', 'Buygues', ';'] l'
# ['títols', ',', 'cosa', 'que'] no
# ['destaca', "l'", 'aprovació', 'del'] PERI
# ['a', 'demanar', 'almoina', 'per'] a
# ['per', 'mil·lilitre', 'de', 'sang'] ,
# [',', 'es', 'limiten', 'a'] prendre
# ['països', 'més', 'pobres', ','] l'
# ['li', 'van', 'protegir', 'el'] canell
# ['li', 'va', 'passar', 'una'] desena
# ['UPC', 'de', 'Terrassa', ','] i
# ['que', 'això', 'pugui', 'tenir'] per
# ['</s>', '<s>', 'De_Sàrraga', 'ha'] afegit
# ['amb', 'el_seu', 'pare', '"'] </s>
# ['</s>', '<s>', 'El', "Grup_Parlamentari_d'_Izquierda_Unida"] ha
# ['audiovisual', 'però', 'va', 'afegir'] que
# ['del', 'trajecte', 'Lleida-Plana_de_Picamoixons-Roda_de_Barà', '</s>'] <s>
# ['ha', 'més', 'signes', 'de'] debilitat
# ['molta', 'població', 'flotant', '</s>'] <s>
# ['van', 'intervenir', 'a', 'Granada'] el
# ['grup', 'de', 'dirigents', 'només'] desitja
# ['fiscals', 'seria', 'de', '10'] abonaments
# ['les_seves', 'sucursals', 'i', 'la_seva'] percepció
# ['afectar', ',', 'a_partir_de', 'la'] tarda
# ['Intra-ACN', '</s>', '<s>', 'Amb'] treballs
# ['diferència', 'davant', 'els', '"'] curts
# [',', 'quan', 'el', 'nou'] Lliure
# ['la', 'Generalitat', 'i', 'anuncia'] que
# ['La', 'proposta', ',', 'i'] seguint
# ['es', 'disputarà', 'un', 'escó'] de
# ['pallissa', 'a', 'un', 'taxista'] ,
# ['la', 'intervenció', "d'", 'altres'] persones
# [',', 'Josep_Marsal', '</s>', '<s>'] Marsal
# ['les', 'responsabilitats', 'de', 'diputat'] al
# ['els', 'agrada', 'Rexach', ','] i
# ['<s>', 'Amb', 'la', 'mesura'] ,
# ['i', 'cal', 'descentralitzar', 'el'] fenomen
# ['dopatge', 'i', 'que', 'pugui'] ser
# ['edifici', 'històric', '-', 'de'] 8.600
# ['de', 'serenitat', 'necessari', 'per'] asseure
# ['que', 'els', 'ciutadans', 'utilitzessin'] el
# ['serà', 'explotat', 'per', 'un'] consorci
# ["d'", 'apallissar', '-les', ','] cosa
# ['en', "l'", 'eficàcia', 'dels'] actors
# ['explicada', 'pel', 'setmanari', 'Familia_Cristiana'] </s>
# ['la', 'línia', 'i', "l'"] estació
# ['i', 'portarà', 'una', 'pancarta'] on
# ['del', 'Moianès', ',', 'de'] destins
# ['proper', '27_de_juliol', ',', 'al'] País_Basc
# ['Un', 'contraatac', 'amb', 'obertura'] final
# ['la', 'conclusió', 'ni_tan_sols', 'presumptiva'] ,
# ['no', 'tenen', 'més', 'risc'] de
# ['</s>', '<s>', 'Aquesta', 'xarxa'] exterior
# ['reafirmar', 'ara', '"', 'que'] cap
# ['li', 'ha', 'reclamat', 'que'] lideri
# [',', 'es', 'presenta', 'sense'] cap
# ['Sant_Joan', 'de', 'Sant_Feliu_de_Llobregat', ','] perquè
# [',', 'França', ',', 'Bèlgica'] ,
# ['Cultura', 'de', "l'", 'Ajuntament_de_Reus'] ,
# ['A_més', ',', 'vol', 'augmentar'] la
# ['dels', 'vallencs', "'", '</s>'] <s>
# ['té', 'un', 'pressupost', 'de'] 110
# ['a', 'casa', 'de', 'la'] víctima
# ['de', 'pes', 'ha', 'estat'] atribuït
# ['tocaments', 'als', 'genitals', ','] i
# ['la', 'població', 'catalana', 'afavoreix'] un
# ['instal·lació', 'de', 'dues', 'línies'] més
# ['el_seu', 'company', 'de', 'repartiment'] ,
# ['dels', 'carrers', 'ens', 'recorden'] personatges
# ['les', 'condicions', 'en', 'les'] quals
# ['milions', 'de', 'pessetes', '</s>'] <s>
# ['premis', ',', 'i', 'valorarà'] la
# ['</s>', '<s>', 'Expotecnia-99', 'té'] compromesos
# ['Malas', ',', 'de', 'Carmen_Alborch'] </s>
# ['invariable', '</s>', '<s>', 'Els'] increments
# ['la', 'indústria', 'es', 'van'] registrar
# ['companyia', 'de', 'telecomunicacions', '</s>'] <s>
# ['<s>', 'A_més', ',', 'també'] han
# ['de', 'Sant_Boi', 'per', 'a'] l'
# ["'", 'pot', 'ser', 'un'] salt
# ['<s>', 'El', 'projecte', ','] acollit
# ['la', 'defensa', 'de', 'la'] bondat
# ['-se', 'a', '24', 'milions'] </s>
# ["L'", 'equip', 'que', 'guanyi'] aquesta
# ['i', 'millorar', 'la', 'qualitat'] de
# ['altra', 'que', ',', 'per'] aconseguir
# ['el', 'tercer', 'decimal', 'és'] inferior
# ['fins', 'mitja', 'hora', 'després'] d'
# ['del', 'PSC', '</s>', '<s>'] En
# ['del', 'Baix_Llobregat_Nord', 'i', 'del'] Berguedà
# ['al', 'Teatre_Principal', 'de', 'Vilanova_i_la_Geltrú'] </s>
# ['No', 'es', 'descarta', 'que'] el
# ['la', 'promouen', 'o', "l'"] estudien
# ['Universitat_de_Vic', '</s>', '<s>', "S'"] hi
# ['que', 'els', 'contes', 'es'] facin
# ['exploració', 'psicològica', 'del', 'processat'] abans
# ['<s>', 'Documentos_TV', 'es', 'tanca'] amb
# ['del', 'Centre_Internacional_de_Cooperació', 'sobre', "l'"] Efecte_2000
# ['<s>', 'Per', 'reflexionar', 'sobre'] aquestes
# ['a_càrrec_de', 'tècnics', 'alemanys', '</s>'] <s>
# ['negar', '-se', 'a', 'les'] peticions
# ['espanyol', 'que', "l'", 'acompanyava'] es
# ['<s>', 'Ticó', 'ha', 'comentat'] a
# ['A_més_a_més', ',', 'les', 'companyies'] que
# ['no', 'el', 'canalitzador', 'de'] les
# ['nois', 'al', 'pati', "d'"] una
# ['que', 'el', 'tribunal', 'havia'] prohibit
# [',', 'per', 'uns', 'vots'] ,
# ['sanitari', 'més', 'participatiu', ','] garantint
# ['que', 'va', 'trencar', 'la'] disciplina
# ['és', 'que', 'el', 'professor'] ,
# ['com', 'el', 'de', 'la'] Guàrdia_Urbana
# ['propietari', "d'", 'easyJet', ','] han
# ['fibra', 'òptica', 'necessària', 'per'] desenvolupar
# ['de', '10', 'Mbytes', 'en'] aproximadament
# ['decennals', '</s>', '<s>', "L'"] obra
# ['que', 'proposen', 'inclou', 'dues'] zones
# ['del', 'bus', 'i', 'del'] metro
# ['recordatoris', ',', 'seriosos', 'o'] irònics
# ['càrrecs', 'en', 'activitats', 'de'] la
# ['</s>', '<s>', 'Clos', 'va'] aconseguir
# ["D'", 'aquestes', 'operacions', ','] 107
# ['regir', 'el', 'creixement', 'de'] Girona
# ['una', 'gestió', 'i', 'explotació'] també
# ['tots', 'aquells', 'que', "s'"] entesten
# ['de', 'Fomento_de_Construcciones_y_Contratas', 'va', 'ser'] de
# ['el', 'tenor', 'català', ','] que
# ['color', '</s>', '<s>', 'Les'] Jornades
# ['fixar', 'objectius', 'de', 'futur'] i
# ['lleus', 'les', 'temptatives', "d'"] assassinat
# ["d'", 'altres', '</s>', '<s>'] Les
# ['Per', 'Moreno', ',', 'Valls'] '
# ['votació', 'per', 'aprovar', 'la'] constitució
# ['organització', 'municipal', 'a', 'la'] de
# ['<s>', 'Tenim', 'desavinences', 'amb'] Batasuna
# ['no', 'pretén', "'", 'de'] cap
# ['activitats', 'a', 'la', 'Casa_de_Cultura'] de
# ['important', 'que', 'se', 'celebra'] en
# ['de', 'Ratzinger', 'sobre', "l'"] ecumenisme
# ['registrar', 'un', 'augment', 'del'] 0,1%
# ['del', 'PSC', 'que', 'treballa'] amb
# ['exercia', 'de', 'crític', 'gastronòmic'] en
# ['també', 'al', 'pavelló', 'Araba'] </s>
# ['actuarà', 'demà', 'al', 'vespre'] al
# ['<s>', 'Tots', 'dos', 'van'] acordar
# ['sentimentalisme', 'i', 'intimisme', '-'] ,
# ['han', 'comunicat', ',', 'el'] nen
# ['de', 'Figueres', ',', 'a_partir_de'] les
# ['resolució', 'confirma', 'la', 'valoració'] que
# [',', 'tot_i_que', 'també', 'hi'] ha
# ['successor', 'abans', 'de', 'morir'] l'
# ['cas', 'del', 'Palau', '"'] ,
# ['conflicte', 'basc', ',', 'la'] guerra
# ['projecte', 'governamental', 'que', 'preveu'] més
# ['i', 'París', 'per', 'realitzar'] treballs
# ["l'", 'equilibri', 'entre', "l'"] oferta
# ['autoritzats', 'per', 'la', 'Junta_Electoral'] </s>
# ['buscar', 'informació', 'del', 'seu'] personatge
# ['Federació', 'espanyola', 'a_causa_de', 'les'] declaracions
# [',', 'sembla', 'que', "l'"] educació
# ['any', 'de', 'presó', 'Carles_Ocaña_Crespo'] ,
# ['de', "l'", "Escola_d'_Art_de_la_Diputació_de_Tarragona", ';'] Josep_Sala
# ['compta', 'amb', 'gairebé', '500'] accionistes
# ['han', 'enregistrat', 'temperatures', 'de'] rigorós
# ['acabar', '-se', 'el', 'termini'] Àngel_González
# ['<s>', 'La', 'primera', 'estatueta'] per
# ['Generalitat', "s'", 'ha', 'decidit'] a
# ['50', 'treballadors', 'tenen', "l'"] obligació
# ['i', 'van', 'sufocar', 'el'] debat
# ['de', 'la', 'mort', "d'"] uns
# ['capital', 'de', 'Kosovo', '</s>'] <s>
# ['anunciar', 'que', ',', 'cada'] any
# ['que', "Universal_'s_Port_Aventura", 'reserva', 'per'] a
# ['obriran', 'al', 'mateix', 'temps'] que
# ['aquests', 'documents', '</s>', '<s>'] El
# ['</s>', '<s>', "L'", 'Inter'] viu
# ["des_d'", 'un', 'plató', 'i'] en
# ['però', 'el_seu', 'canell', 'esquerre'] tampoc
# ['Barcelona', 'no', 'repercutirà', 'en'] les
# ['han', 'participat', 'experts', 'arribats'] d'
# ['en', 'la', 'producció', "d'"] aquelles
# ['<s>', '12', 'CD', '</s>'] <s>
# ['oficines', 'per', 'tot', 'el'] territori
# ['el', 'patrimoni', 'cultural', 'i'] natural
# ['les', 'agències', "d'", 'esdeveniments'] i
# ['espectacles', 'més', 'ben', 'rebuts'] en
# ['la', 'suposada', 'gran', 'atracció'] al_llarg_del
# ['sola', 'i', 'ferida', ','] i
# ['un', '90%', '-', 'per'] als
# [',', 'tot_i_que', 'no', 'deixava'] per
# ["'", ',', 'perquè', 'era'] '
# ['realitzat', 'pel', "Centre_d'_Estudis_Dalinians", ','] presentarà
# ['inscrit', 'utilitzant', 'les', 'targetes'] i
# ['situï', 'Catalunya', 'com', 'un'] referent
# [',', 'aquest', 'document', 'caldrà'] consignar
# ['En', 'la', 'trobada', 'a'] la
# [',', 'a_través_de', 'la', 'qual'] li
# ['li', 'va', 'dir', 'que'] no
# [',', 'amb', 'la', 'intenció'] de
# ['"', 'de', 'quatre', 'grapes'] "
# ['assumpte', 'que', 'ambdós', 'partits'] de
# ['En', 'aquest', 'sentit', ','] el
# ['la', 'Universitat_Rovira_i_Virgili', "'", 'en'] el_seu
# ['ho', 'donen', '"', '</s>'] <s>
# ['Escartín', ',', 'després', "d'"] augmentar
# ['que', 'la', 'Sindicatura', 'designi'] un
# ['a', 'Castella_i_Lleó', '</s>', '<s>'] Melero
# ['Tots', 'contra', 'Arzalluz', '</s>'] <s>
# ['més', 'gran', 'aquest', 'any'] amb
# ['i', 'escoles', 'amb', 'servei'] de
# ['falta', 'de', 'judici', 'pels'] juristes
# ['tribunal', 'de', 'la', 'secció'] setena
# ['dissipar', 'els', 'temors', 'provocats'] pel
# ['permetre', 'consolidar', 'i', 'potenciar'] l'
# ['ampliació', 'del', 'contracte', ','] sempre
# ['municipal', ',', 'de', 'rampes'] d'
# ['companyia', 'Transtours', ',', 'amb'] 175
# ['Catalunya', 'és', 'un', 'país'] on
# ['</s>', '<s>', 'De_fet', ','] tant
# ['<s>', 'Les', 'crítiques', 'del'] jutge
# ['Ajuntament_de_Vilafranca', 'continua', 'mantenint', 'contactes'] amb
# ['actuació', 'en', 'aquest', 'sector'] es
# ['de', 'molts', 'ciutadans', 'que'] aquest
# ["'", ',', 'però', 'han'] comentat
# ['vergonya', 'de', 'molts', 'i'] desprestigi
# ['com_ara', 'retribucions', ',', 'seguretat'] o
# ['aquest', 'partit', 'i', 'ha'] reiterat
# ['riu', 'Congost', 'es', 'plantaran'] freixes
# ['no', 'va', 'tirar', 'marxa'] enrere
# ['varietats', "d'", 'aquesta', 'marca'] també
# ['enormement', 'desesperançada', '"', '</s>'] <s>
# ['amenacin', 'una', 'part', 'important'] de
# ['aigua', ',', 'els', 'mitjans'] de
# ['un', 'Sopar_Romà', 'i', 'Malabars'] a
# ['espanyol', ',', 'José_María_Aznar', ','] i
# ['lectures', 'diferents', 'sobre', 'la'] tinença
# ['treball', 'de', 'grup', '</s>'] <s>
# ['-li', 'el', 'passaport', 'i'] des_de
# [',', 'que', 'va', 'des_del'] tango
# ['més', 'de', 'cinc', 'anys'] que
# ['dues', 'dedicades', 'a', 'la'] fabricació
# ['2001', 'i', 'Quim_Monzó', '2002'] </s>
# ['"', 'no', 'consentirà', '"'] </s>
# ['de', "l'", 'arquitectura', ','] Pich-Aguilera
# ['ha', 'presentat', 'avui', 'una'] campanya
# ['assessorament', ',', 'atenció', 'i'] tractament
# ['suposa', 'el', 'retorn', 'de'] Parsifal
# ['ser', 'reduït', 'pels', 'policies'] quan
# ['estat', 'cap', 'de', "l'"] oficina
# ['la_seva', 'declaració', 'de', "l'"] any
# ['a', 'acabar', 'tancant', 'les'] portes
# ['Washington', 'va', 'sostenir', 'que'] va
# ["Escola_d'_Art_de_Manresa", 'inaugura', 'el', 'dia_9_de_gener'] l'
# ['cuidar', 'el', 'medi_ambient', '</s>'] <s>
# ['atur', "s'", 'ha', 'incrementat'] d'
# ['declaracions', 'a', 'Mollerussa', ','] on
# ['espai', 'per', 'a', 'la'] commemoració
# ['aquests', 'dos', 'darrers', 'casos'] també
# ['els', 'preparatius', 'per', 'apadrinar'] -lo
# ['com_a', 'exemple', 'les', '20'] hectàrees
# ['Una', 'nova', 'producció', 'sobre'] catàstrofes
# ['"', '</s>', '<s>', 'El'] clamor
# ['jutge', 'de', 'guàrdia', 'el'] dia
# ['de', "l'", 'aparició', 'a'] la
# [',', 'establir', 'mecanismes', 'que'] vetllin
# ['conseqüències', 'que', 'pot', 'tenir'] en
# ['passat', 'des_de', 'llavors', 'unes'] 500
# ['flanc', 'elegit', 'per', 'minar'] el
# ['té', 'la', 'filial', 'espanyola'] a
# ['de', 'virtuosos', 'com', 'Carl_Flesch'] i
# ['CAC', ',', 'que', 'com_a'] mínim
# ['del', 'tram', 'de', 'platja'] limítrof
# ['les', 'agències', 'de', 'viatges'] </s>
# ['i', 'un', 'taller', 'de'] braçalets
# ['mesos', 'seguits', ',', 'i'] uns
# ['reuneix', 'els', 'principals', 'grups'] que
# ['quina', 'resposta', 'es', 'donava'] a
# ['la_seva', 'principal', 'preferència', ','] encara_que
# ['política', 'havia', 'estat', 'tocant'] un
# [',', 'quatre', 'vegades', ','] el
# ['fer', 'un', 'complex', 'hoteler'] i
# ["l'", 'edifici', 'de', 'Lluís_Doménech_i_Montaner'] després
# ['persones', 'amb', 'minusvàlues', '</s>'] <s>
# ["l'", 'establiment', 'podria', 'perdre'] diners
# ['diagnòstic', 'els', 'metges', 'es'] mostren
# ['"', 'Hem', 'de', 'lluitar'] amb
# ['catalana', "'", '</s>', '<s>'] Cerf
# ['ser', 'substituït', 'pel', 'personal'] titular
# ['a', 'dirigir', 'els', 'socialistes'] ,
# ['ha', 'el', 'president', ','] el
# ['<s>', "L'", 'objectiu', 'és'] evitar
# ['Dels', '46', 'números', 'editats'] fins
# ['la', 'Marató', "d'", 'EMUTE'] a_favor_de
# ["l'", 'única', 'entitat', "d'"] aquestes
# ['</s>', '<s>', 'Les', 'lents'] ,
# ['-se', 'públic', 'que', 'la'] inflació
# ['mateixa', 'comissaria', ',', 'i'] que
# ['els', '992', 'de', 'la'] que
# ['els', 'estatuts', 'reguladors', 'del'] Consorci_Turístic
# ['i', 'li', 'van', 'fer'] entregar
# ['per', 'a', 'aquest', 'lloc'] el
# ['la_seva', 'malaltia', '</s>', '<s>'] Segons
# ['esporàdicament', ',', 'com', "d'"] autotuteles
# ['<s>', 'Per', 'la_seva', 'part'] ,
# ['no', 'va', 'aconseguir', 'el_seu'] propòsit
# ['que', 'ja', "s'", 'ha'] constituït
# ['mateixa', 'assemblea', "s'", 'ha'] aprovat
# ['més', 'favorable', 'que', "l'"] espanyola
# ['que', 'dissenyen', 'les_seves', 'formes'] de
# ['<s>', 'És', 'un', 'vot'] que
# ['Gaspart', 'ha', 'tocat', 'sostre'] i
# ['SOCIETAT_DE_TULE', '</s>', '<s>', 'Són'] lluciferins
# ['anys', '"', 'que', 'és'] el
# ['i', 'la', 'resta', 'es'] deuen
# ['La', 'preocupació', 'expressada', 'per'] Duisenberg
# ['la', 'mostra', '</s>', '<s>'] El
# ['medul·lars', '"', ',', 'com'] reduir
# ['ribes', 'del', 'riu', 'Tàmesi'] ,
# ['Vilamalla', 'després', 'de', 'forçar'] la
# ['a', 'les', 'entitats', 'col·locadores'] de
# ...
# ["s'", 'aprofitaven', 'un_cop', 'es'] despenjaven
# ['precisar', 'Uderzo', ',', 'que'] va
# [',', 'segons', 'ha', 'dit'] el_seu
# ['el', '2,21%', '</s>', '<s>'] Altres
# ['Baix_Llobregat', ',', 'que', 'està'] assenyalat
# ['aquest', 'centre', 'funcioni', 'abans'] de
# ['Pla_Hidrològic_Nacional', 'PHN', 'elaborat', 'pel'] Govern
# ['els', 'socialistes', '</s>', '<s>'] Fins_i_tot
# ['jove', 'presumptivament', 'de', 'la'] '
# ['hauria', 'jugat', 'Pallach', '</s>'] <s>
# ['Molins_de_Rei', 'a', 'Caldes', ','] al
# ['declaració', 'de', 'suport', 'a'] la
# ['de', 'prescripcions', 'literàries', 'personalitzades'] i
# ['de', "l'", 'Ajuntament_de_Terrassa', '</s>'] <s>
# [',', 'però', 'que', 'està'] reconeguda
# ['<s>', '"', 'Les', 'obres'] ,
# ['http://www.bibliodt.org', '</s>', '<s>', "D'"] aquesta
# ['okupes', '</s>', '<s>', 'La'] policia
# [',', 'assegura', 'que', 'del'] que
# ['centres', 'i', 'familiars', '</s>'] <s>
# ['des_del', 'Govern', 'es', 'reclama'] un
# ['autor', '</s>', '<s>', 'No_obstant'] ,
# [',', 'Pere_López', ',', 'això'] suposarà
# ['que', '"', 'la', 'gent'] respecti
# ['alberguen', 'la', 'seu', 'del'] Casino_de_Barcelona
# ['tancament', 'del', 'sumari', 'que'] es
# ['un', 'mapa', 'de', 'la'] societat
# ['complaure', 'la', 'simpatia', 'dels'] seus
# ['un', 'total', 'de', '15.329'] llocs
# ['fullet', 'de', 'presentació', 'de'] la
# ['cal', 'superar', "a_través_d'", 'un'] judici
# ['a', 'la', 'Gran_Via_Jaume_I', ','] al
# ['</s>', '<s>', 'La', 'llarga'] distància
# ['de', '500', 'cantaires', "d'"] arreu
# ['el', 'pendent', 'actual', 'del'] 18_per_cent
# ['lleis', ',', 'calendari', ','] '
# [',', 'ha', 'preferit', 'no'] dir
# ['i', 'els', 'Magical_Mystery_Grup', '</s>'] <s>
# ['va', 'perdre', 'la', 'majoria'] absoluta
# ["l'", 'assistència', 'a', 'una'] conferència
# ['dit', 'amb', 'sorna', 'Trias'] </s>
# ['per', 'les', 'autoritats', '</s>'] <s>
# ["L'", 'equipament', ',', 'situat'] al
# ['batre', 'el', 'record', 'caldrà'] que
# ['llenyosa', '</s>', '<s>', 'Pot'] arribar
# ['pròxims', 'dies', '</s>', '<s>'] La
# ['apunta', 'que', '"', 'hi'] haurà
# ['per', 'una', 'oficina', 'especial'] ,
# ['de', "l'", 'aigua', 'basada'] en
# ['informat', 'fonts', 'de', 'Transports_Metropolitans_de_Barcelona'] TMB
# ['han', 'hagut', 'de', 'deixar'] la
# ['una', 'càlida', 'ovació', '</s>'] <s>
# ["l'", 'Estat', 'espanyol', 'amb'] un
# ['de', 'les', 'últimes', 'setmanes'] ,
# ['centrals', 'nuclears', ',', 'empreses'] subministradores
# ['compres', 'de', 'les', 'empreses'] va
# ['la', 'correspondència', 'que', 'va'] mantenir
# ['ha', 'elevat', 'el', 'patrimoni'] dels
# ['sol·licita', 'als', 'grups', 'polítics'] amb
# ['necessitats', 'de', 'producció', '</s>'] <s>
# ['negre', 'realitzades', 'per', "l'"] empresa
# ['als', 'tribunals', 'si', 'cal'] ,
# ['serà', 'a', 'les', 'nou_del_vespre'] de
# ['els', 'àmbits', 'en', 'què'] la
# ['Els', 'veïns', 'han', 'iniciat'] una
# [',', 'segons', 'les', 'dades'] del
# ['congrés', 'de', 'la', 'societat'] civil
# ['"', '</s>', '<s>', "L'"] articulista
# ['Estan', 'a', 'Barcelona', 'i'] València
# ['que', "s'", 'està', 'donant'] massa
# ['18%', 'hagin', 'decidit', 'tancar'] l'
# ['judici', ':', '"', 'És'] una
# ['de', 'la', 'plaça', 'del'] Carme
# ['de', "l'", 'esbart', 'Ciutat_Comptal'] vestides
# ['de', 'multa', 'per', 'a'] un
# ['Hospital', 'de', 'beneficència', 'de'] Girona
# ['dimarts', 'que', 've', 'en'] la
# ['12,1%', 'de', 'la', 'població'] d'
# ['actors', 'els', 'agrada', 'conèixer'] els
# ["'", ',', 'que', 'relaten'] la_seva
# ['aconseguir', 'aplegar', 'entre', '15.000'] i
# ['19,1%', 'de', 'les', 'infraccions'] </s>
# [',', 'aquesta', 'li', 'va'] caure
# ["d'", 'altres', '</s>', '<s>'] La
# [',', 'i', ',', 'sense'] identificar-los
# ['italià', '</s>', '<s>', '-'] ¿
# ["l'", 'emissor', ',', 'que'] som
# ['parlat', "d'", 'irregularitats', 'urbanístiques'] '
# ['</s>', '<s>', 'Si', 'se'] segueix
# ['ahir', 'que', 'el', 'contenciós'] només
# ['candidatura', 'de', 'Joaquim_de_Miquel', 'seran'] nomenats
# ['Mossos', 'han', 'localitzat', 'el'] cotxe
# ['petites', 'i', 'mitjanes', ','] perquè
# ['ja', 'ha', 'anunciat', 'que'] interposarà
# ['Els', 'serveis', 'informatius', 'de'] la
# [',', 'les_seves', 'tarifes', 'han'] augmentat
# ['PP', 'van', 'fer', 'ahir'] front
# ['polític', 'de', 'fons', ','] que
# [',', 'respectivament', ',', 'a'] la
# ['preguntes', ',', 'que', 'anirien'] eliminant
# ['som', 'administració', 'local', 'amb'] vocació
# ['creixement', 'econòmic', '</s>', '<s>'] Aquesta
# ['a', 'les', 'ciutats', 'van'] fer
# ['Són', 'obres', ',', 'ha'] assegurat
# ['que', "'", 'en', 'moltes'] coses
# ['<s>', 'Dues', 'casualitats', ':'] l'
# ['arsenal', 'massiu', ',', 'en_lloc_de'] seguir
# ['les', 'línies', '2', 'i'] 3
# [',', 'des_de', "l'", 'experiència'] i
# ['el', 'dia_14', ',', 'però'] en
# ['naixement', 'de', 'Salvador_Dalí', ','] ha
# ['de', 'protecció', "d'", 'ocells'] -
# ['Barcelona', "s'", 'ha', "d'"] implicar
# ['de', 'Ràdio_Tortosa', 'Baix_Ebre', ';'] 107.0
# ['una', 'edició', 'especial', ','] que
# ['federació', 'adverteix', 'que', 'la'] indústria
# ['patrimoni', 'artístic', 'de', 'la'] corporació
# ["s'", 'havien', 'produït', 'a'] Castella_la_Manxa
# ['ahir', ',', 'durant', 'la'] presentació
# ['contractació', 'en', 'precari', "'"] </s>
# ['que', 'la', 'corresponsal', 'a'] Amèrica_Llatina
# ['<s>', 'No_obstant', 'això', ','] la
# ["l'", 'Equip_de_Govern', 'de', "l'"] Ajuntament_de_Lleida
# ['ha', 'acceptat', 'la', 'pena'] sol·licitada
# ['i', 'que', 'afecten', 'un'] 20_%
# ['i', 'que', 'se', "l'"] havia
# ['a', 'Catalunya', 'és', 'de'] 57,9
# ['ja_que', 'tots', 'els', 'assortidors'] ,
# ['enllà', 'de', 'les_seves', 'competències'] ,
# ['va', 'retractar', 'ahir', 'dels'] insults
# ['haver', 'anat', 'a', 'les'] llistes
# ['pretensió', 'de', '"', "l'"] esquerra
# ['guanyat', 'la_seva', 'primera', 'medalla'] en
# ['interpretarà', "'", 'Donna_,_donna', "'"] ,
# [',', 'i', 'també', 'les'] noves
# ['</s>', '<s>', 'Per', 'a'] la
# ['València', ',', 'que', "a_partir_d'"] avui
# ['París', ',', 'Londres', ','] Mònaco
# ['de', 'repetir', 'aquest', 'pacte'] ,
# ['majoria', 'dels', '252', 'accidents'] de
# ['sobirania', ',', "l'", 'estratègia'] política
# ['iniciativa', 'del', 'Palau', ','] a
# ['se', "'ls", 'queda', 'la'] companyia
# ["d'", 'hora', ',', 'diguem'] que
# [',', 'cas', 'de', 'Berlusconi'] ,
# ['la', 'importància', 'del', 'conveni'] per
# ['alguns', 'dels', 'membres', 'del'] col·lectiu
# ['</s>', '<s>', '"', 'Això'] es
# [',', 'i', 'es', 'comptabilitzaven'] 2.217
# ['a', 'referir', 'a', 'la'] possibilitat
# [',', 'culturals', ',', 'històrics'] ,
# ['que', 'la', 'Reserva_Federal', 'no'] haurà
# [',', 'qui', 'ha', 'denunciat'] que
# ['els', 'grups', 'parlamentaris', ','] fa_referència
# ['</s>', '<s>', 'Els', "Mossos_d'_Esquadra"] han
# ['<s>', 'El', 'GEPSE', 'no'] disposa
# ['escenes', 'de', 'Gran_hermano', 'han'] batut
# ['Juan_José_Lucas', '</s>', '<s>', 'Tots'] dos
# ['Barcelona', ',', 'així_com', 'en'] diversos
# ['per', 'al', 'pròxim', '21_de_juny'] ,
# ['recitatius', 'soporífers', 'allunyats', 'de'] tota
# ['moral', ',', 'hi', 'entra'] l'
# ['El', 'Premi_Sant_Jordi', 'de', 'novel·la'] estarà
# ['de', 'pisos', 'tutelats', 'a'] la
# ['destinar', 'a', 'les', 'comarques'] de
# ['a', 'la', 'zona', 'de'] banyistes
# ['als', 'Serveis_Territorials', 'de', 'Girona'] ,
# ['aquesta', 'manera', ',', 'pensa'] que
# ['bombos', ',', 'custodiats', 'dia'] i
# ['decidissin', 'prescindir', 'del', 'Govern'] espanyol
# ['un', 'mínim', "d'", 'un'] 2_per_cent
# ['"', 'pantomima', '"', 'i'] va
# ['estat', 'durant', 'les', 'dues'] últimes
# ['inversions', 'a', 'la', 'planta'] per
# ['de', 'Joan_Miró', 'i', 'Antoni_Tàpies'] durant
# ['de', 'terror', 'després', 'de'] la
# ['en', 'sessió', 'extraordinària', 'avui'] ,
# ['metres', 'de', 'llargada', ','] amb
# [',', 'a', "l'", 'únic'] fòrum
# ['<s>', 'Aquesta', 'actuació', 'possibilita'] la
# ['la', 'fugida', "d'", 'entre'] 2.000
# ['de', 'morts', 'per', 'accident'] de
# ['a', 'Catalunya', 'ha', 'baixat'] de
# ['grup', 'francès', 'que', 'combina'] ritmes
# ['desenvolupament', '"', 'i', 'garantir'] el
# ['Sot', ',', 'que', 'guanyarà'] 350
# ['convertit', 'en', 'un', 'gueto'] estanc
# ['<s>', 'Les', 'últimes', 'dades'] relatives
# ['de', 'la', 'centralitat', 'en'] la
# ['66.554', 'milions', 'de', 'pessetes'] a
# ['al', 'mestre', 'Nusrat_Fateh_Ali_Khan', ','] amb_motiu_del
# ['han', 'demanat', 'als', 'seus'] homòlegs
# ['i', 'conquistats', 'per', 'la_seva'] concepció
# ['¿', 'Com', 'se', "'n"] surt
# ['està', 'oberta', 'a', 'músics'] de
# ['<s>', 'També', 'es', 'mantindrà'] la
# [',', 'el', 'Solsonès', ','] el
# ["l'", 'Antàrtida', 'és', 'una'] espècie
# ['i', 'a', "'", 'Mujer_en_guerra'] '
# ['<s>', 'La', 'cerimònia', "d'"] ahir
# ['alguna', 'responsabilitat', "'", '</s>'] <s>
# ['que', 'encara', 'es', 'puguin'] interposar
# ["l'", 'etíop', 'Wami', 'i'] guanyar
# ['la', 'Costa_Daurada', 'a_través_del', 'turisme'] ,
# ["L'", 'informe', 'de', 'la'] gestora
# [',', 'una', 'concentració', 'silenciosa'] davant
# ['tarragoní', '</s>', '<s>', 'Per'] a
# ['declaracions', 'de', 'Serrahima', ','] en
# [',', 'no', 'es', 'registraven'] retencions
# ['i', 'derivats', '</s>', '<s>'] Puig
# ['intencionada', 'és', 'la', 'venjança'] ,
# ['malgrat_que', 'no', 'portava', 'arma'] ,
# ['gran', 'part', 'del', 'seu'] recorregut
# ['que', 'la', 'recollida', 'no_només'] era
# ['entre', '1979', 'i', '1991'] </s>
# ['conduir', 'de', 'manera', 'abrupta'] la
# ['Reixac', '</s>', '<s>', 'Reixac'] ha
# ['la', 'direcció', 'facultativa', 'i'] els
# ['<s>', 'La', 'dreta', '"'] carca
# ['cascada', 'de', 'la', 'Casa_Vicens'] ,
# ['desdoblament', 'de', 'la', 'C-31'] sigui
# ['La', 'policia', 'de', 'Manchester'] està
# ['la', 'meitat', 'de', 'la'] producció
# ['Port_de_Tarragona', 'és', 'el', 'tercer'] en
# ['El', 'jutge', 'de', 'Barcelona'] que
# ['margina', "l'", 'agricultura', 'mediterrània'] ,
# [',', 'és', 'la', 'futura'] construcció
# ['després', 'de', 'dirigir', '-se'] a
# ['emergent', 'Blair', 'amb', 'els_seus'] programes
# ['recopila', 'monòlegs', 'de', "l'"] humorista
# ['</s>', '<s>', 'Les', 'mesures'] preventives
# ['per', 'la', 'Universitat_Complutense_de_Madrid', ','] segons
# ['intervenir', 'en', 'els', 'mercats'] </s>
# ['de', 'TVC', ',', 'tal_i_com'] ha
# ['</s>', '<s>', 'El', 'Govern_de_la_Generalitat'] va
# ['deixa', 'un', 'càrrec', 'que'] ha
# ['Palau_Firal', ',', 'que', 'inclou'] la
# ['la', 'Sindicatura', 'rep', 'altres'] encàrrecs
# ['noves', 'peces', 'i', '10'] cares
# ['esbrinar', 'el', 'destí', 'final'] de
# ['experts', '</s>', '<s>', 'Els'] primers
# ["d'", 'Antes_que_anochezca', '"', 'no'] coneix
# ['amb', 'el_seu', 'autoritarisme', "'"] està
# ['mitjançant', 'la', 'construcció', 'de'] rotondes
# ['no', 'arriben', 'a', "l'"] 1%
# ['això_és', ',', 'el', 'nomenament'] de
# ['</s>', '<s>', 'Mentre_que', 'a'] les
# ['de', 'ser', 'una', 'illa'] </s>
# ['<s>', 'Així_mateix', ',', 'segons'] els
# ['definitiva', 'per', 'al', 'municipi'] de
# ['aqüífers', 'sobreexplotats', 'de', 'les'] conques
# ['part', 'del', 'davant', 'extreu'] la
# ['mentre_que', 'el', 'retard', 'mitjà'] es
# [',', 'Javier_Muguruza', ',', 'Pomada'] i
# ['el_seu', 'compromís', 'amb', 'el'] Barça
# ['</s>', '<s>', 'La', 'Plataforma'] ha
# ['fer', '-li', 'tocaments', 'als'] genitals
# ['quinze', 'mesos', 'en', 'què'] ens
# ['</s>', '<s>', 'Un', 'catamarà'] alemany
# ['molt', 'important', 'en', 'el'] Congrés
# ["s'", 'ajusta', 'a', 'dret'] i
# ['un', 'ganivet', 'mentre', 'cridava'] "
# [',', 'inevitable', 'que', 'fos'] així
# ['format', 'pels', 'estudiants', "d'"] Informàtica_de_Gestió
# ['</s>', '<s>', 'La', 'dona'] va
# ['cançons', 'de', 'Sau', 'o'] d'
# ['era', 'a', "l'", 'escenari'] s'
# ['Girona', ',', 'precedida', 'per'] una
# ['acte', ',', 'al', 'centre'] de
# ['blocs', 'i', 'garantir', 'la'] seguretat
# ['temors', 'dels', 'dies', 'previs'] davant
# [',', 'amb', 'un', 'goril·la'] de
# ['fes', 'aconsellable', '</s>', '<s>'] Els
# ['va', "d'", 'Amer', 'fins'] Anglès
# ["'", '</s>', '<s>', 'Forés'] s'
# ['que', 'pretén', 'posar', 'el'] litoral
# ['penal', '</s>', '<s>', 'El'] programa
# ['un', 'judici', 'contra', 'un'] presumpte
# ['ha', 'de', 'guanyar', 'en'] presència
# ['<s>', 'La_seva', 'primera', 'transacció'] real
# ['Carod', 'també', 'ha', 'avançat'] que
# ['que', 'desenvolupi', 'mesures', 'de'] seguretat
# ['Maragall', ',', 'informa', 'Manuel_Cabello'] </s>
# ['evitar', 'que', 'molestin', 'al'] veïnat
# ['nascut', 'amb', 'voluntat', 'de'] continuïtat
# ['després', 'compara', 'amb', 'el'] que
# ['perillar', '</s>', '<s>', 'La'] solució
# ['també', 'du', 'el', 'nom'] de
# ['després', 'de', 'les_seves', 'intervencions'] </s>
# ['sondeig', 'ha', 'estat', 'fet'] per
# [',', 'a', 'la', 'disminució'] del
# ['<s>', 'Una', 'nova', 'generació'] de
# ["l'", 'article', '245', 'de'] la
# ['molt', 'més', '</s>', '<s>'] Aquesta
# ['vuit', 'companys', 'més', 'de'] l'
# ['activa', '</s>', '<s>', 'No_obstant'] això
# ['ni', "d'", 'un', 'mer'] estudi
# ['i', 'el', 'candidat', 'republicà'] a
# ['entre', 'aquesta', 'institució', 'i'] la
# [',', 'en', 'la', 'innocència'] o
# ['van', 'trigar', 'poc', 'a'] demostrar
# ['registrats', 'per', 'compte', 'propi'] al
# ['de', 'la', 'Cambra', 'catalana'] ,
# ['del', 'partit', ',', 'Alberto_Fernández_Díaz'] </s>
# ['ha', 'incrementat', 'els_seus', 'preus'] en
# ['es', 'llegeix', 'cros', 'segueix'] sent
# ['nou', 'servei', 'de', 'telèfon'] gratuït
# ['minoritaris', ',', '435.044', 'milions'] ,
# ['amb', 'les', 'seqüeles', 'que'] presentaven
# ['ha', 'manifestat', 'Pere_Guinovart', '</s>'] <s>
# ['fomentar', '"', 'la', 'desinformació'] "
# ['les', 'ceràmiques', 'de', "l'"] artista
# ['ha', 'caracteritzat', 'per', 'una'] intensa
# ['a', 'Marràqueix', '</s>', '<s>'] Mitjançant
# ['sobre', 'el', 'desafiament', 'educatiu'] que
# ['dels', 'números', '341-343', 'de'] la
# ['i', 'el', 'sector', 'no'] sap
# ['va', 'comptar', 'amb', 'el'] suport
# ['la', 'bassa', 'per_part_del', "Departament_d'_Indústria"] </s>
# ['</s>', '<s>', 'Blair', 'es'] va
# ['i', 'al_mateix_temps', 'ha', 'reiterat'] la
# ['contra', 'els', 'drets', 'dels'] treballadors
# ['la', 'crisi', 'financera', '</s>'] <s>
# ['carrer', 'Lepant', 'de', 'Barcelona'] amb
# ['el', 'president', 'no', 'es'] presenti
# [',', 'tenia', "l'", 'oposició'] dels
# ['que', 'va', 'de', 'febrer'] a
# ['insta', 'el', 'Govern_de_la_Generalitat', 'a'] efectuar
# ['policies', 'locals', ',', 'agents'] rurals
# ['que', 'pronostica', 'un', 'avanç'] del
# ['pròxims', 'compromisos', 'previstos', 'de'] la
# ['de', 'la', 'fundació', 'antitransvasista'] exposa
# ['<s>', 'La', 'resolució', 'confirma'] la
# ['maletes', ',', 'on', 'la'] policia
# ['oferta', '</s>', '<s>', 'Aquest'] també
# ['aquest', 'any', ',', 'com_a'] novetat
# ['pes', 'se', 'les', 'hauran'] de
# ['el', 'Fòrum', ',', 'qüestió'] que
# ['si', 'va', 'vestit', 'de'] blaugrana
# ["l'", 'ampliació', 'de', 'la'] UE
# ["m'", 'estranyo', '</s>', '<s>'] Hi
# ['seu', 'context', 'en', "l'"] Estat
# ['dene', ',', 'Louis_Ayha', ','] va
# ['de', 'seguir', '-les', '</s>'] <s>
# ['projecte', 'de', 'prevenció', 'de'] focs
# ['treball', 'de', 'recerca', 'sobre'] les
# ['el', 'novel·lista', 'i', 'assagista'] Bashkim_Shehu
# ["l'", 'adquisició', "d'", 'habitatges'] "
# ['obres', 'de', 'desviament', 'del'] torrent
# ['Parc', '</s>', '<s>', 'El'] nou
# ['</s>', '<s>', 'Els', 'últims'] anys
# ['pirinenc', ',', 'malgrat_que', 'el'] permís
# ['amb', 'el', 'Govern', "l'"] establiment
# ['vianants', 'i', 'els', 'vehicles'] sense
# ['vida', 'dels', 'captaires', ','] a_través_d'
# ['Bateig_de_foc_de_Gaudí', "'", 'dels', 'Comediants'] es
# ['És', "a_l'_inrevés", '</s>', '<s>'] Ells
# ['pareos', 'combinats', 'amb', 'camises'] de
# ['de', 'Televisió_Local_per_Ones_Terrestres', 'perquè', 'ja'] emetia
# ['Nova_Via', '"', ',', 'el'] diputat
# ['el', '5,4_%', "'", '</s>'] <s>
# ['és', 'el', 'conseller', 'delegat'] ,
# ['van', 'escollir', 'un', 'fragment'] de
# ['Joan_Ferran', '</s>', '<s>', 'Al_voltant_de'] la
# ['</s>', '<s>', 'C._JANE', '/'] M._CABELLO
# ['Albufera', 'València', ',', 'Gallocanta'] Terol
# [',', 'quan', 'la', 'separació'] de
# ['abertzale', 'per_part_del', 'jutge', 'de'] l'
# ["L'_Estructura_a_l'_Arquitectura_._L'_experiència", '"', '</s>', '<s>'] La
# ['</s>', '<s>', 'No_obstant', ','] el
# ['No', "l'", 'espanten', 'els'] canvis
# ['Els', 'cementiris', 'de', 'Barcelona'] van
# ['de', "l'", 'Alcoià', '</s>'] <s>
# ['que', 'necessita', 'Euskal_Herria', '"'] ,
# ['entre', 'totes', 'dues', 'patronals'] seria
# ['quantitat', 'de', 'permisos', 'acordats'] per
# ['ball', 'a', 'la', 'sorra'] </s>
# ['com_a', 'eina', 'estratègica', 'per'] a
# ['<s>', 'La', 'col·lisió', 'es'] va
# ['de', 'treball', '</s>', '<s>'] El

# %%
class NNLM(nn.Module):
    def __init__(self, num_classes, dim_input, dim_hidden, dim_embedding):
        super().__init__()
        self.num_classes = num_classes
        self.dim_input = dim_input
        self.dim_hidden = dim_hidden
        self.dim_embedding = dim_embedding
        self.embeddings = nn.Embedding(self.num_classes, self.dim_embedding) # embedding layer or look up table
        self.hidden1 = nn.Linear(self.dim_input * self.dim_embedding, self.dim_hidden, bias=False)
        self.ones = nn.Parameter(torch.ones(self.dim_hidden))       
        self.hidden2 = nn.Linear(self.dim_hidden, self.num_classes, bias=False)
        self.hidden3 = nn.Linear(self.dim_input * self.dim_embedding, self.num_classes, bias=False) # final layer
        self.bias = nn.Parameter(torch.ones(self.num_classes))

    def forward(self, X):
        word_embeds = self.embeddings(X)
        X = word_embeds.view(-1, self.dim_input * self.dim_embedding) # first layer
        tanh = torch.tanh(self.ones + self.hidden1(X)) # tanh layer
        output = self.bias + self.hidden3(X) + self.hidden2(tanh) # summing up all the layers with bias
        return output

# %%
num_classes = len(dataset.vocabulary)
dim_input = length_window - 1
dim_hidden = 50
dim_embedding = 32
learning_rate= 1e-3
num_epochs = 60

model = NNLM(num_classes, dim_input, dim_hidden, dim_embedding)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

path = 'NNLM.pt'
do_train = True
do_test = True

# %%
# In the top menu go to Runtime -> Change runtime type and set Hardware 
# accelerator to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
model = model.to(device)
# Out:
# cuda:0

# %%
from torch.cuda.random import device_count
if do_train:
    size = len(dataloader.dataset)
    for epoch in range(num_epochs):
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if batch % 100 == 0:
                loss, current = loss.item(), batch * batch_size
                print('Epoch {} loss: {:>7f}  [{:>5d}/{:>5d}]'
                    .format(epoch+1, loss, current, size))

    torch.save({'model_state_dict': model.state_dict()}, path)
else:
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# Epoch 1 loss: 10.860778  [    0/509115]
# Epoch 1 loss: 7.070927  [100000/509115]
# Epoch 1 loss: 6.493715  [200000/509115]
# Epoch 1 loss: 6.374540  [300000/509115]
# Epoch 1 loss: 6.438286  [400000/509115]
# Epoch 1 loss: 6.164059  [500000/509115]
# Epoch 2 loss: 5.865498  [    0/509115]
# Epoch 2 loss: 5.727062  [100000/509115]
# Epoch 2 loss: 5.558372  [200000/509115]
# Epoch 2 loss: 5.637250  [300000/509115]
# Epoch 2 loss: 5.631076  [400000/509115]
# Epoch 2 loss: 5.414221  [500000/509115]
# Epoch 3 loss: 5.192548  [    0/509115]
# Epoch 3 loss: 5.205191  [100000/509115]
# Epoch 3 loss: 5.042065  [200000/509115]
# Epoch 3 loss: 5.090976  [300000/509115]
# Epoch 3 loss: 5.071109  [400000/509115]
# Epoch 3 loss: 5.069546  [500000/509115]
# Epoch 4 loss: 4.553745  [    0/509115]
# Epoch 4 loss: 4.715072  [100000/509115]
# Epoch 4 loss: 4.683568  [200000/509115]
# Epoch 4 loss: 4.873069  [300000/509115]
# Epoch 4 loss: 4.582596  [400000/509115]
# Epoch 4 loss: 4.794263  [500000/509115]
# Epoch 5 loss: 4.290627  [    0/509115]
# Epoch 5 loss: 4.410605  [100000/509115]
# Epoch 5 loss: 4.498081  [200000/509115]
# Epoch 5 loss: 4.428974  [300000/509115]
# Epoch 5 loss: 4.350593  [400000/509115]
# Epoch 5 loss: 4.494624  [500000/509115]
# Epoch 6 loss: 4.058710  [    0/509115]
# Epoch 6 loss: 3.989166  [100000/509115]
# Epoch 6 loss: 4.292597  [200000/509115]
# Epoch 6 loss: 4.292395  [300000/509115]
# Epoch 6 loss: 4.313144  [400000/509115]
# Epoch 6 loss: 4.172389  [500000/509115]
# Epoch 7 loss: 3.788846  [    0/509115]
# Epoch 7 loss: 3.864698  [100000/509115]
# Epoch 7 loss: 4.016366  [200000/509115]
# Epoch 7 loss: 3.950952  [300000/509115]
# Epoch 7 loss: 4.017631  [400000/509115]
# Epoch 7 loss: 4.213590  [500000/509115]
# Epoch 8 loss: 3.679051  [    0/509115]
# Epoch 8 loss: 3.741101  [100000/509115]
# Epoch 8 loss: 3.775223  [200000/509115]
# Epoch 8 loss: 3.802591  [300000/509115]
# Epoch 8 loss: 4.054841  [400000/509115]
# Epoch 8 loss: 4.017054  [500000/509115]
# Epoch 9 loss: 3.579481  [    0/509115]
# Epoch 9 loss: 3.642065  [100000/509115]
# Epoch 9 loss: 3.728963  [200000/509115]
# Epoch 9 loss: 3.820922  [300000/509115]
# Epoch 9 loss: 3.754643  [400000/509115]
# Epoch 9 loss: 3.953735  [500000/509115]
# Epoch 10 loss: 3.474008  [    0/509115]
# Epoch 10 loss: 3.621724  [100000/509115]
# Epoch 10 loss: 3.555552  [200000/509115]
# Epoch 10 loss: 3.685640  [300000/509115]
# Epoch 10 loss: 3.776051  [400000/509115]
# Epoch 10 loss: 3.638526  [500000/509115]

# %%
if do_test:
    num_sentences = 5
    max_num_words = 100

    nsent = 0
    generated_words = ['<s>', 'El', 'dia', 'que']
    assert len(generated_words)==dim_input # length_window-1

    model.eval()
    with torch.no_grad():
        while (nsent < num_sentences) and (len(generated_words) < max_num_words):
            # TODO: set input_ids to the list of ids of the last dim_input generated words
            input_ids = [dataset.word_to_id[word] for word in generated_words[-dim_input:]]

            pred = model(torch.tensor(input_ids).unsqueeze(0).to(device))
            probs = torch.nn.functional.softmax(pred, dim=1)

            #TODO:
            # probs is the probability of each id (word) in the vocabulary.
            # Now you have to select one output_id according to them, either the one
            # with maximum probability, or sample one id according to their
            # distribution in probs.
            # Hint: see doc. on numpy argmax and torch.multinomial
            # What's better ?

            # Using torch.multinomial to sample one id according to their distribution in probs
            output_id = torch.multinomial(probs, 1).item()

            # Get the ouput_word corresponding to the output_id
            output_word = dataset.id_vocabulary[output_id]

            generated_words += [output_word]
            if output_word == '</s>':
                nsent += 1  

    generated_text = ' '.join(generated_words)
    generated_text = generated_text.replace(' </s> <s>', '.').replace('<s> ','').replace(' </s>','.')
    for s in [' l\' ',' s\' ',' d\' ',]:
        generated_text = generated_text.replace(s, s[:-1])
    generated_text = generated_text.replace(' , ', ', ').replace('_',' ')
    print(generated_text)
# Out:
# El dia que no reunirà operadores de les eleccions autonòmiques, es vol càrrec amb una jornada de 40 necessari de fer del català i Izquierda Unida, poden marcar promocions de professionals, en concepte d' ha creat que l'interlocutor per la categoria : generacional la mundial de mà, en dos anys de presó. L' únic conseller delegat de Presidència de la qualitat que s'envolta malalts al segon nord. L' actriu es va produir a la presó Model de les conferències promocionals de notícies. Paral·lelament propietat que la referència es va pronunciar
